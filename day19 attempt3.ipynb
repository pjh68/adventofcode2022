# %% [markdown]
# # Day 19: Not Enough Minerals
#
# A classic resource and machine building strategy game.
#
# First up, let's have a quick check of the size of the problem:
#
# 24 Minutes, with a minute-resolution simulation.
# Puzzle input contains 30 blueprints.
#
# The blueprints vary the quantity of the source materials required, but they don't change the type of resource.
#
# ## Approach
#
# A first glance, this looks similar to the valves puzzle from a few days ago. I solved that using a brute-force technique, checking every single possible option (and discarding some obvious losers along the way to improve performance).
# But there are so many more possibilities here, that taking that approach seems wrong. And also a bit repetative... I want to try something different.
#
# So... how about having a strategy engine that works backwards from the goal?
#
# Generic recipes:
# a Ore              -> ore bot   -> Ore
# b Ore              -> clay bot  -> Clay
# c Ore + d Clay     -> obs bot   -> Obsidian
# e Ore + f Obsidian -> geode bot -> Geode
#
# Re-arrange to work backwards: (and ignoring time)
# 1 Geode = e Ore + f Obsidian
#         = e Ore + f (c Ore + d Clay)
#         = e Ore + fc Ore + fdb Ore
#         = ( e + fc + fdb ) Ore
#
# Start with 1 ore collecting Robot.
# Ore is the primary contraint... but we don't want an ore stock-pile at the end.
#
#
# Other approaches to consider... could this be turned into a single function that can be optimised?
# What would the inputs be? The choice how many robots of each type to build in each minute.
# But it's integer choices... so we're into integer programming - maybe try using: https://www.cvxpy.org/examples/applications/OOCO.html
#
# But perhaps I should try a slightly more straightforward way first?
#
# Many hours in, straightforward isn't working.
#
# Is this a clue in the puzzle?
# "The elephants are starting to look hungry, so you shouldn't take too long; you need to figure out which blueprint would maximize the number of opened geodes after 24 minutes by figuring out which robots to build and when to build them."
#
# Hungry suggests a greedy algorithm.
# But already discovered that doens't work.
#
# Urgghrr.... close to giving up. Do I just brute force it again?

# %%
testData ="""Blueprint 1: Each ore robot costs 4 ore. Each clay robot costs 2 ore. Each obsidian robot costs 3 ore and 14 clay. Each geode robot costs 2 ore and 7 obsidian.
Blueprint 2: Each ore robot costs 2 ore. Each clay robot costs 3 ore. Each obsidian robot costs 3 ore and 8 clay. Each geode robot costs 3 ore and 12 obsidian."""

import re

def process(input:str):
    pattern = '(\d+)'
    for l in input.splitlines():
        match = re.findall(pattern,l)
        blueprint = [int(i) for i in match]
        print(blueprint)

#test
process(testData)
# Out:
# [1, 4, 2, 3, 14, 2, 7]
# [2, 2, 3, 3, 8, 3, 12]

# %%
#optimised
ID = 0
ORE = 1
CLAY = 2
OBSIDIAN = 3
GEODE = 4

#friendly
# ID = 'ID'
# ORE = 'ore'
# CLAY = 'clay'
# OBSIDIAN = 'obsidian'
# GEODE = 'geode'

RUNTIME = 24

import copy 
from math import ceil
import random

class Puzzle:
    def blueprintsFrom(self, input):
        pattern = '(\d+)'
        blueprints = []
        for l in input.splitlines():
            match = re.findall(pattern,l)
            intarr = [int(i) for i in match]
            blueprint = {}
            blueprint[ID] = intarr[0]
            blueprint[ORE] = {ORE:intarr[1], CLAY:0, OBSIDIAN:0, GEODE:0}
            blueprint[CLAY] = {ORE:intarr[2], CLAY:0, OBSIDIAN:0, GEODE:0}
            blueprint[OBSIDIAN] = {ORE:intarr[3], CLAY:intarr[4], OBSIDIAN:0, GEODE:0}
            blueprint[GEODE] = {ORE:intarr[5], CLAY:0, OBSIDIAN:intarr[6], GEODE:0}
            blueprints.append(blueprint)
        return blueprints
    
    def __init__(self, input:str):
        self.blueprints = self.blueprintsFrom(input)
    
    def runPuzzle(self):
        total = 0
        for blueprintIndex in range(len(self.blueprints)):
            geodes = self.playGame(blueprintIndex)
            id = self.blueprints[blueprintIndex][ID]
            quality = id * geodes
            print('Completed game for blueprint ' + str(id))
            total += quality
        print ('Total score for all blueprints: ' +str(total))

    def playGame(self, blueprintID:int)->int:
        #play all version of a game for a given blueprint and return max score
        rootgame = Game(self.blueprints[blueprintID])
        processQueue = []
        maxScore = 0
        botOptions = [GEODE,OBSIDIAN,CLAY,ORE]
        completedGames = 0
        prunedGames = 0
        for bot in botOptions:
            f = rootgame.fork(bot)
            processQueue.append(f) 

        while processQueue:
            totalgames = len(processQueue) + completedGames + prunedGames
            if totalgames % 100000 == 0: #print update every thousand games
                print('Processing ' + str(len(processQueue))+ ' simulations, with pruning on: ' +str(maxScore) + ' Complete: ' + str(completedGames) + ' Pruned: '+str(prunedGames))
            game = processQueue.pop() #by taking off the bottom we have turned Queue into stack... this should give us depth first search, allowing us to cull worse answers quicker
            #fork it with every option of bot to build next
            #print('Running : ' + str(game))
            running = game.progressWithChoice()
            maxScore = max(maxScore,game.materials[GEODE])
            if running:
                if game.upperbound > maxScore:
                    #print('Qualified:' + str(game))
                    #the bot order of perference matters quite a lot... both extremes of order are clearly terrible. We might converge better by randomising
                    random.shuffle(botOptions)
                    for bot in botOptions:
                        f = game.fork(bot)
                        processQueue.append(f)
                else:
                    pass
                    #print('Pruned  : ' +str(game))    
                    prunedGames += 1
            else:
                pass
                #print('Complete: '+str(game))
                completedGames += 1
        return maxScore

class Game:
    def fork(self, nextBot:str):
        #fork a copy of the game
        f = Game(self.blueprint)
        f.time = self.time
        f.materials = copy.copy(self.materials)
        f.bots = copy.copy(self.bots)
        f.upperbound = self.upperbound
        f.nextBot = nextBot
        return f
    
    def __init__(self, blueprint):
        self.time = 0
        self.materials= {ORE:0, CLAY:0, OBSIDIAN:0, GEODE:0}
        self.bots= {ORE:1, CLAY:0, OBSIDIAN:0, GEODE:0}
        self.blueprint = blueprint
        #keep track of theoretical maximum GEODE count - will use this to prune branches
        self.upperbound = 0
        self.nextBot = 0

    def progressWithChoice(self)->bool:
        #pass in the choice of what bot to build next. Return True is there is still time on the clock, False is simulation complete
        #alway makes sense to build a bot next... because ultimate goal (geode splitting) doesn't require the consumpation of material, so it always makes sense to at least try to build another geoode bot
        botRecipe = self.blueprint[self.nextBot]
        timeRemaining = RUNTIME - self.time
        #calculate time required to build bot
        timeNeeded = 0
        for k, v in self.materials.items():
            if botRecipe[k] != 0:
                rateOfProduction = self.bots[k]
                if rateOfProduction==0:
                    #we're not building the bot
                    timeNeeded = RUNTIME + 1 #essentially forever
                else:
                    t = ceil((botRecipe[k] - v) / self.bots[k])
                timeNeeded = max(timeNeeded,t)
        
        #bot won't be ready until self.time + timeneeded + 1
        timeNeeded += 1    
        if timeNeeded > timeRemaining:
            #progress simulation to end of runtime
            for k,v in self.bots.items():
                self.materials[k] += v * timeRemaining

            self.time += timeRemaining
            return False
        else:
            #progress simualtion until bot is purchases
            for k,v in self.bots.items():
                self.materials[k] += v * timeNeeded
            #remove materials for bot build
            for k, v in self.materials.items():
                self.materials[k] -= botRecipe[k]
            #add bot
            self.bots[self.nextBot] += 1
            self.time += timeNeeded
            self.updateUpperBound()
            #print('T=' + str(self.time)+ ' Bots: ' + str(self.bots) + ' Materials: ' + str(self.materials) + ' Upperbound: ' + str(self.upperbound))
            return True
     
    def updateUpperBound(self):
        timeRemaining = RUNTIME - self.time
        #assume we build a geode bot per minute - we can come back and refine this is we want to be more brutal.
        self.upperbound = (timeRemaining + 1) * timeRemaining / 2 + self.materials[GEODE] + self.bots[GEODE] * timeRemaining

    def __str__(self):
        return 'T=' + str(self.time)+ ' Bots: ' + str(self.bots) + ' Materials: ' + str(self.materials) + ' Upperbound: ' + str(self.upperbound) + ' Next bot: ' + str(self.nextBot)
#tests
tp = Puzzle(testData)
#print(tp.blueprints)
print(tp.playGame(0))
# Out:
# Processing 28 simulations, with pruning on: 4 Complete: 16525 Pruned: 83447
# Processing 27 simulations, with pruning on: 4 Complete: 16525 Pruned: 83448
# Processing 26 simulations, with pruning on: 4 Complete: 16525 Pruned: 83449
# Processing 25 simulations, with pruning on: 4 Complete: 16525 Pruned: 83450
# Processing 24 simulations, with pruning on: 4 Complete: 16525 Pruned: 83451
# Processing 23 simulations, with pruning on: 4 Complete: 16525 Pruned: 83452
# Processing 25 simulations, with pruning on: 8 Complete: 63071 Pruned: 336904
# 9

# %%
#puzzle input
puzzleinput = open('day19input.txt').read()
p = Puzzle(puzzleinput)
p.runPuzzle()
# Out:
# Processing 29 simulations, with pruning on: 0 Complete: 41291 Pruned: 58680
# Processing 28 simulations, with pruning on: 0 Complete: 41292 Pruned: 58680
# Processing 27 simulations, with pruning on: 0 Complete: 41292 Pruned: 58681
# Processing 26 simulations, with pruning on: 0 Complete: 41292 Pruned: 58682
# Processing 25 simulations, with pruning on: 0 Complete: 41292 Pruned: 58683
# Processing 19 simulations, with pruning on: 0 Complete: 165200 Pruned: 234781
# Completed game for blueprint 1
# Processing 39 simulations, with pruning on: 1 Complete: 30598 Pruned: 69363
# Processing 38 simulations, with pruning on: 1 Complete: 30598 Pruned: 69364
# Processing 37 simulations, with pruning on: 1 Complete: 30598 Pruned: 69365
# Processing 41 simulations, with pruning on: 2 Complete: 125595 Pruned: 274364
# Processing 40 simulations, with pruning on: 2 Complete: 125595 Pruned: 274365
# Processing 39 simulations, with pruning on: 2 Complete: 125596 Pruned: 274365
# Processing 38 simulations, with pruning on: 2 Complete: 125597 Pruned: 274365
# Processing 37 simulations, with pruning on: 2 Complete: 125597 Pruned: 274366
# Processing 42 simulations, with pruning on: 2 Complete: 203330 Pruned: 496628
# Processing 41 simulations, with pruning on: 2 Complete: 203330 Pruned: 496629
# Processing 40 simulations, with pruning on: 2 Complete: 203330 Pruned: 496630
# Processing 39 simulations, with pruning on: 2 Complete: 203331 Pruned: 496630
# Processing 38 simulations, with pruning on: 2 Complete: 203331 Pruned: 496631
# Processing 31 simulations, with pruning on: 2 Complete: 266217 Pruned: 733752
# Processing 30 simulations, with pruning on: 2 Complete: 266217 Pruned: 733753
# Processing 29 simulations, with pruning on: 2 Complete: 266217 Pruned: 733754
# Processing 28 simulations, with pruning on: 2 Complete: 266217 Pruned: 733755
# Processing 27 simulations, with pruning on: 2 Complete: 266218 Pruned: 733755
# Processing 26 simulations, with pruning on: 2 Complete: 266219 Pruned: 733755
# Processing 32 simulations, with pruning on: 3 Complete: 323670 Pruned: 976298
# Processing 31 simulations, with pruning on: 3 Complete: 323670 Pruned: 976299
# Processing 30 simulations, with pruning on: 3 Complete: 323670 Pruned: 976300
# Processing 29 simulations, with pruning on: 3 Complete: 323670 Pruned: 976301
# Processing 28 simulations, with pruning on: 3 Complete: 323670 Pruned: 976302
# Processing 27 simulations, with pruning on: 3 Complete: 323670 Pruned: 976303
# Processing 26 simulations, with pruning on: 3 Complete: 323670 Pruned: 976304
# Processing 25 simulations, with pruning on: 3 Complete: 323670 Pruned: 976305
# Processing 34 simulations, with pruning on: 4 Complete: 387344 Pruned: 1212622
# Processing 33 simulations, with pruning on: 4 Complete: 387344 Pruned: 1212623
# Processing 32 simulations, with pruning on: 4 Complete: 387344 Pruned: 1212624
# Processing 31 simulations, with pruning on: 4 Complete: 387344 Pruned: 1212625
# Processing 30 simulations, with pruning on: 4 Complete: 387344 Pruned: 1212626
# Processing 29 simulations, with pruning on: 4 Complete: 470553 Pruned: 1429418
# Processing 44 simulations, with pruning on: 4 Complete: 551232 Pruned: 1648724
# Processing 43 simulations, with pruning on: 4 Complete: 551232 Pruned: 1648725
# Processing 42 simulations, with pruning on: 4 Complete: 551232 Pruned: 1648726
# Processing 41 simulations, with pruning on: 4 Complete: 551232 Pruned: 1648727
# Processing 40 simulations, with pruning on: 4 Complete: 551233 Pruned: 1648727
# Processing 39 simulations, with pruning on: 4 Complete: 551233 Pruned: 1648728
# Processing 38 simulations, with pruning on: 4 Complete: 551233 Pruned: 1648729
# Processing 37 simulations, with pruning on: 4 Complete: 551233 Pruned: 1648730
# Processing 40 simulations, with pruning on: 5 Complete: 603581 Pruned: 1896379
# Processing 39 simulations, with pruning on: 5 Complete: 603581 Pruned: 1896380
# Processing 38 simulations, with pruning on: 5 Complete: 603581 Pruned: 1896381
# Processing 37 simulations, with pruning on: 5 Complete: 603581 Pruned: 1896382
# Processing 36 simulations, with pruning on: 5 Complete: 603581 Pruned: 1896383
# Processing 35 simulations, with pruning on: 5 Complete: 603581 Pruned: 1896384
# Processing 32 simulations, with pruning on: 5 Complete: 640245 Pruned: 2159723
# Processing 31 simulations, with pruning on: 5 Complete: 640245 Pruned: 2159724
# Processing 30 simulations, with pruning on: 5 Complete: 640245 Pruned: 2159725
# Processing 29 simulations, with pruning on: 5 Complete: 640245 Pruned: 2159726
# Processing 28 simulations, with pruning on: 5 Complete: 640245 Pruned: 2159727
# Processing 27 simulations, with pruning on: 5 Complete: 640245 Pruned: 2159728
# Processing 26 simulations, with pruning on: 5 Complete: 640245 Pruned: 2159729
# Processing 27 simulations, with pruning on: 6 Complete: 675980 Pruned: 2423993
# Processing 26 simulations, with pruning on: 6 Complete: 675980 Pruned: 2423994
# Processing 25 simulations, with pruning on: 6 Complete: 675980 Pruned: 2423995
# Processing 24 simulations, with pruning on: 6 Complete: 675980 Pruned: 2423996
# Processing 23 simulations, with pruning on: 6 Complete: 675980 Pruned: 2423997
# Processing 33 simulations, with pruning on: 6 Complete: 744772 Pruned: 2655195
# Processing 32 simulations, with pruning on: 6 Complete: 744772 Pruned: 2655196
# Processing 31 simulations, with pruning on: 6 Complete: 744772 Pruned: 2655197
# Processing 30 simulations, with pruning on: 6 Complete: 744772 Pruned: 2655198
# Processing 29 simulations, with pruning on: 6 Complete: 744772 Pruned: 2655199
# Processing 28 simulations, with pruning on: 6 Complete: 744773 Pruned: 2655199
# Processing 27 simulations, with pruning on: 6 Complete: 794941 Pruned: 2905032
# Processing 28 simulations, with pruning on: 7 Complete: 826088 Pruned: 3173884
# Processing 27 simulations, with pruning on: 7 Complete: 826088 Pruned: 3173885
# Processing 26 simulations, with pruning on: 7 Complete: 826088 Pruned: 3173886
# Processing 25 simulations, with pruning on: 7 Complete: 826088 Pruned: 3173887
# Processing 24 simulations, with pruning on: 7 Complete: 826088 Pruned: 3173888
# Processing 26 simulations, with pruning on: 7 Complete: 860349 Pruned: 3439625
# Processing 25 simulations, with pruning on: 7 Complete: 860349 Pruned: 3439626
# Processing 24 simulations, with pruning on: 7 Complete: 860350 Pruned: 3439626
# Processing 23 simulations, with pruning on: 7 Complete: 860350 Pruned: 3439627
# Processing 22 simulations, with pruning on: 7 Complete: 860350 Pruned: 3439628
# Processing 34 simulations, with pruning on: 7 Complete: 888533 Pruned: 3711433
# Processing 33 simulations, with pruning on: 7 Complete: 888533 Pruned: 3711434
# Processing 32 simulations, with pruning on: 7 Complete: 888533 Pruned: 3711435
# Processing 31 simulations, with pruning on: 7 Complete: 888533 Pruned: 3711436
# Processing 30 simulations, with pruning on: 7 Complete: 888533 Pruned: 3711437
# Processing 32 simulations, with pruning on: 9 Complete: 910642 Pruned: 3989326
# Processing 31 simulations, with pruning on: 9 Complete: 910642 Pruned: 3989327
# Processing 30 simulations, with pruning on: 9 Complete: 910642 Pruned: 3989328
# Processing 29 simulations, with pruning on: 9 Complete: 910642 Pruned: 3989329
# Processing 28 simulations, with pruning on: 9 Complete: 910642 Pruned: 3989330
# Processing 27 simulations, with pruning on: 9 Complete: 944094 Pruned: 4255879
# Processing 32 simulations, with pruning on: 9 Complete: 987004 Pruned: 4512964
# Processing 31 simulations, with pruning on: 9 Complete: 987004 Pruned: 4512965
# Processing 30 simulations, with pruning on: 9 Complete: 987004 Pruned: 4512966
# Processing 29 simulations, with pruning on: 9 Complete: 987004 Pruned: 4512967
# Processing 28 simulations, with pruning on: 9 Complete: 987004 Pruned: 4512968
# Processing 27 simulations, with pruning on: 9 Complete: 987005 Pruned: 4512968
# Processing 30 simulations, with pruning on: 9 Complete: 1021174 Pruned: 4778796
# Processing 29 simulations, with pruning on: 9 Complete: 1021174 Pruned: 4778797
# Processing 28 simulations, with pruning on: 9 Complete: 1021174 Pruned: 4778798
# Processing 27 simulations, with pruning on: 9 Complete: 1021174 Pruned: 4778799
# Processing 26 simulations, with pruning on: 9 Complete: 1021174 Pruned: 4778800
# Processing 25 simulations, with pruning on: 9 Complete: 1087648 Pruned: 5012327
# Processing 24 simulations, with pruning on: 9 Complete: 1087648 Pruned: 5012328
# Processing 23 simulations, with pruning on: 9 Complete: 1087648 Pruned: 5012329
# Processing 22 simulations, with pruning on: 9 Complete: 1087648 Pruned: 5012330
# Processing 21 simulations, with pruning on: 9 Complete: 1087648 Pruned: 5012331
# Processing 20 simulations, with pruning on: 9 Complete: 1087648 Pruned: 5012332
# Processing 19 simulations, with pruning on: 9 Complete: 1087648 Pruned: 5012333
# Processing 24 simulations, with pruning on: 9 Complete: 1128416 Pruned: 5271560
# Processing 23 simulations, with pruning on: 9 Complete: 1128416 Pruned: 5271561
# Processing 22 simulations, with pruning on: 9 Complete: 1128416 Pruned: 5271562
# Processing 21 simulations, with pruning on: 9 Complete: 1128416 Pruned: 5271563
# Processing 20 simulations, with pruning on: 9 Complete: 1128416 Pruned: 5271564
# Processing 25 simulations, with pruning on: 9 Complete: 1163647 Pruned: 5536328
# Processing 24 simulations, with pruning on: 9 Complete: 1163647 Pruned: 5536329
# Processing 23 simulations, with pruning on: 9 Complete: 1163647 Pruned: 5536330
# Processing 22 simulations, with pruning on: 9 Complete: 1163647 Pruned: 5536331
# Processing 21 simulations, with pruning on: 9 Complete: 1163647 Pruned: 5536332
# Processing 24 simulations, with pruning on: 9 Complete: 1203138 Pruned: 5796838
# Processing 23 simulations, with pruning on: 9 Complete: 1203138 Pruned: 5796839
# Processing 22 simulations, with pruning on: 9 Complete: 1203138 Pruned: 5796840
# Processing 21 simulations, with pruning on: 9 Complete: 1203138 Pruned: 5796841
# Processing 20 simulations, with pruning on: 9 Complete: 1203138 Pruned: 5796842
# Processing 19 simulations, with pruning on: 9 Complete: 1203138 Pruned: 5796843
# Processing 27 simulations, with pruning on: 9 Complete: 1233793 Pruned: 6066180
# Processing 26 simulations, with pruning on: 9 Complete: 1233793 Pruned: 6066181
# Processing 25 simulations, with pruning on: 9 Complete: 1233793 Pruned: 6066182
# Processing 24 simulations, with pruning on: 9 Complete: 1233793 Pruned: 6066183
# Processing 23 simulations, with pruning on: 9 Complete: 1233793 Pruned: 6066184
# Processing 31 simulations, with pruning on: 9 Complete: 1272688 Pruned: 6327281
# Processing 30 simulations, with pruning on: 9 Complete: 1272688 Pruned: 6327282
# Processing 29 simulations, with pruning on: 9 Complete: 1272688 Pruned: 6327283
# Processing 28 simulations, with pruning on: 9 Complete: 1272688 Pruned: 6327284
# Processing 27 simulations, with pruning on: 9 Complete: 1272688 Pruned: 6327285
# Processing 26 simulations, with pruning on: 9 Complete: 1272688 Pruned: 6327286
# Processing 27 simulations, with pruning on: 9 Complete: 1327120 Pruned: 6572853
# Completed game for blueprint 2
# Processing 27 simulations, with pruning on: 2 Complete: 22284 Pruned: 77689
# Processing 23 simulations, with pruning on: 2 Complete: 110414 Pruned: 289563
# Processing 22 simulations, with pruning on: 2 Complete: 110414 Pruned: 289564
# Processing 21 simulations, with pruning on: 2 Complete: 110414 Pruned: 289565
# Processing 20 simulations, with pruning on: 2 Complete: 110414 Pruned: 289566
# Processing 19 simulations, with pruning on: 2 Complete: 110415 Pruned: 289566
# Processing 18 simulations, with pruning on: 2 Complete: 110416 Pruned: 289566
# Processing 17 simulations, with pruning on: 2 Complete: 182692 Pruned: 517291
# Completed game for blueprint 3
# Processing 32 simulations, with pruning on: 0 Complete: 41727 Pruned: 58241
# Processing 31 simulations, with pruning on: 0 Complete: 41727 Pruned: 58242
# Processing 30 simulations, with pruning on: 0 Complete: 41727 Pruned: 58243
# Processing 29 simulations, with pruning on: 0 Complete: 41728 Pruned: 58243
# Processing 28 simulations, with pruning on: 0 Complete: 41728 Pruned: 58244
# Processing 23 simulations, with pruning on: 1 Complete: 150328 Pruned: 249649
# Processing 22 simulations, with pruning on: 1 Complete: 150329 Pruned: 249649
# Completed game for blueprint 4
# Processing 22 simulations, with pruning on: 5 Complete: 13389 Pruned: 86589
# Processing 21 simulations, with pruning on: 5 Complete: 13389 Pruned: 86590
# Processing 20 simulations, with pruning on: 5 Complete: 13389 Pruned: 86591
# Processing 19 simulations, with pruning on: 5 Complete: 13389 Pruned: 86592
# Processing 18 simulations, with pruning on: 5 Complete: 13389 Pruned: 86593
# Processing 17 simulations, with pruning on: 5 Complete: 13389 Pruned: 86594
# Completed game for blueprint 5
# Processing 25 simulations, with pruning on: 0 Complete: 34493 Pruned: 65482
# Processing 24 simulations, with pruning on: 0 Complete: 34493 Pruned: 65483
# Processing 23 simulations, with pruning on: 0 Complete: 34493 Pruned: 65484
# Processing 22 simulations, with pruning on: 0 Complete: 34493 Pruned: 65485
# Processing 21 simulations, with pruning on: 0 Complete: 34494 Pruned: 65485
# Processing 33 simulations, with pruning on: 0 Complete: 138316 Pruned: 261651
# Processing 32 simulations, with pruning on: 0 Complete: 138316 Pruned: 261652
# Processing 31 simulations, with pruning on: 0 Complete: 138316 Pruned: 261653
# Processing 30 simulations, with pruning on: 0 Complete: 138317 Pruned: 261653
# Processing 29 simulations, with pruning on: 0 Complete: 138317 Pruned: 261654
# Processing 24 simulations, with pruning on: 0 Complete: 240519 Pruned: 459457
# Processing 23 simulations, with pruning on: 0 Complete: 240519 Pruned: 459458
# Processing 22 simulations, with pruning on: 0 Complete: 240519 Pruned: 459459
# Processing 21 simulations, with pruning on: 0 Complete: 240519 Pruned: 459460
# Processing 20 simulations, with pruning on: 0 Complete: 240520 Pruned: 459460
# Processing 19 simulations, with pruning on: 0 Complete: 240521 Pruned: 459460
# Processing 18 simulations, with pruning on: 0 Complete: 240522 Pruned: 459460
# Processing 30 simulations, with pruning on: 0 Complete: 342870 Pruned: 657100
# Processing 29 simulations, with pruning on: 0 Complete: 342871 Pruned: 657100
# Processing 37 simulations, with pruning on: 0 Complete: 447022 Pruned: 852941
# Processing 36 simulations, with pruning on: 0 Complete: 447023 Pruned: 852941
# Processing 35 simulations, with pruning on: 0 Complete: 447023 Pruned: 852942
# Processing 34 simulations, with pruning on: 0 Complete: 447023 Pruned: 852943
# Processing 33 simulations, with pruning on: 0 Complete: 447023 Pruned: 852944
# Processing 29 simulations, with pruning on: 0 Complete: 550035 Pruned: 1049936
# Processing 28 simulations, with pruning on: 0 Complete: 550035 Pruned: 1049937
# Processing 27 simulations, with pruning on: 0 Complete: 550036 Pruned: 1049937
# Processing 26 simulations, with pruning on: 0 Complete: 550036 Pruned: 1049938
# Processing 25 simulations, with pruning on: 0 Complete: 550036 Pruned: 1049939
# Completed game for blueprint 6
# Processing 33 simulations, with pruning on: 0 Complete: 35723 Pruned: 64244
# Processing 32 simulations, with pruning on: 0 Complete: 35723 Pruned: 64245
# Processing 31 simulations, with pruning on: 0 Complete: 35723 Pruned: 64246
# Processing 30 simulations, with pruning on: 0 Complete: 35723 Pruned: 64247
# Processing 29 simulations, with pruning on: 0 Complete: 35724 Pruned: 64247
# Processing 32 simulations, with pruning on: 1 Complete: 132223 Pruned: 267745
# Processing 31 simulations, with pruning on: 1 Complete: 132224 Pruned: 267745
# Processing 30 simulations, with pruning on: 1 Complete: 132224 Pruned: 267746
# Processing 29 simulations, with pruning on: 1 Complete: 132224 Pruned: 267747
# Processing 28 simulations, with pruning on: 1 Complete: 132224 Pruned: 267748
# Processing 27 simulations, with pruning on: 1 Complete: 132225 Pruned: 267748
# Processing 24 simulations, with pruning on: 1 Complete: 223596 Pruned: 476380
# Processing 23 simulations, with pruning on: 1 Complete: 223596 Pruned: 476381
# Processing 22 simulations, with pruning on: 1 Complete: 223597 Pruned: 476381
# Processing 21 simulations, with pruning on: 1 Complete: 223597 Pruned: 476382
# Processing 20 simulations, with pruning on: 1 Complete: 223597 Pruned: 476383
# Processing 19 simulations, with pruning on: 1 Complete: 223598 Pruned: 476383
# Completed game for blueprint 7
# Processing 23 simulations, with pruning on: 2 Complete: 28480 Pruned: 71497
# Processing 22 simulations, with pruning on: 2 Complete: 28480 Pruned: 71498
# Processing 21 simulations, with pruning on: 2 Complete: 28480 Pruned: 71499
# Processing 20 simulations, with pruning on: 2 Complete: 28481 Pruned: 71499
# Processing 19 simulations, with pruning on: 2 Complete: 28481 Pruned: 71500
# Processing 18 simulations, with pruning on: 2 Complete: 28482 Pruned: 71500
# Processing 28 simulations, with pruning on: 2 Complete: 99693 Pruned: 300279
# Processing 27 simulations, with pruning on: 2 Complete: 99694 Pruned: 300279
# Processing 17 simulations, with pruning on: 3 Complete: 181356 Pruned: 518627
# Completed game for blueprint 8
# Processing 37 simulations, with pruning on: 0 Complete: 34658 Pruned: 65305
# Processing 36 simulations, with pruning on: 0 Complete: 34658 Pruned: 65306
# Processing 35 simulations, with pruning on: 0 Complete: 34658 Pruned: 65307
# Processing 34 simulations, with pruning on: 0 Complete: 34658 Pruned: 65308
# Processing 33 simulations, with pruning on: 0 Complete: 34659 Pruned: 65308
# Processing 32 simulations, with pruning on: 0 Complete: 34660 Pruned: 65308
# Processing 32 simulations, with pruning on: 1 Complete: 130642 Pruned: 269326
# Processing 31 simulations, with pruning on: 1 Complete: 130642 Pruned: 269327
# Processing 30 simulations, with pruning on: 1 Complete: 130642 Pruned: 269328
# Processing 29 simulations, with pruning on: 1 Complete: 130642 Pruned: 269329
# Processing 28 simulations, with pruning on: 1 Complete: 130643 Pruned: 269329
# Processing 37 simulations, with pruning on: 2 Complete: 219561 Pruned: 480402
# Processing 36 simulations, with pruning on: 2 Complete: 219561 Pruned: 480403
# Processing 35 simulations, with pruning on: 2 Complete: 219561 Pruned: 480404
# Processing 34 simulations, with pruning on: 2 Complete: 219561 Pruned: 480405
# Processing 33 simulations, with pruning on: 2 Complete: 219562 Pruned: 480405
# Processing 31 simulations, with pruning on: 2 Complete: 287154 Pruned: 712815
# Processing 30 simulations, with pruning on: 2 Complete: 287154 Pruned: 712816
# Processing 29 simulations, with pruning on: 2 Complete: 287154 Pruned: 712817
# Processing 28 simulations, with pruning on: 2 Complete: 287154 Pruned: 712818
# Processing 27 simulations, with pruning on: 2 Complete: 287154 Pruned: 712819
# Processing 31 simulations, with pruning on: 3 Complete: 356070 Pruned: 943899
# Processing 30 simulations, with pruning on: 3 Complete: 356071 Pruned: 943899
# Processing 29 simulations, with pruning on: 3 Complete: 356071 Pruned: 943900
# Processing 28 simulations, with pruning on: 3 Complete: 356071 Pruned: 943901
# Processing 27 simulations, with pruning on: 3 Complete: 356071 Pruned: 943902
# Processing 26 simulations, with pruning on: 3 Complete: 356071 Pruned: 943903
# Processing 24 simulations, with pruning on: 4 Complete: 414655 Pruned: 1185321
# Processing 32 simulations, with pruning on: 4 Complete: 474388 Pruned: 1425580
# Processing 31 simulations, with pruning on: 4 Complete: 474388 Pruned: 1425581
# Processing 30 simulations, with pruning on: 4 Complete: 474388 Pruned: 1425582
# Processing 29 simulations, with pruning on: 4 Complete: 474388 Pruned: 1425583
# Processing 28 simulations, with pruning on: 4 Complete: 474388 Pruned: 1425584
# Processing 27 simulations, with pruning on: 4 Complete: 474388 Pruned: 1425585
# Processing 26 simulations, with pruning on: 4 Complete: 474388 Pruned: 1425586
# Processing 13 simulations, with pruning on: 5 Complete: 534145 Pruned: 1665842
# Processing 12 simulations, with pruning on: 5 Complete: 534146 Pruned: 1665842
# Processing 31 simulations, with pruning on: 6 Complete: 579960 Pruned: 1920009
# Processing 30 simulations, with pruning on: 6 Complete: 579960 Pruned: 1920010
# Processing 29 simulations, with pruning on: 6 Complete: 579960 Pruned: 1920011
# Processing 28 simulations, with pruning on: 6 Complete: 579960 Pruned: 1920012
# Processing 27 simulations, with pruning on: 6 Complete: 579960 Pruned: 1920013
# Processing 27 simulations, with pruning on: 6 Complete: 624084 Pruned: 2175889
# Processing 26 simulations, with pruning on: 7 Complete: 667858 Pruned: 2432116
# Processing 20 simulations, with pruning on: 7 Complete: 710527 Pruned: 2689453
# Processing 19 simulations, with pruning on: 7 Complete: 710527 Pruned: 2689454
# Processing 18 simulations, with pruning on: 7 Complete: 710527 Pruned: 2689455
# Processing 17 simulations, with pruning on: 7 Complete: 710527 Pruned: 2689456
# Processing 16 simulations, with pruning on: 7 Complete: 710528 Pruned: 2689456
# Processing 24 simulations, with pruning on: 7 Complete: 751999 Pruned: 2947977
# Processing 24 simulations, with pruning on: 7 Complete: 791149 Pruned: 3208827
# Completed game for blueprint 9
# Processing 41 simulations, with pruning on: 0 Complete: 36328 Pruned: 63631
# Processing 40 simulations, with pruning on: 0 Complete: 36329 Pruned: 63631
# Processing 39 simulations, with pruning on: 0 Complete: 36329 Pruned: 63632
# Processing 38 simulations, with pruning on: 0 Complete: 36329 Pruned: 63633
# Processing 37 simulations, with pruning on: 0 Complete: 36329 Pruned: 63634
# Processing 35 simulations, with pruning on: 0 Complete: 151871 Pruned: 248094
# Processing 34 simulations, with pruning on: 0 Complete: 151872 Pruned: 248094
# Processing 33 simulations, with pruning on: 0 Complete: 151873 Pruned: 248094
# Processing 32 simulations, with pruning on: 0 Complete: 151873 Pruned: 248095
# Processing 31 simulations, with pruning on: 0 Complete: 151873 Pruned: 248096
# Processing 31 simulations, with pruning on: 0 Complete: 268106 Pruned: 431863
# Processing 30 simulations, with pruning on: 0 Complete: 268106 Pruned: 431864
# Processing 29 simulations, with pruning on: 0 Complete: 268106 Pruned: 431865
# Processing 28 simulations, with pruning on: 0 Complete: 268106 Pruned: 431866
# Processing 27 simulations, with pruning on: 0 Complete: 268107 Pruned: 431866
# Processing 42 simulations, with pruning on: 0 Complete: 386033 Pruned: 613925
# Processing 41 simulations, with pruning on: 0 Complete: 386034 Pruned: 613925
# Processing 40 simulations, with pruning on: 0 Complete: 386034 Pruned: 613926
# Processing 39 simulations, with pruning on: 0 Complete: 386034 Pruned: 613927
# Processing 38 simulations, with pruning on: 0 Complete: 386034 Pruned: 613928
# Processing 21 simulations, with pruning on: 0 Complete: 497869 Pruned: 802110
# Processing 20 simulations, with pruning on: 0 Complete: 497869 Pruned: 802111
# Processing 19 simulations, with pruning on: 0 Complete: 497870 Pruned: 802111
# Processing 18 simulations, with pruning on: 0 Complete: 497871 Pruned: 802111
# Processing 17 simulations, with pruning on: 0 Complete: 497871 Pruned: 802112
# Processing 24 simulations, with pruning on: 0 Complete: 611322 Pruned: 988654
# Processing 23 simulations, with pruning on: 0 Complete: 611322 Pruned: 988655
# Processing 22 simulations, with pruning on: 0 Complete: 611322 Pruned: 988656
# Processing 21 simulations, with pruning on: 0 Complete: 611322 Pruned: 988657
# Processing 20 simulations, with pruning on: 0 Complete: 611323 Pruned: 988657
# Processing 26 simulations, with pruning on: 0 Complete: 723081 Pruned: 1176893
# Processing 25 simulations, with pruning on: 0 Complete: 723081 Pruned: 1176894
# Processing 24 simulations, with pruning on: 0 Complete: 723081 Pruned: 1176895
# Processing 23 simulations, with pruning on: 0 Complete: 723082 Pruned: 1176895
# Processing 22 simulations, with pruning on: 0 Complete: 723082 Pruned: 1176896
# Processing 24 simulations, with pruning on: 0 Complete: 831593 Pruned: 1368383
# Processing 23 simulations, with pruning on: 0 Complete: 831594 Pruned: 1368383
# Processing 22 simulations, with pruning on: 0 Complete: 831595 Pruned: 1368383
# Processing 21 simulations, with pruning on: 0 Complete: 831595 Pruned: 1368384
# Processing 20 simulations, with pruning on: 0 Complete: 831595 Pruned: 1368385
# Processing 27 simulations, with pruning on: 0 Complete: 942778 Pruned: 1557195
# Processing 26 simulations, with pruning on: 0 Complete: 942779 Pruned: 1557195
# Processing 26 simulations, with pruning on: 0 Complete: 1058730 Pruned: 1741244
# Processing 25 simulations, with pruning on: 0 Complete: 1058731 Pruned: 1741244
# Processing 24 simulations, with pruning on: 0 Complete: 1058731 Pruned: 1741245
# Processing 23 simulations, with pruning on: 0 Complete: 1058731 Pruned: 1741246
# Processing 22 simulations, with pruning on: 0 Complete: 1058732 Pruned: 1741246
# Processing 30 simulations, with pruning on: 0 Complete: 1168309 Pruned: 1931661
# Processing 29 simulations, with pruning on: 0 Complete: 1168310 Pruned: 1931661
# Processing 28 simulations, with pruning on: 0 Complete: 1168310 Pruned: 1931662
# Processing 27 simulations, with pruning on: 0 Complete: 1168310 Pruned: 1931663
# Processing 26 simulations, with pruning on: 0 Complete: 1168311 Pruned: 1931663
# Processing 29 simulations, with pruning on: 0 Complete: 1281142 Pruned: 2118829
# Processing 28 simulations, with pruning on: 0 Complete: 1281143 Pruned: 2118829
# Processing 31 simulations, with pruning on: 0 Complete: 1393978 Pruned: 2305991
# Processing 33 simulations, with pruning on: 0 Complete: 1507949 Pruned: 2492018
# Processing 32 simulations, with pruning on: 0 Complete: 1507949 Pruned: 2492019
# Processing 31 simulations, with pruning on: 0 Complete: 1507950 Pruned: 2492019
# Processing 30 simulations, with pruning on: 0 Complete: 1507950 Pruned: 2492020
# Processing 29 simulations, with pruning on: 0 Complete: 1507950 Pruned: 2492021
# Processing 26 simulations, with pruning on: 0 Complete: 1622186 Pruned: 2677788
# Processing 25 simulations, with pruning on: 0 Complete: 1622186 Pruned: 2677789
# Processing 24 simulations, with pruning on: 0 Complete: 1622186 Pruned: 2677790
# Processing 23 simulations, with pruning on: 0 Complete: 1622186 Pruned: 2677791
# Processing 22 simulations, with pruning on: 0 Complete: 1622187 Pruned: 2677791
# Processing 21 simulations, with pruning on: 0 Complete: 1622188 Pruned: 2677791
# Processing 31 simulations, with pruning on: 0 Complete: 1737035 Pruned: 2862934
# Processing 30 simulations, with pruning on: 0 Complete: 1737036 Pruned: 2862934
# Processing 29 simulations, with pruning on: 0 Complete: 1737036 Pruned: 2862935
# Processing 28 simulations, with pruning on: 0 Complete: 1737036 Pruned: 2862936
# Processing 27 simulations, with pruning on: 0 Complete: 1737036 Pruned: 2862937
# Processing 23 simulations, with pruning on: 0 Complete: 1853029 Pruned: 3046948
# Processing 22 simulations, with pruning on: 0 Complete: 1853029 Pruned: 3046949
# Processing 21 simulations, with pruning on: 0 Complete: 1853030 Pruned: 3046949
# Processing 20 simulations, with pruning on: 0 Complete: 1853030 Pruned: 3046950
# Processing 19 simulations, with pruning on: 0 Complete: 1853031 Pruned: 3046950
# Processing 31 simulations, with pruning on: 0 Complete: 1965689 Pruned: 3234280
# Processing 30 simulations, with pruning on: 0 Complete: 1965689 Pruned: 3234281
# Processing 29 simulations, with pruning on: 0 Complete: 1965689 Pruned: 3234282
# Processing 28 simulations, with pruning on: 0 Complete: 1965690 Pruned: 3234282
# Processing 27 simulations, with pruning on: 0 Complete: 1965690 Pruned: 3234283
# Processing 30 simulations, with pruning on: 0 Complete: 2077662 Pruned: 3422308
# Processing 29 simulations, with pruning on: 0 Complete: 2077662 Pruned: 3422309
# Processing 28 simulations, with pruning on: 0 Complete: 2077662 Pruned: 3422310
# Processing 27 simulations, with pruning on: 0 Complete: 2077662 Pruned: 3422311
# Processing 26 simulations, with pruning on: 0 Complete: 2077663 Pruned: 3422311
# Processing 25 simulations, with pruning on: 0 Complete: 2077664 Pruned: 3422311
# Processing 29 simulations, with pruning on: 0 Complete: 2188792 Pruned: 3611179
# Processing 28 simulations, with pruning on: 0 Complete: 2188792 Pruned: 3611180
# Processing 27 simulations, with pruning on: 0 Complete: 2188792 Pruned: 3611181
# Processing 26 simulations, with pruning on: 0 Complete: 2188792 Pruned: 3611182
# Processing 25 simulations, with pruning on: 0 Complete: 2188793 Pruned: 3611182
# Processing 24 simulations, with pruning on: 0 Complete: 2188794 Pruned: 3611182
# Processing 30 simulations, with pruning on: 0 Complete: 2296570 Pruned: 3803400
# Processing 43 simulations, with pruning on: 0 Complete: 2410825 Pruned: 3989132
# Processing 42 simulations, with pruning on: 0 Complete: 2410825 Pruned: 3989133
# Processing 41 simulations, with pruning on: 0 Complete: 2410826 Pruned: 3989133
# Processing 40 simulations, with pruning on: 0 Complete: 2410826 Pruned: 3989134
# Processing 39 simulations, with pruning on: 0 Complete: 2410826 Pruned: 3989135
# Processing 38 simulations, with pruning on: 0 Complete: 2410827 Pruned: 3989135
# Processing 35 simulations, with pruning on: 0 Complete: 2526883 Pruned: 4173082
# Processing 34 simulations, with pruning on: 0 Complete: 2526883 Pruned: 4173083
# Processing 33 simulations, with pruning on: 0 Complete: 2526883 Pruned: 4173084
# Processing 32 simulations, with pruning on: 0 Complete: 2526884 Pruned: 4173084
# Processing 31 simulations, with pruning on: 0 Complete: 2526884 Pruned: 4173085
# Processing 32 simulations, with pruning on: 0 Complete: 2641653 Pruned: 4358315
# Processing 31 simulations, with pruning on: 0 Complete: 2641653 Pruned: 4358316
# Processing 30 simulations, with pruning on: 0 Complete: 2641653 Pruned: 4358317
# Processing 29 simulations, with pruning on: 0 Complete: 2641654 Pruned: 4358317
# Processing 28 simulations, with pruning on: 0 Complete: 2641654 Pruned: 4358318
# Processing 31 simulations, with pruning on: 0 Complete: 2748689 Pruned: 4551280
# Processing 30 simulations, with pruning on: 0 Complete: 2748689 Pruned: 4551281
# Processing 29 simulations, with pruning on: 0 Complete: 2748689 Pruned: 4551282
# Processing 28 simulations, with pruning on: 0 Complete: 2748690 Pruned: 4551282
# Processing 27 simulations, with pruning on: 0 Complete: 2748690 Pruned: 4551283
# Processing 26 simulations, with pruning on: 0 Complete: 2748691 Pruned: 4551283
# Processing 32 simulations, with pruning on: 0 Complete: 2862418 Pruned: 4737550
# Processing 31 simulations, with pruning on: 0 Complete: 2862419 Pruned: 4737550
# Processing 32 simulations, with pruning on: 0 Complete: 2969800 Pruned: 4930168
# Processing 31 simulations, with pruning on: 0 Complete: 2969800 Pruned: 4930169
# Processing 30 simulations, with pruning on: 0 Complete: 2969801 Pruned: 4930169
# Processing 29 simulations, with pruning on: 0 Complete: 2969801 Pruned: 4930170
# Processing 28 simulations, with pruning on: 0 Complete: 2969801 Pruned: 4930171
# Processing 27 simulations, with pruning on: 0 Complete: 2969802 Pruned: 4930171
# Processing 38 simulations, with pruning on: 0 Complete: 3080881 Pruned: 5119081
# Processing 37 simulations, with pruning on: 0 Complete: 3080882 Pruned: 5119081
# Processing 36 simulations, with pruning on: 0 Complete: 3080882 Pruned: 5119082
# Processing 35 simulations, with pruning on: 0 Complete: 3080882 Pruned: 5119083
# Processing 34 simulations, with pruning on: 0 Complete: 3080882 Pruned: 5119084
# Processing 36 simulations, with pruning on: 0 Complete: 3187803 Pruned: 5312161
# Processing 35 simulations, with pruning on: 0 Complete: 3187804 Pruned: 5312161
# Processing 34 simulations, with pruning on: 0 Complete: 3187804 Pruned: 5312162
# Processing 33 simulations, with pruning on: 0 Complete: 3187804 Pruned: 5312163
# Processing 32 simulations, with pruning on: 0 Complete: 3187804 Pruned: 5312164
# Processing 37 simulations, with pruning on: 0 Complete: 3299601 Pruned: 5500362
# Processing 36 simulations, with pruning on: 0 Complete: 3299601 Pruned: 5500363
# Processing 35 simulations, with pruning on: 0 Complete: 3299601 Pruned: 5500364
# Processing 34 simulations, with pruning on: 0 Complete: 3299602 Pruned: 5500364
# Processing 33 simulations, with pruning on: 0 Complete: 3299602 Pruned: 5500365
# Processing 24 simulations, with pruning on: 0 Complete: 3411699 Pruned: 5688277
# Processing 23 simulations, with pruning on: 0 Complete: 3411700 Pruned: 5688277
# Processing 31 simulations, with pruning on: 0 Complete: 3526318 Pruned: 5873651
# Processing 30 simulations, with pruning on: 0 Complete: 3526318 Pruned: 5873652
# Processing 29 simulations, with pruning on: 0 Complete: 3526318 Pruned: 5873653
# Processing 28 simulations, with pruning on: 0 Complete: 3526318 Pruned: 5873654
# Processing 27 simulations, with pruning on: 0 Complete: 3526319 Pruned: 5873654
# Processing 32 simulations, with pruning on: 0 Complete: 3642898 Pruned: 6057070
# Processing 30 simulations, with pruning on: 0 Complete: 3766201 Pruned: 6233769
# Processing 29 simulations, with pruning on: 0 Complete: 3766201 Pruned: 6233770
# Processing 28 simulations, with pruning on: 0 Complete: 3766202 Pruned: 6233770
# Processing 27 simulations, with pruning on: 0 Complete: 3766203 Pruned: 6233770
# Processing 26 simulations, with pruning on: 0 Complete: 3766203 Pruned: 6233771
# Processing 36 simulations, with pruning on: 0 Complete: 3879335 Pruned: 6420629
# Processing 35 simulations, with pruning on: 0 Complete: 3879336 Pruned: 6420629
# Processing 24 simulations, with pruning on: 0 Complete: 3996540 Pruned: 6603436
# Processing 23 simulations, with pruning on: 0 Complete: 3996541 Pruned: 6603436
# Processing 22 simulations, with pruning on: 0 Complete: 3996541 Pruned: 6603437
# Processing 21 simulations, with pruning on: 0 Complete: 3996541 Pruned: 6603438
# Processing 20 simulations, with pruning on: 0 Complete: 3996542 Pruned: 6603438
# Processing 19 simulations, with pruning on: 0 Complete: 3996543 Pruned: 6603438
# Processing 18 simulations, with pruning on: 0 Complete: 3996544 Pruned: 6603438
# Processing 36 simulations, with pruning on: 0 Complete: 4110162 Pruned: 6789802
# Processing 35 simulations, with pruning on: 0 Complete: 4110163 Pruned: 6789802
# Processing 34 simulations, with pruning on: 0 Complete: 4110163 Pruned: 6789803
# Processing 33 simulations, with pruning on: 0 Complete: 4110163 Pruned: 6789804
# Processing 32 simulations, with pruning on: 0 Complete: 4110163 Pruned: 6789805
# Processing 31 simulations, with pruning on: 0 Complete: 4110164 Pruned: 6789805
# Processing 30 simulations, with pruning on: 0 Complete: 4110164 Pruned: 6789806
# Processing 35 simulations, with pruning on: 0 Complete: 4224260 Pruned: 6975705
# Processing 34 simulations, with pruning on: 0 Complete: 4224261 Pruned: 6975705
# Processing 33 simulations, with pruning on: 0 Complete: 4224261 Pruned: 6975706
# Processing 32 simulations, with pruning on: 0 Complete: 4224261 Pruned: 6975707
# Processing 31 simulations, with pruning on: 0 Complete: 4224261 Pruned: 6975708
# Processing 30 simulations, with pruning on: 0 Complete: 4224262 Pruned: 6975708
# Processing 36 simulations, with pruning on: 0 Complete: 4335734 Pruned: 7164230
# Processing 28 simulations, with pruning on: 0 Complete: 4443672 Pruned: 7356300
# Processing 27 simulations, with pruning on: 0 Complete: 4443672 Pruned: 7356301
# Processing 32 simulations, with pruning on: 0 Complete: 4559106 Pruned: 7540862
# Processing 31 simulations, with pruning on: 0 Complete: 4559107 Pruned: 7540862
# Processing 30 simulations, with pruning on: 0 Complete: 4559107 Pruned: 7540863
# Processing 29 simulations, with pruning on: 0 Complete: 4559108 Pruned: 7540863
# Processing 28 simulations, with pruning on: 0 Complete: 4559108 Pruned: 7540864
# Processing 27 simulations, with pruning on: 0 Complete: 4673790 Pruned: 7726183
# Processing 26 simulations, with pruning on: 0 Complete: 4673790 Pruned: 7726184
# Processing 25 simulations, with pruning on: 0 Complete: 4673791 Pruned: 7726184
# Processing 24 simulations, with pruning on: 0 Complete: 4673791 Pruned: 7726185
# Processing 23 simulations, with pruning on: 0 Complete: 4673791 Pruned: 7726186
# Processing 39 simulations, with pruning on: 0 Complete: 4790648 Pruned: 7909313
# Processing 38 simulations, with pruning on: 0 Complete: 4790648 Pruned: 7909314
# Processing 37 simulations, with pruning on: 0 Complete: 4790649 Pruned: 7909314
# Processing 36 simulations, with pruning on: 0 Complete: 4790649 Pruned: 7909315
# Processing 35 simulations, with pruning on: 0 Complete: 4790649 Pruned: 7909316
# Processing 34 simulations, with pruning on: 0 Complete: 4790650 Pruned: 7909316
# Processing 39 simulations, with pruning on: 0 Complete: 4904025 Pruned: 8095936
# Processing 38 simulations, with pruning on: 0 Complete: 4904026 Pruned: 8095936
# Processing 37 simulations, with pruning on: 0 Complete: 4904026 Pruned: 8095937
# Processing 36 simulations, with pruning on: 0 Complete: 4904027 Pruned: 8095937
# Processing 35 simulations, with pruning on: 0 Complete: 4904027 Pruned: 8095938
# Processing 34 simulations, with pruning on: 0 Complete: 4904028 Pruned: 8095938
# Processing 35 simulations, with pruning on: 0 Complete: 5017766 Pruned: 8282199
# Processing 39 simulations, with pruning on: 0 Complete: 5123849 Pruned: 8476112
# Processing 38 simulations, with pruning on: 0 Complete: 5123850 Pruned: 8476112
# Processing 37 simulations, with pruning on: 0 Complete: 5123850 Pruned: 8476113
# Processing 36 simulations, with pruning on: 0 Complete: 5123850 Pruned: 8476114
# Processing 35 simulations, with pruning on: 0 Complete: 5123850 Pruned: 8476115
# Processing 27 simulations, with pruning on: 0 Complete: 5235522 Pruned: 8664451
# Processing 34 simulations, with pruning on: 0 Complete: 5350885 Pruned: 8849081
# Processing 33 simulations, with pruning on: 0 Complete: 5350885 Pruned: 8849082
# Processing 32 simulations, with pruning on: 0 Complete: 5350885 Pruned: 8849083
# Processing 31 simulations, with pruning on: 0 Complete: 5350886 Pruned: 8849083
# Processing 30 simulations, with pruning on: 0 Complete: 5350886 Pruned: 8849084
# Processing 29 simulations, with pruning on: 0 Complete: 5350887 Pruned: 8849084
# Processing 37 simulations, with pruning on: 0 Complete: 5460581 Pruned: 9039382
# Processing 36 simulations, with pruning on: 0 Complete: 5460581 Pruned: 9039383
# Processing 35 simulations, with pruning on: 0 Complete: 5460581 Pruned: 9039384
# Processing 34 simulations, with pruning on: 0 Complete: 5460581 Pruned: 9039385
# Processing 33 simulations, with pruning on: 0 Complete: 5460582 Pruned: 9039385
# Processing 32 simulations, with pruning on: 0 Complete: 5460583 Pruned: 9039385
# Processing 33 simulations, with pruning on: 0 Complete: 5567527 Pruned: 9232440
# Processing 32 simulations, with pruning on: 0 Complete: 5567527 Pruned: 9232441
# Processing 31 simulations, with pruning on: 0 Complete: 5567527 Pruned: 9232442
# Processing 30 simulations, with pruning on: 0 Complete: 5567528 Pruned: 9232442
# Processing 29 simulations, with pruning on: 0 Complete: 5567528 Pruned: 9232443
# Processing 35 simulations, with pruning on: 0 Complete: 5674068 Pruned: 9425897
# Processing 34 simulations, with pruning on: 0 Complete: 5674069 Pruned: 9425897
# Processing 33 simulations, with pruning on: 0 Complete: 5674069 Pruned: 9425898
# Processing 32 simulations, with pruning on: 0 Complete: 5674069 Pruned: 9425899
# Processing 31 simulations, with pruning on: 0 Complete: 5674069 Pruned: 9425900
# Processing 32 simulations, with pruning on: 0 Complete: 5783079 Pruned: 9616889
# Processing 31 simulations, with pruning on: 0 Complete: 5783080 Pruned: 9616889
# Processing 30 simulations, with pruning on: 0 Complete: 5783081 Pruned: 9616889
# Processing 29 simulations, with pruning on: 0 Complete: 5783081 Pruned: 9616890
# Processing 28 simulations, with pruning on: 0 Complete: 5783081 Pruned: 9616891
# Processing 34 simulations, with pruning on: 0 Complete: 5887693 Pruned: 9812273
# Processing 30 simulations, with pruning on: 0 Complete: 5989797 Pruned: 10010173
# Processing 30 simulations, with pruning on: 0 Complete: 6091687 Pruned: 10208283
# Processing 39 simulations, with pruning on: 0 Complete: 6202422 Pruned: 10397539
# Processing 38 simulations, with pruning on: 0 Complete: 6202422 Pruned: 10397540
# Processing 37 simulations, with pruning on: 0 Complete: 6202422 Pruned: 10397541
# Processing 36 simulations, with pruning on: 0 Complete: 6202422 Pruned: 10397542
# Processing 35 simulations, with pruning on: 0 Complete: 6202423 Pruned: 10397542
# Processing 26 simulations, with pruning on: 0 Complete: 6311809 Pruned: 10588165
# Processing 31 simulations, with pruning on: 0 Complete: 6422141 Pruned: 10777828
# Processing 32 simulations, with pruning on: 0 Complete: 6539127 Pruned: 10960841
# Processing 26 simulations, with pruning on: 0 Complete: 6654899 Pruned: 11145075
# Processing 25 simulations, with pruning on: 0 Complete: 6654899 Pruned: 11145076
# Processing 24 simulations, with pruning on: 0 Complete: 6654899 Pruned: 11145077
# Processing 23 simulations, with pruning on: 0 Complete: 6654899 Pruned: 11145078
# Processing 22 simulations, with pruning on: 0 Complete: 6654900 Pruned: 11145078
# Processing 21 simulations, with pruning on: 0 Complete: 6654901 Pruned: 11145078
# Processing 25 simulations, with pruning on: 0 Complete: 6767803 Pruned: 11332172
# Processing 24 simulations, with pruning on: 0 Complete: 6767803 Pruned: 11332173
# Processing 23 simulations, with pruning on: 0 Complete: 6767803 Pruned: 11332174
# Processing 22 simulations, with pruning on: 0 Complete: 6767803 Pruned: 11332175
# Processing 21 simulations, with pruning on: 0 Complete: 6767804 Pruned: 11332175
# Processing 30 simulations, with pruning on: 0 Complete: 6889042 Pruned: 11510928
# Processing 36 simulations, with pruning on: 0 Complete: 7007936 Pruned: 11692028
# Processing 35 simulations, with pruning on: 0 Complete: 7007937 Pruned: 11692028
# Processing 34 simulations, with pruning on: 0 Complete: 7007937 Pruned: 11692029
# Processing 33 simulations, with pruning on: 0 Complete: 7007937 Pruned: 11692030
# Processing 32 simulations, with pruning on: 0 Complete: 7007937 Pruned: 11692031
# Processing 25 simulations, with pruning on: 0 Complete: 7126919 Pruned: 11873056
# Processing 24 simulations, with pruning on: 0 Complete: 7126919 Pruned: 11873057
# Processing 23 simulations, with pruning on: 0 Complete: 7126919 Pruned: 11873058
# Processing 22 simulations, with pruning on: 0 Complete: 7126919 Pruned: 11873059
# Processing 21 simulations, with pruning on: 0 Complete: 7126920 Pruned: 11873059
# Completed game for blueprint 10
# Processing 25 simulations, with pruning on: 2 Complete: 27511 Pruned: 72464
# Processing 24 simulations, with pruning on: 2 Complete: 27511 Pruned: 72465
# Processing 23 simulations, with pruning on: 2 Complete: 27511 Pruned: 72466
# Processing 27 simulations, with pruning on: 2 Complete: 109447 Pruned: 290526
# Processing 26 simulations, with pruning on: 2 Complete: 109447 Pruned: 290527
# Processing 25 simulations, with pruning on: 2 Complete: 109447 Pruned: 290528
# Processing 24 simulations, with pruning on: 2 Complete: 109447 Pruned: 290529
# Processing 23 simulations, with pruning on: 2 Complete: 109448 Pruned: 290529
# Processing 25 simulations, with pruning on: 2 Complete: 181658 Pruned: 518317
# Processing 36 simulations, with pruning on: 2 Complete: 263090 Pruned: 736874
# Processing 35 simulations, with pruning on: 2 Complete: 263090 Pruned: 736875
# Processing 34 simulations, with pruning on: 2 Complete: 263090 Pruned: 736876
# Processing 33 simulations, with pruning on: 2 Complete: 263090 Pruned: 736877
# Processing 32 simulations, with pruning on: 2 Complete: 263091 Pruned: 736877
# Processing 31 simulations, with pruning on: 2 Complete: 340644 Pruned: 959325
# Processing 30 simulations, with pruning on: 2 Complete: 340644 Pruned: 959326
# Processing 29 simulations, with pruning on: 2 Complete: 340644 Pruned: 959327
# Processing 28 simulations, with pruning on: 2 Complete: 340644 Pruned: 959328
# Processing 27 simulations, with pruning on: 2 Complete: 340644 Pruned: 959329
# Processing 26 simulations, with pruning on: 2 Complete: 425994 Pruned: 1173980
# Processing 25 simulations, with pruning on: 2 Complete: 425994 Pruned: 1173981
# Processing 24 simulations, with pruning on: 2 Complete: 425994 Pruned: 1173982
# Processing 23 simulations, with pruning on: 2 Complete: 425995 Pruned: 1173982
# Processing 22 simulations, with pruning on: 2 Complete: 425995 Pruned: 1173983
# Processing 27 simulations, with pruning on: 2 Complete: 509504 Pruned: 1390469
# Processing 26 simulations, with pruning on: 2 Complete: 509504 Pruned: 1390470
# Processing 25 simulations, with pruning on: 2 Complete: 509504 Pruned: 1390471
# Processing 24 simulations, with pruning on: 2 Complete: 509504 Pruned: 1390472
# Processing 23 simulations, with pruning on: 2 Complete: 509505 Pruned: 1390472
# Processing 22 simulations, with pruning on: 2 Complete: 509506 Pruned: 1390472
# Processing 21 simulations, with pruning on: 2 Complete: 509507 Pruned: 1390472
# Completed game for blueprint 11
# Processing 30 simulations, with pruning on: 1 Complete: 26414 Pruned: 73556
# Processing 42 simulations, with pruning on: 2 Complete: 87763 Pruned: 312195
# Processing 41 simulations, with pruning on: 2 Complete: 87763 Pruned: 312196
# Processing 40 simulations, with pruning on: 2 Complete: 87763 Pruned: 312197
# Processing 39 simulations, with pruning on: 2 Complete: 87763 Pruned: 312198
# Processing 38 simulations, with pruning on: 2 Complete: 87763 Pruned: 312199
# Processing 37 simulations, with pruning on: 2 Complete: 87763 Pruned: 312200
# Processing 36 simulations, with pruning on: 2 Complete: 140564 Pruned: 559400
# Processing 35 simulations, with pruning on: 2 Complete: 140564 Pruned: 559401
# Processing 34 simulations, with pruning on: 2 Complete: 140564 Pruned: 559402
# Processing 33 simulations, with pruning on: 2 Complete: 140564 Pruned: 559403
# Processing 32 simulations, with pruning on: 2 Complete: 140564 Pruned: 559404
# Processing 30 simulations, with pruning on: 3 Complete: 200472 Pruned: 799498
# Processing 29 simulations, with pruning on: 3 Complete: 200472 Pruned: 799499
# Processing 28 simulations, with pruning on: 3 Complete: 200472 Pruned: 799500
# Processing 27 simulations, with pruning on: 3 Complete: 200472 Pruned: 799501
# Processing 26 simulations, with pruning on: 3 Complete: 200472 Pruned: 799502
# Processing 25 simulations, with pruning on: 3 Complete: 200473 Pruned: 799502
# Processing 24 simulations, with pruning on: 3 Complete: 200474 Pruned: 799502
# Processing 35 simulations, with pruning on: 3 Complete: 257622 Pruned: 1042343
# Processing 34 simulations, with pruning on: 3 Complete: 257622 Pruned: 1042344
# Processing 33 simulations, with pruning on: 3 Complete: 257623 Pruned: 1042344
# Processing 32 simulations, with pruning on: 3 Complete: 257623 Pruned: 1042345
# Processing 31 simulations, with pruning on: 3 Complete: 257623 Pruned: 1042346
# Processing 30 simulations, with pruning on: 3 Complete: 257624 Pruned: 1042346
# Processing 30 simulations, with pruning on: 3 Complete: 324315 Pruned: 1275655
# Processing 29 simulations, with pruning on: 3 Complete: 324316 Pruned: 1275655
# Processing 28 simulations, with pruning on: 3 Complete: 324316 Pruned: 1275656
# Processing 27 simulations, with pruning on: 3 Complete: 324316 Pruned: 1275657
# Processing 26 simulations, with pruning on: 3 Complete: 324316 Pruned: 1275658
# Processing 35 simulations, with pruning on: 3 Complete: 393156 Pruned: 1506809
# Processing 34 simulations, with pruning on: 3 Complete: 393156 Pruned: 1506810
# Processing 33 simulations, with pruning on: 3 Complete: 393156 Pruned: 1506811
# Processing 32 simulations, with pruning on: 3 Complete: 393156 Pruned: 1506812
# Processing 31 simulations, with pruning on: 3 Complete: 393156 Pruned: 1506813
# Processing 32 simulations, with pruning on: 3 Complete: 448827 Pruned: 1751141
# Processing 30 simulations, with pruning on: 3 Complete: 520740 Pruned: 1979230
# Processing 29 simulations, with pruning on: 3 Complete: 520740 Pruned: 1979231
# Processing 28 simulations, with pruning on: 3 Complete: 520740 Pruned: 1979232
# Processing 27 simulations, with pruning on: 3 Complete: 520740 Pruned: 1979233
# ...
# Processing 26 simulations, with pruning on: 0 Complete: 3454656 Pruned: 5645318
# Processing 25 simulations, with pruning on: 0 Complete: 3454657 Pruned: 5645318
# Processing 41 simulations, with pruning on: 0 Complete: 3567776 Pruned: 5832183
# Processing 40 simulations, with pruning on: 0 Complete: 3567776 Pruned: 5832184
# Processing 39 simulations, with pruning on: 0 Complete: 3567777 Pruned: 5832184
# Processing 38 simulations, with pruning on: 0 Complete: 3567777 Pruned: 5832185
# Processing 37 simulations, with pruning on: 0 Complete: 3567777 Pruned: 5832186
# Processing 39 simulations, with pruning on: 0 Complete: 3682041 Pruned: 6017920
# Processing 38 simulations, with pruning on: 0 Complete: 3682041 Pruned: 6017921
# Processing 37 simulations, with pruning on: 0 Complete: 3682041 Pruned: 6017922
# Processing 36 simulations, with pruning on: 0 Complete: 3682041 Pruned: 6017923
# Processing 35 simulations, with pruning on: 0 Complete: 3682042 Pruned: 6017923
# Processing 34 simulations, with pruning on: 0 Complete: 3682043 Pruned: 6017923
# Processing 29 simulations, with pruning on: 0 Complete: 3794152 Pruned: 6205819
# Processing 36 simulations, with pruning on: 0 Complete: 3905031 Pruned: 6394933
# Processing 35 simulations, with pruning on: 0 Complete: 3905031 Pruned: 6394934
# Processing 34 simulations, with pruning on: 0 Complete: 3905032 Pruned: 6394934
# Processing 33 simulations, with pruning on: 0 Complete: 3905032 Pruned: 6394935
# Processing 32 simulations, with pruning on: 0 Complete: 3905032 Pruned: 6394936
# Processing 36 simulations, with pruning on: 0 Complete: 4018334 Pruned: 6581630
# Processing 30 simulations, with pruning on: 0 Complete: 4131785 Pruned: 6768185
# Processing 29 simulations, with pruning on: 0 Complete: 4237393 Pruned: 6962578
# Processing 28 simulations, with pruning on: 0 Complete: 4237394 Pruned: 6962578
# Processing 36 simulations, with pruning on: 0 Complete: 4351621 Pruned: 7148343
# Processing 35 simulations, with pruning on: 0 Complete: 4351622 Pruned: 7148343
# Processing 39 simulations, with pruning on: 0 Complete: 4467918 Pruned: 7332043
# Processing 38 simulations, with pruning on: 0 Complete: 4467919 Pruned: 7332043
# Processing 37 simulations, with pruning on: 0 Complete: 4467919 Pruned: 7332044
# Processing 36 simulations, with pruning on: 0 Complete: 4467919 Pruned: 7332045
# Processing 35 simulations, with pruning on: 0 Complete: 4467919 Pruned: 7332046
# Processing 29 simulations, with pruning on: 0 Complete: 4573675 Pruned: 7526296
# Processing 38 simulations, with pruning on: 0 Complete: 4680898 Pruned: 7719064
# Processing 37 simulations, with pruning on: 0 Complete: 4680898 Pruned: 7719065
# Processing 36 simulations, with pruning on: 0 Complete: 4680898 Pruned: 7719066
# Processing 35 simulations, with pruning on: 0 Complete: 4680899 Pruned: 7719066
# Processing 34 simulations, with pruning on: 0 Complete: 4680899 Pruned: 7719067
# Processing 33 simulations, with pruning on: 0 Complete: 4680900 Pruned: 7719067
# Processing 24 simulations, with pruning on: 1 Complete: 4769448 Pruned: 7930528
# Processing 23 simulations, with pruning on: 1 Complete: 4769448 Pruned: 7930529
# Processing 22 simulations, with pruning on: 1 Complete: 4769448 Pruned: 7930530
# Processing 21 simulations, with pruning on: 1 Complete: 4769449 Pruned: 7930530
# Processing 20 simulations, with pruning on: 1 Complete: 4769449 Pruned: 7930531
# Processing 39 simulations, with pruning on: 1 Complete: 4874178 Pruned: 8125783
# Processing 38 simulations, with pruning on: 1 Complete: 4874179 Pruned: 8125783
# Processing 37 simulations, with pruning on: 1 Complete: 4874179 Pruned: 8125784
# Processing 36 simulations, with pruning on: 1 Complete: 4874179 Pruned: 8125785
# Processing 35 simulations, with pruning on: 1 Complete: 4874179 Pruned: 8125786
# Processing 34 simulations, with pruning on: 1 Complete: 4874180 Pruned: 8125786
# Processing 34 simulations, with pruning on: 1 Complete: 4985365 Pruned: 8314601
# Processing 33 simulations, with pruning on: 1 Complete: 4985365 Pruned: 8314602
# Processing 32 simulations, with pruning on: 1 Complete: 4985365 Pruned: 8314603
# Processing 31 simulations, with pruning on: 1 Complete: 4985365 Pruned: 8314604
# Processing 30 simulations, with pruning on: 1 Complete: 4985366 Pruned: 8314604
# Processing 31 simulations, with pruning on: 1 Complete: 5095745 Pruned: 8504224
# Processing 30 simulations, with pruning on: 1 Complete: 5095745 Pruned: 8504225
# Processing 29 simulations, with pruning on: 1 Complete: 5095745 Pruned: 8504226
# Processing 28 simulations, with pruning on: 1 Complete: 5095746 Pruned: 8504226
# Processing 27 simulations, with pruning on: 1 Complete: 5095746 Pruned: 8504227
# Processing 27 simulations, with pruning on: 1 Complete: 5201587 Pruned: 8698386
# Processing 26 simulations, with pruning on: 1 Complete: 5201587 Pruned: 8698387
# Processing 25 simulations, with pruning on: 1 Complete: 5201587 Pruned: 8698388
# Processing 24 simulations, with pruning on: 1 Complete: 5201587 Pruned: 8698389
# Processing 23 simulations, with pruning on: 1 Complete: 5201588 Pruned: 8698389
# Processing 22 simulations, with pruning on: 1 Complete: 5312458 Pruned: 8887520
# Processing 21 simulations, with pruning on: 1 Complete: 5312458 Pruned: 8887521
# Processing 20 simulations, with pruning on: 1 Complete: 5312459 Pruned: 8887521
# Processing 19 simulations, with pruning on: 1 Complete: 5312459 Pruned: 8887522
# Processing 18 simulations, with pruning on: 1 Complete: 5312459 Pruned: 8887523
# Completed game for blueprint 26
# Processing 29 simulations, with pruning on: 0 Complete: 37548 Pruned: 62423
# Processing 34 simulations, with pruning on: 0 Complete: 153329 Pruned: 246637
# Processing 33 simulations, with pruning on: 0 Complete: 153329 Pruned: 246638
# Processing 32 simulations, with pruning on: 0 Complete: 153329 Pruned: 246639
# Processing 31 simulations, with pruning on: 0 Complete: 153329 Pruned: 246640
# Processing 30 simulations, with pruning on: 0 Complete: 153330 Pruned: 246640
# Processing 32 simulations, with pruning on: 0 Complete: 270240 Pruned: 429728
# Processing 31 simulations, with pruning on: 0 Complete: 270241 Pruned: 429728
# Processing 30 simulations, with pruning on: 0 Complete: 270241 Pruned: 429729
# Processing 29 simulations, with pruning on: 0 Complete: 270241 Pruned: 429730
# Processing 28 simulations, with pruning on: 0 Complete: 270241 Pruned: 429731
# Processing 31 simulations, with pruning on: 0 Complete: 386486 Pruned: 613483
# Processing 30 simulations, with pruning on: 0 Complete: 386486 Pruned: 613484
# Processing 29 simulations, with pruning on: 0 Complete: 386487 Pruned: 613484
# Processing 28 simulations, with pruning on: 0 Complete: 386487 Pruned: 613485
# Processing 27 simulations, with pruning on: 0 Complete: 386487 Pruned: 613486
# Processing 30 simulations, with pruning on: 0 Complete: 498269 Pruned: 801701
# Processing 29 simulations, with pruning on: 0 Complete: 498269 Pruned: 801702
# Processing 28 simulations, with pruning on: 0 Complete: 498270 Pruned: 801702
# Processing 27 simulations, with pruning on: 0 Complete: 498270 Pruned: 801703
# Processing 26 simulations, with pruning on: 0 Complete: 498270 Pruned: 801704
# Processing 25 simulations, with pruning on: 0 Complete: 498271 Pruned: 801704
# Processing 28 simulations, with pruning on: 0 Complete: 613343 Pruned: 986629
# Processing 27 simulations, with pruning on: 0 Complete: 613343 Pruned: 986630
# Processing 26 simulations, with pruning on: 0 Complete: 613344 Pruned: 986630
# Processing 25 simulations, with pruning on: 0 Complete: 613344 Pruned: 986631
# Processing 24 simulations, with pruning on: 0 Complete: 613344 Pruned: 986632
# Processing 30 simulations, with pruning on: 0 Complete: 730115 Pruned: 1169855
# Processing 29 simulations, with pruning on: 0 Complete: 730116 Pruned: 1169855
# Processing 28 simulations, with pruning on: 0 Complete: 730116 Pruned: 1169856
# Processing 27 simulations, with pruning on: 0 Complete: 730116 Pruned: 1169857
# Processing 26 simulations, with pruning on: 0 Complete: 730117 Pruned: 1169857
# Processing 38 simulations, with pruning on: 0 Complete: 852732 Pruned: 1347230
# Processing 37 simulations, with pruning on: 0 Complete: 852733 Pruned: 1347230
# Processing 36 simulations, with pruning on: 0 Complete: 852733 Pruned: 1347231
# Processing 35 simulations, with pruning on: 0 Complete: 852733 Pruned: 1347232
# Processing 34 simulations, with pruning on: 0 Complete: 852733 Pruned: 1347233
# Processing 33 simulations, with pruning on: 0 Complete: 852734 Pruned: 1347233
# Processing 33 simulations, with pruning on: 0 Complete: 966259 Pruned: 1533708
# Processing 32 simulations, with pruning on: 0 Complete: 966259 Pruned: 1533709
# Processing 31 simulations, with pruning on: 0 Complete: 966260 Pruned: 1533709
# Processing 30 simulations, with pruning on: 0 Complete: 966260 Pruned: 1533710
# Processing 29 simulations, with pruning on: 0 Complete: 966260 Pruned: 1533711
# Processing 24 simulations, with pruning on: 0 Complete: 1080401 Pruned: 1719575
# Processing 30 simulations, with pruning on: 0 Complete: 1195015 Pruned: 1904955
# Processing 33 simulations, with pruning on: 0 Complete: 1306438 Pruned: 2093529
# Processing 32 simulations, with pruning on: 0 Complete: 1306439 Pruned: 2093529
# Processing 31 simulations, with pruning on: 0 Complete: 1306439 Pruned: 2093530
# Processing 30 simulations, with pruning on: 0 Complete: 1306439 Pruned: 2093531
# Processing 29 simulations, with pruning on: 0 Complete: 1306439 Pruned: 2093532
# Processing 17 simulations, with pruning on: 0 Complete: 1425354 Pruned: 2274629
# Completed game for blueprint 27
# Processing 31 simulations, with pruning on: 0 Complete: 39766 Pruned: 60203
# Processing 30 simulations, with pruning on: 0 Complete: 39766 Pruned: 60204
# Processing 29 simulations, with pruning on: 0 Complete: 39766 Pruned: 60205
# Processing 28 simulations, with pruning on: 0 Complete: 39766 Pruned: 60206
# Processing 27 simulations, with pruning on: 0 Complete: 39767 Pruned: 60206
# Processing 24 simulations, with pruning on: 0 Complete: 161322 Pruned: 238654
# Processing 23 simulations, with pruning on: 0 Complete: 161322 Pruned: 238655
# Processing 22 simulations, with pruning on: 0 Complete: 161322 Pruned: 238656
# Processing 21 simulations, with pruning on: 0 Complete: 161323 Pruned: 238656
# Processing 20 simulations, with pruning on: 0 Complete: 161323 Pruned: 238657
# Processing 19 simulations, with pruning on: 0 Complete: 161324 Pruned: 238657
# Completed game for blueprint 28
# Processing 30 simulations, with pruning on: 3 Complete: 17775 Pruned: 82195
# Processing 38 simulations, with pruning on: 3 Complete: 71143 Pruned: 328819
# Processing 37 simulations, with pruning on: 3 Complete: 71144 Pruned: 328819
# Processing 32 simulations, with pruning on: 5 Complete: 118954 Pruned: 581014
# Processing 31 simulations, with pruning on: 5 Complete: 118954 Pruned: 581015
# Processing 30 simulations, with pruning on: 5 Complete: 118954 Pruned: 581016
# Processing 29 simulations, with pruning on: 5 Complete: 118954 Pruned: 581017
# Processing 28 simulations, with pruning on: 5 Complete: 118954 Pruned: 581018
# Processing 27 simulations, with pruning on: 5 Complete: 118954 Pruned: 581019
# Processing 30 simulations, with pruning on: 5 Complete: 176624 Pruned: 823346
# Processing 29 simulations, with pruning on: 5 Complete: 176624 Pruned: 823347
# Processing 28 simulations, with pruning on: 5 Complete: 176624 Pruned: 823348
# Processing 27 simulations, with pruning on: 5 Complete: 176624 Pruned: 823349
# Processing 26 simulations, with pruning on: 5 Complete: 176624 Pruned: 823350
# Processing 25 simulations, with pruning on: 5 Complete: 176624 Pruned: 823351
# Processing 37 simulations, with pruning on: 5 Complete: 227014 Pruned: 1072949
# Processing 36 simulations, with pruning on: 5 Complete: 227014 Pruned: 1072950
# Processing 35 simulations, with pruning on: 5 Complete: 227014 Pruned: 1072951
# Processing 34 simulations, with pruning on: 5 Complete: 227014 Pruned: 1072952
# Processing 33 simulations, with pruning on: 5 Complete: 227015 Pruned: 1072952
# Processing 26 simulations, with pruning on: 5 Complete: 303488 Pruned: 1296486
# Processing 25 simulations, with pruning on: 5 Complete: 303489 Pruned: 1296486
# Processing 33 simulations, with pruning on: 5 Complete: 356266 Pruned: 1543701
# Processing 39 simulations, with pruning on: 5 Complete: 397427 Pruned: 1802534
# Processing 38 simulations, with pruning on: 5 Complete: 397427 Pruned: 1802535
# Processing 37 simulations, with pruning on: 5 Complete: 397427 Pruned: 1802536
# Processing 36 simulations, with pruning on: 5 Complete: 397427 Pruned: 1802537
# Processing 35 simulations, with pruning on: 5 Complete: 397427 Pruned: 1802538
# Processing 34 simulations, with pruning on: 5 Complete: 397427 Pruned: 1802539
# Processing 33 simulations, with pruning on: 5 Complete: 434798 Pruned: 2065169
# Processing 34 simulations, with pruning on: 6 Complete: 473429 Pruned: 2326537
# Processing 33 simulations, with pruning on: 6 Complete: 473429 Pruned: 2326538
# Processing 32 simulations, with pruning on: 6 Complete: 473429 Pruned: 2326539
# Processing 31 simulations, with pruning on: 6 Complete: 473430 Pruned: 2326539
# Processing 30 simulations, with pruning on: 6 Complete: 473430 Pruned: 2326540
# Processing 37 simulations, with pruning on: 6 Complete: 530183 Pruned: 2569780
# Processing 36 simulations, with pruning on: 6 Complete: 530183 Pruned: 2569781
# Processing 35 simulations, with pruning on: 6 Complete: 530183 Pruned: 2569782
# Processing 34 simulations, with pruning on: 6 Complete: 530183 Pruned: 2569783
# Processing 33 simulations, with pruning on: 6 Complete: 530183 Pruned: 2569784
# Completed game for blueprint 29
# Processing 36 simulations, with pruning on: 3 Complete: 19579 Pruned: 80385
# Processing 35 simulations, with pruning on: 3 Complete: 19579 Pruned: 80386
# Processing 34 simulations, with pruning on: 3 Complete: 19579 Pruned: 80387
# Processing 33 simulations, with pruning on: 3 Complete: 19579 Pruned: 80388
# Processing 32 simulations, with pruning on: 3 Complete: 19579 Pruned: 80389
# Processing 31 simulations, with pruning on: 3 Complete: 19579 Pruned: 80390
# Processing 37 simulations, with pruning on: 4 Complete: 82088 Pruned: 317875
# Processing 36 simulations, with pruning on: 4 Complete: 82088 Pruned: 317876
# Processing 35 simulations, with pruning on: 4 Complete: 82088 Pruned: 317877
# Processing 34 simulations, with pruning on: 4 Complete: 82088 Pruned: 317878
# Processing 33 simulations, with pruning on: 4 Complete: 82088 Pruned: 317879
# Processing 36 simulations, with pruning on: 4 Complete: 157135 Pruned: 542829
# Processing 35 simulations, with pruning on: 4 Complete: 157135 Pruned: 542830
# Processing 34 simulations, with pruning on: 4 Complete: 157136 Pruned: 542830
# Processing 33 simulations, with pruning on: 4 Complete: 157136 Pruned: 542831
# Processing 32 simulations, with pruning on: 4 Complete: 157136 Pruned: 542832
# Processing 28 simulations, with pruning on: 4 Complete: 226578 Pruned: 773394
# Processing 37 simulations, with pruning on: 4 Complete: 283656 Pruned: 1016307
# Processing 24 simulations, with pruning on: 4 Complete: 350118 Pruned: 1249858
# Processing 25 simulations, with pruning on: 5 Complete: 405204 Pruned: 1494771
# Processing 24 simulations, with pruning on: 5 Complete: 405204 Pruned: 1494772
# Processing 23 simulations, with pruning on: 5 Complete: 405204 Pruned: 1494773
# Processing 22 simulations, with pruning on: 5 Complete: 405204 Pruned: 1494774
# Processing 21 simulations, with pruning on: 5 Complete: 405204 Pruned: 1494775
# Processing 27 simulations, with pruning on: 5 Complete: 469092 Pruned: 1730881
# Processing 26 simulations, with pruning on: 5 Complete: 469092 Pruned: 1730882
# Processing 25 simulations, with pruning on: 5 Complete: 469092 Pruned: 1730883
# Processing 24 simulations, with pruning on: 5 Complete: 469092 Pruned: 1730884
# Processing 23 simulations, with pruning on: 5 Complete: 469092 Pruned: 1730885
# Processing 18 simulations, with pruning on: 5 Complete: 515078 Pruned: 1984904
# Completed game for blueprint 30
# Total score for all blueprints: 1115
