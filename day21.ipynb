# %% [markdown]
# # Day 21 Monkey Math
#
# Or should it be called "monkey dispatch"? Cos that's my approach: register monkeys for events, and dispatch when event occurs

# %%
testData = """root: pppw + sjmn
dbpl: 5
cczh: sllz + lgvd
zczc: 2
ptdq: humn - dvpt
dvpt: 3
lfqf: 4
humn: 5
ljgn: 2
sjmn: drzm * dbpl
sllz: 4
pppw: cczh / lfqf
lgvd: ljgn * ptdq
drzm: hmdt - zczc
hmdt: 32"""

class MonkeyTalk:
    def __init__(self, input:str):
        self.monkeys = []
        self.knownValues:{str:int} = {}
        self.monkeyListeners:{str:[Monkey]} = {}
        self.monkeyEvents=[]
        self.endTalk = False
        for l in input.splitlines():
            chunk = l.split(': ')
            monkeyID = chunk[0]
            operators = chunk[1].split(' ')
            if len(operators)==1:
                #number already known
                #m = Monkey(monkeyID, self)
                #The monkey will only shout and then do nothing, so don't think I even need to create the monkey object
                self.knownValues[monkeyID] = int(operators[0])
                self.chat(monkeyID)
            else:
                #number not already known
                m = Monkey(monkeyID,self)
                self.monkeys.append(m)
                m.left = operators[0]
                m.operator = operators[1]
                m.right = operators[2]
                self.registerListener(m.left, m)
                self.registerListener(m.right, m)
        print('MonkeyTalk initalised with '+str(len(self.monkeys))+' monkeys listening and ' + str(len(self.monkeyEvents))+ ' monkeys already shouting')



    def registerListener(self, listenID:str, dispatchMonkey:Monkey):
        if listenID in self.monkeyListeners:
            self.monkeyListeners[listenID].append(dispatchMonkey)
        else:
            self.monkeyListeners[listenID] = [dispatchMonkey]

    def chat(self, monkeyID:str):
        self.monkeyEvents.append(monkeyID)

    def runTalk(self):
        #run the event queue
        while self.monkeyEvents and not self.endTalk:
            e = self.monkeyEvents.pop(0)
            for m in self.monkeyListeners[e]:
                m.handleEvent() #we don't call any parameters, because the monkey will need to check both values exist anyway
        else:
            print('Monkeys have run out of chat')

class Monkey:
    def __init__(self, id:str, talk:MonkeyTalk):
        self.id = id
        self.talk = talk
        #setup in monkeytalk:
        #m.left = operators[1]
        #m.operator = operators[2]
        #m.right = operators[3]

    def handleEvent(self):
        #we know value has been updated, but need to check which
        if self.left in self.talk.knownValues and self.right in self.talk.knownValues:
            left = self.talk.knownValues[self.left]
            right = self.talk.knownValues[self.right]
            match self.operator:
                case '+':
                    value = left + right
                case '-':
                    value = left - right
                case '*':
                    value = left * right
                case '/':
                    value = left / right
                case _:
                    raise Exception('unknown operator: '+str(self.operator))
            print('Monkey ' + self.id + ' knowns left='+str(self.left)+' and right='+str(self.right)+' using operator='+self.operator+' yields value='+str(value))
            self.talk.knownValues[self.id] = value
            self.talk.chat(self.id)
            if self.id == 'root':
                print('Root value found: '+str(value))
                self.talk.endTalk = True

#tests
tmt = MonkeyTalk(testData)
tmt.runTalk()
# Out:
# MonkeyTalk initalised with 7 monkeys listening and 8 monkeys already shouting
# Monkey drzm knowns left=hmdt and right=zczc using operator=- yields value=30
# Monkey ptdq knowns left=humn and right=dvpt using operator=- yields value=2
# Monkey ptdq knowns left=humn and right=dvpt using operator=- yields value=2
# Monkey lgvd knowns left=ljgn and right=ptdq using operator=* yields value=4
# Monkey cczh knowns left=sllz and right=lgvd using operator=+ yields value=8
# Monkey drzm knowns left=hmdt and right=zczc using operator=- yields value=30
# Monkey sjmn knowns left=drzm and right=dbpl using operator=* yields value=150
# Monkey lgvd knowns left=ljgn and right=ptdq using operator=* yields value=4
# Monkey lgvd knowns left=ljgn and right=ptdq using operator=* yields value=4
# Monkey cczh knowns left=sllz and right=lgvd using operator=+ yields value=8
# Monkey pppw knowns left=cczh and right=lfqf using operator=/ yields value=2.0
# Monkey sjmn knowns left=drzm and right=dbpl using operator=* yields value=150
# Monkey root knowns left=pppw and right=sjmn using operator=+ yields value=152.0
# Root value found: 152.0
# Monkeys have run out of chat

# %%
puzzleinput = open('day21input.txt').read()
mt = MonkeyTalk(puzzleinput)
mt.runTalk()
# Out:
# MonkeyTalk initalised with 1377 monkeys listening and 1378 monkeys already shouting
# Monkey jtvj knowns left=nlbr and right=cldt using operator=* yields value=34
# Monkey jjqv knowns left=vscg and right=tfng using operator=* yields value=6
# Monkey srsw knowns left=ghzz and right=djwh using operator=+ yields value=15
# Monkey vrmv knowns left=bthj and right=fqhq using operator=* yields value=12
# Monkey pttb knowns left=cljv and right=jhzr using operator=+ yields value=10
# Monkey wcgb knowns left=pwhn and right=djnb using operator=+ yields value=7
# Monkey gbsj knowns left=wnng and right=wqgg using operator=* yields value=52
# Monkey dcnn knowns left=cvdl and right=pwdq using operator=* yields value=8
# Monkey mmtb knowns left=tjms and right=rvhc using operator=* yields value=10
# Monkey rqnb knowns left=dwqp and right=nvwt using operator=+ yields value=11
# Monkey qcgj knowns left=djnl and right=hmld using operator=* yields value=6
# Monkey qhtw knowns left=qpgb and right=mplt using operator=* yields value=38
# Monkey qzwn knowns left=mbrg and right=ffdf using operator=* yields value=18
# Monkey hrzc knowns left=hhpb and right=chlh using operator=+ yields value=13
# Monkey rjvn knowns left=nwbv and right=jtzp using operator=+ yields value=21
# Monkey rsrp knowns left=znqv and right=hclm using operator=+ yields value=13
# Monkey bmmv knowns left=gwdv and right=bthc using operator=* yields value=14
# Monkey dzns knowns left=lmfv and right=hdrh using operator=* yields value=18
# Monkey zdst knowns left=dhfl and right=bgzl using operator=+ yields value=23
# Monkey hmbh knowns left=swtl and right=zchv using operator=+ yields value=13
# Monkey zmwr knowns left=zrzq and right=jwdq using operator=* yields value=10
# Monkey sjqp knowns left=hbqg and right=nwmm using operator=* yields value=187
# Monkey zfmh knowns left=vvcd and right=zmhj using operator=* yields value=32
# Monkey mmhg knowns left=bvcg and right=jgqh using operator=* yields value=25
# Monkey dbvl knowns left=ztvw and right=fhpf using operator=+ yields value=24
# Monkey szgp knowns left=qpjd and right=lstn using operator=* yields value=10
# Monkey nlpc knowns left=jmfv and right=dlhc using operator=- yields value=11
# Monkey njjn knowns left=wrzm and right=nszs using operator=* yields value=24
# Monkey jsbb knowns left=ssdq and right=lqjp using operator=* yields value=49
# Monkey jjpb knowns left=rspw and right=qcmh using operator=+ yields value=11
# Monkey rdtb knowns left=cnjr and right=pgwj using operator=* yields value=27
# Monkey gwts knowns left=rzjb and right=vvsd using operator=+ yields value=18
# Monkey hcvc knowns left=nvsm and right=ptpl using operator=* yields value=15
# Monkey tcfm knowns left=btmp and right=lbfb using operator=* yields value=15
# Monkey sbbz knowns left=zbgh and right=dnrv using operator=+ yields value=9
# Monkey lwrs knowns left=tpml and right=wvmt using operator=* yields value=90
# Monkey ftqc knowns left=scsc and right=fcjj using operator=* yields value=34
# Monkey hjft knowns left=szhz and right=jnnp using operator=* yields value=6
# Monkey ddcq knowns left=zhtl and right=ggcd using operator=+ yields value=7
# Monkey sscf knowns left=mzqf and right=trmq using operator=* yields value=12
# Monkey qdcs knowns left=dmhc and right=zvvr using operator=+ yields value=7
# Monkey btqg knowns left=nmwl and right=hdhh using operator=* yields value=8
# Monkey sgpp knowns left=vnbc and right=ssbc using operator=+ yields value=7
# Monkey mcdp knowns left=rsrp and right=lwzh using operator=+ yields value=31
# Monkey qhtw knowns left=qpgb and right=mplt using operator=* yields value=38
# Monkey snnz knowns left=ghqq and right=ngff using operator=+ yields value=8
# Monkey nmvc knowns left=fccf and right=frqq using operator=* yields value=90
# Monkey lqtr knowns left=jsvv and right=pfhm using operator=+ yields value=7
# Monkey qjcb knowns left=jjqv and right=hbbf using operator=* yields value=24
# Monkey hnzj knowns left=dncv and right=tvgg using operator=* yields value=20
# Monkey nvvr knowns left=lsww and right=ztjg using operator=* yields value=8
# Monkey dltf knowns left=rjtd and right=sllr using operator=* yields value=91
# Monkey qlzh knowns left=rswz and right=mcrj using operator=+ yields value=7
# Monkey tncw knowns left=nwwz and right=lzmn using operator=+ yields value=8
# Monkey pdhr knowns left=frbf and right=sfpl using operator=* yields value=8
# Monkey mhvn knowns left=dzmw and right=rtlb using operator=+ yields value=23
# Monkey rlmp knowns left=njjn and right=dzvn using operator=+ yields value=31
# Monkey sgpp knowns left=vnbc and right=ssbc using operator=+ yields value=7
# Monkey vpcr knowns left=vbzz and right=tdnf using operator=* yields value=42
# Monkey hdhb knowns left=dclr and right=tlcm using operator=* yields value=50
# Monkey zjll knowns left=jwjh and right=pbfd using operator=* yields value=12
# Monkey wjlc knowns left=dzbw and right=spnq using operator=* yields value=8
# Monkey cpzz knowns left=sprl and right=cjcn using operator=* yields value=14
# Monkey zqzn knowns left=mhvn and right=jwzq using operator=* yields value=115
# Monkey dffq knowns left=mqpc and right=znrj using operator=* yields value=24
# Monkey tzhs knowns left=vfbj and right=mbmn using operator=* yields value=10
# Monkey zgmn knowns left=gffh and right=bhbj using operator=* yields value=24
# Monkey fjcd knowns left=fpsr and right=vdgr using operator=* yields value=70
# Monkey qcmb knowns left=tfmr and right=tzdq using operator=* yields value=28
# Monkey jqlt knowns left=vzjl and right=chmv using operator=* yields value=21
# Monkey pndh knowns left=srvp and right=svvr using operator=+ yields value=7
# Monkey pnfc knowns left=dcdt and right=qfzq using operator=* yields value=55
# Monkey wmdg knowns left=svld and right=thfc using operator=* yields value=25
# Monkey qslq knowns left=wjzp and right=bjfr using operator=+ yields value=7
# Monkey zvgf knowns left=vbcf and right=rcnw using operator=* yields value=42
# Monkey tgpd knowns left=rvmw and right=zdll using operator=* yields value=12
# Monkey cgsw knowns left=fjrm and right=gmpl using operator=* yields value=8
# Monkey vgqv knowns left=rmmn and right=jcdj using operator=* yields value=12
# Monkey whtj knowns left=lzpb and right=vlql using operator=* yields value=20
# Monkey dgwj knowns left=ptsl and right=pfnm using operator=+ yields value=6
# Monkey lcrd knowns left=mclg and right=gppd using operator=* yields value=15
# Monkey qltd knowns left=bqvf and right=nlpc using operator=+ yields value=29
# Monkey qczj knowns left=tjdp and right=bvwq using operator=* yields value=18
# Monkey pdhr knowns left=frbf and right=sfpl using operator=* yields value=8
# Monkey chtq knowns left=sphf and right=wblq using operator=* yields value=18
# Monkey btqg knowns left=nmwl and right=hdhh using operator=* yields value=8
# Monkey nvvr knowns left=lsww and right=ztjg using operator=* yields value=8
# Monkey wvgc knowns left=tjwv and right=fgnv using operator=+ yields value=14
# Monkey rflf knowns left=zlsv and right=pstm using operator=+ yields value=13
# Monkey gnsl knowns left=qcpd and right=qpzn using operator=* yields value=8
# Monkey dlth knowns left=mpgh and right=zpqc using operator=/ yields value=7.0
# Monkey wlpn knowns left=jvdt and right=rbjs using operator=+ yields value=11
# Monkey ntmg knowns left=mjhq and right=njzm using operator=* yields value=14
# Monkey tppg knowns left=bsct and right=cvcz using operator=* yields value=180
# Monkey qgwz knowns left=bvnh and right=lzhw using operator=+ yields value=20
# Monkey qfpg knowns left=lbzr and right=plwd using operator=+ yields value=7
# Monkey tddz knowns left=jjfd and right=rbcd using operator=* yields value=6
# Monkey qvbt knowns left=gjgv and right=jtvj using operator=* yields value=306
# Monkey gcsv knowns left=hqhw and right=nbrf using operator=* yields value=6
# Monkey fvtj knowns left=gmlp and right=njnl using operator=* yields value=8
# Monkey fnvh knowns left=rblr and right=ffrq using operator=+ yields value=7
# Monkey rdpl knowns left=lmqr and right=fsmq using operator=* yields value=6
# Monkey dlzc knowns left=wdtv and right=mrgj using operator=* yields value=34
# Monkey nlgs knowns left=cqsj and right=bmld using operator=* yields value=6
# Monkey sscf knowns left=mzqf and right=trmq using operator=* yields value=12
# Monkey vljt knowns left=chgm and right=jvcs using operator=* yields value=27
# Monkey vnlm knowns left=schh and right=vjll using operator=* yields value=15
# Monkey ctll knowns left=gnfp and right=mnzg using operator=* yields value=9
# Monkey chhd knowns left=dbrt and right=tjlf using operator=* yields value=25
# Monkey mmjt knowns left=wdpw and right=lzml using operator=* yields value=9
# Monkey wdjw knowns left=dbdj and right=drsj using operator=* yields value=15
# Monkey bzzz knowns left=bfmm and right=whnw using operator=+ yields value=7
# Monkey lbdc knowns left=jngq and right=tvzd using operator=+ yields value=10
# Monkey cfwt knowns left=pfgn and right=qrcq using operator=* yields value=6
# Monkey pttb knowns left=cljv and right=jhzr using operator=+ yields value=10
# Monkey lbtj knowns left=nvfj and right=djhj using operator=+ yields value=7
# Monkey nfpg knowns left=psrj and right=pqgt using operator=* yields value=8
# Monkey vwtf knowns left=nhjc and right=pbfn using operator=* yields value=21
# Monkey cfln knowns left=thbm and right=shnv using operator=* yields value=28
# Monkey nhbm knowns left=jgvd and right=zhgw using operator=* yields value=25
# Monkey mmjt knowns left=wdpw and right=lzml using operator=* yields value=9
# Monkey vbpc knowns left=lwml and right=lssr using operator=+ yields value=7
# Monkey stqb knowns left=lmqz and right=gpbf using operator=+ yields value=7
# Monkey qphs knowns left=mmmd and right=rlcm using operator=* yields value=28
# Monkey npsr knowns left=srjf and right=czmz using operator=* yields value=26
# Monkey dmlf knowns left=gnsl and right=jrzr using operator=- yields value=7
# Monkey swcp knowns left=znld and right=srlj using operator=* yields value=21
# Monkey phcb knowns left=gcvz and right=dltf using operator=* yields value=1001
# Monkey lwrs knowns left=tpml and right=wvmt using operator=* yields value=90
# Monkey mdqj knowns left=pnbn and right=wwmf using operator=* yields value=8
# Monkey dlzc knowns left=wdtv and right=mrgj using operator=* yields value=34
# Monkey lmpz knowns left=gzhn and right=zhgl using operator=+ yields value=23
# Monkey zmjg knowns left=vstl and right=ggqd using operator=* yields value=288
# Monkey lmpz knowns left=gzhn and right=zhgl using operator=+ yields value=23
# Monkey wbzh knowns left=zfbf and right=qtnz using operator=+ yields value=31
# Monkey rbmg knowns left=fzlz and right=nzcc using operator=- yields value=10
# Monkey mdqj knowns left=pnbn and right=wwmf using operator=* yields value=8
# Monkey jtfb knowns left=tvbj and right=bchh using operator=* yields value=12
# Monkey mbml knowns left=dmtn and right=bvhz using operator=* yields value=12
# Monkey lvfn knowns left=zzbh and right=csfn using operator=+ yields value=19
# Monkey gwdt knowns left=zsjv and right=rjjv using operator=+ yields value=17
# Monkey jftf knowns left=qjcb and right=vmsb using operator=- yields value=23
# Monkey hjft knowns left=szhz and right=jnnp using operator=* yields value=6
# Monkey hrgq knowns left=swbm and right=wlpn using operator=+ yields value=23
# Monkey dwgn knowns left=jznf and right=fgmh using operator=+ yields value=13
# Monkey zjzw knowns left=lbtj and right=whgf using operator=* yields value=77
# Monkey rvdr knowns left=mdbc and right=bfhw using operator=* yields value=8
# Monkey zlfl knowns left=fcqq and right=rfjq using operator=+ yields value=13
# Monkey rrzz knowns left=hmbh and right=nzbt using operator=+ yields value=19
# Monkey bzzz knowns left=bfmm and right=whnw using operator=+ yields value=7
# Monkey vljt knowns left=chgm and right=jvcs using operator=* yields value=27
# Monkey nzmt knowns left=jsqh and right=cdlz using operator=* yields value=6
# Monkey cwhw knowns left=nsct and right=rzgd using operator=* yields value=8
# Monkey mdjz knowns left=bdfj and right=bpdb using operator=* yields value=26
# Monkey rqtf knowns left=fhqw and right=vmfn using operator=- yields value=10
# Monkey cbqr knowns left=vrjz and right=qblq using operator=* yields value=6
# Monkey pfjr knowns left=djjb and right=mznc using operator=* yields value=10
# Monkey tjzj knowns left=tlzq and right=qbwj using operator=* yields value=8
# Monkey vnlm knowns left=schh and right=vjll using operator=* yields value=15
# Monkey gnsl knowns left=qcpd and right=qpzn using operator=* yields value=8
# Monkey zjrg knowns left=pncm and right=gmbc using operator=+ yields value=7
# Monkey zcwd knowns left=wgrj and right=mzpt using operator=* yields value=39
# Monkey ctvr knowns left=ljpd and right=vzhg using operator=* yields value=25
# Monkey qmmf knowns left=ztqj and right=rtsc using operator=* yields value=33
# Monkey hsdh knowns left=dvbp and right=qrlv using operator=* yields value=30
# Monkey tgvz knowns left=stws and right=vnqt using operator=* yields value=9
# Monkey sflw knowns left=dcnn and right=zltb using operator=* yields value=64
# Monkey gwrm knowns left=jwqm and right=qgwj using operator=+ yields value=9
# Monkey bsqb knowns left=npjf and right=gpvf using operator=* yields value=21
# Monkey dhqb knowns left=vbqf and right=lgpq using operator=+ yields value=19
# Monkey vznm knowns left=zzzd and right=ntcc using operator=+ yields value=9
# Monkey fbss knowns left=zlzc and right=lsrt using operator=+ yields value=10
# Monkey hspp knowns left=lrrt and right=ddrh using operator=+ yields value=7
# Monkey gmpd knowns left=zjtp and right=ndwq using operator=* yields value=44
# Monkey qcgj knowns left=djnl and right=hmld using operator=* yields value=6
# Monkey nmcd knowns left=qpln and right=bzbq using operator=+ yields value=10
# Monkey rllp knowns left=nfpg and right=rtcb using operator=* yields value=16
# Monkey jzgt knowns left=fhbf and right=hmcm using operator=* yields value=6
# Monkey flvd knowns left=zrrm and right=bvlg using operator=+ yields value=7
# Monkey lrtm knowns left=qzvp and right=hsdf using operator=* yields value=28
# Monkey nlwj knowns left=hrsn and right=rcld using operator=+ yields value=7
# Monkey vrzj knowns left=vrjs and right=wvgc using operator=* yields value=84
# Monkey fllm knowns left=ftzb and right=ctqp using operator=* yields value=34
# Monkey qwqt knowns left=ggcn and right=vvdn using operator=+ yields value=11
# Monkey frsc knowns left=gwbc and right=qjms using operator=+ yields value=22
# Monkey njwn knowns left=fhmg and right=cczh using operator=* yields value=14
# Monkey dcnn knowns left=cvdl and right=pwdq using operator=* yields value=8
# Monkey rbpl knowns left=rrsl and right=vwjs using operator=* yields value=22
# Monkey vznm knowns left=zzzd and right=ntcc using operator=+ yields value=9
# Monkey mnsh knowns left=dngf and right=mvgl using operator=+ yields value=10
# Monkey mtjt knowns left=slld and right=cdzn using operator=* yields value=21
# Monkey jpsp knowns left=tgbh and right=ctpf using operator=* yields value=8
# Monkey sqfb knowns left=cdsr and right=dmrl using operator=* yields value=12
# Monkey bqhc knowns left=rzcw and right=qjwl using operator=* yields value=10
# Monkey gvrv knowns left=wqqd and right=qpqw using operator=* yields value=16
# Monkey jjbl knowns left=mtcd and right=brdj using operator=* yields value=28
# Monkey zmjg knowns left=vstl and right=ggqd using operator=* yields value=288
# Monkey mmtb knowns left=tjms and right=rvhc using operator=* yields value=10
# Monkey zbdv knowns left=lrbp and right=rsmp using operator=+ yields value=7
# Monkey qfdz knowns left=fdms and right=wsjg using operator=+ yields value=17
# Monkey qcmb knowns left=tfmr and right=tzdq using operator=* yields value=28
# Monkey tdtj knowns left=qswh and right=hnqn using operator=+ yields value=31
# Monkey zctn knowns left=mrzv and right=mmzq using operator=* yields value=26
# Monkey tzbm knowns left=hdfj and right=mtjt using operator=+ yields value=22
# Monkey rqnb knowns left=dwqp and right=nvwt using operator=+ yields value=11
# Monkey hdhb knowns left=dclr and right=tlcm using operator=* yields value=50
# Monkey bmbl knowns left=tbnv and right=pwsg using operator=* yields value=27
# Monkey pfjr knowns left=djjb and right=mznc using operator=* yields value=10
# Monkey fsll knowns left=jcct and right=lblm using operator=* yields value=24
# Monkey hfnt knowns left=pwjn and right=tzdj using operator=* yields value=6
# Monkey pnfc knowns left=dcdt and right=qfzq using operator=* yields value=55
# Monkey gmnn knowns left=mjcr and right=tgpt using operator=* yields value=30
# Monkey jhbn knowns left=csgg and right=vssg using operator=* yields value=6
# Monkey czcd knowns left=lvrp and right=lsbc using operator=* yields value=24
# Monkey mgvl knowns left=trdc and right=gnbw using operator=* yields value=20
# Monkey fjjn knowns left=nrmn and right=bnlz using operator=+ yields value=13
# Monkey wvgc knowns left=tjwv and right=fgnv using operator=+ yields value=14
# Monkey jrdp knowns left=dbdl and right=rrnr using operator=- yields value=7
# Monkey whtj knowns left=lzpb and right=vlql using operator=* yields value=20
# Monkey jsgg knowns left=pjtn and right=nlvg using operator=+ yields value=11
# Monkey mmsc knowns left=vdrs and right=vhzb using operator=+ yields value=9
# Monkey tmcb knowns left=jmvq and right=qwqt using operator=* yields value=33
# Monkey dhqb knowns left=vbqf and right=lgpq using operator=+ yields value=19
# Monkey qczj knowns left=tjdp and right=bvwq using operator=* yields value=18
# Monkey gbsj knowns left=wnng and right=wqgg using operator=* yields value=52
# Monkey ndhp knowns left=gfnh and right=tvvm using operator=* yields value=8
# Monkey hfnt knowns left=pwjn and right=tzdj using operator=* yields value=6
# Monkey glzr knowns left=ptqb and right=wbqg using operator=* yields value=10
# Monkey zrvw knowns left=zhcg and right=vmgw using operator=* yields value=27
# Monkey cwhw knowns left=nsct and right=rzgd using operator=* yields value=8
# Monkey ftqc knowns left=scsc and right=fcjj using operator=* yields value=34
# Monkey gtct knowns left=szrw and right=gmnn using operator=+ yields value=32
# Monkey cgsw knowns left=fjrm and right=gmpl using operator=* yields value=8
# Monkey lqtr knowns left=jsvv and right=pfhm using operator=+ yields value=7
# Monkey ctll knowns left=gnfp and right=mnzg using operator=* yields value=9
# Monkey zmwr knowns left=zrzq and right=jwdq using operator=* yields value=10
# Monkey wndr knowns left=wdhb and right=dmtz using operator=* yields value=9
# Monkey nlgs knowns left=cqsj and right=bmld using operator=* yields value=6
# Monkey tjzj knowns left=tlzq and right=qbwj using operator=* yields value=8
# Monkey wlpn knowns left=jvdt and right=rbjs using operator=+ yields value=11
# Monkey vlgr knowns left=rpvl and right=bwgc using operator=* yields value=60
# Monkey lldd knowns left=dbgp and right=twtm using operator=+ yields value=13
# Monkey jqlt knowns left=vzjl and right=chmv using operator=* yields value=21
# Monkey bmzh knowns left=jpcv and right=lcbt using operator=+ yields value=7
# Monkey jwjv knowns left=sbgs and right=gmqc using operator=+ yields value=11
# Monkey nfpg knowns left=psrj and right=pqgt using operator=* yields value=8
# Monkey rjjf knowns left=vdtv and right=ljng using operator=+ yields value=7
# Monkey nfpw knowns left=gpcz and right=wzcm using operator=+ yields value=22
# Monkey tdtj knowns left=qswh and right=hnqn using operator=+ yields value=31
# Monkey gvcq knowns left=zvmv and right=jmnq using operator=* yields value=10
# Monkey zlfl knowns left=fcqq and right=rfjq using operator=+ yields value=13
# Monkey jhvz knowns left=sljs and right=lbqh using operator=+ yields value=17
# Monkey gtfn knowns left=tpcs and right=chhr using operator=* yields value=28
# Monkey jmph knowns left=chhc and right=zfrc using operator=* yields value=9
# Monkey szdq knowns left=jbft and right=jdls using operator=* yields value=9
# Monkey vgqv knowns left=rmmn and right=jcdj using operator=* yields value=12
# Monkey gcdq knowns left=dgfb and right=rpqg using operator=+ yields value=17
# Monkey fgmb knowns left=fjjn and right=tcnw using operator=* yields value=39
# Monkey glzr knowns left=ptqb and right=wbqg using operator=* yields value=10
# Monkey pwvd knowns left=wdvm and right=wzsg using operator=* yields value=42
# Monkey vlgr knowns left=rpvl and right=bwgc using operator=* yields value=60
# Monkey swcp knowns left=znld and right=srlj using operator=* yields value=21
# Monkey wrzg knowns left=zgff and right=qrsm using operator=+ yields value=10
# Monkey pqsg knowns left=lmwl and right=rttf using operator=* yields value=54
# Monkey lgnl knowns left=sbmc and right=sjsf using operator=* yields value=22
# Monkey rmwc knowns left=lqdh and right=vwgp using operator=+ yields value=9
# Monkey pdcw knowns left=rrmr and right=mzjn using operator=* yields value=12
# Monkey bwgm knowns left=rtgn and right=lhzp using operator=* yields value=22
# Monkey jnwb knowns left=hsmr and right=zfnr using operator=* yields value=6
# Monkey qwqt knowns left=ggcn and right=vvdn using operator=+ yields value=11
# Monkey wndr knowns left=wdhb and right=dmtz using operator=* yields value=9
# Monkey gvcq knowns left=zvmv and right=jmnq using operator=* yields value=10
# Monkey gcff knowns left=vvqz and right=fgbq using operator=* yields value=25
# Monkey rcrd knowns left=gljf and right=ngmz using operator=+ yields value=7
# Monkey vplq knowns left=qqhc and right=htnc using operator=* yields value=22
# Monkey bsqb knowns left=npjf and right=gpvf using operator=* yields value=21
# Monkey dltf knowns left=rjtd and right=sllr using operator=* yields value=91
# Monkey hzrg knowns left=ffnj and right=sqsv using operator=+ yields value=26
# Monkey fjcd knowns left=fpsr and right=vdgr using operator=* yields value=70
# Monkey bdll knowns left=phzs and right=cmrw using operator=+ yields value=11
# Monkey dwgn knowns left=jznf and right=fgmh using operator=+ yields value=13
# Monkey gjcr knowns left=dwwn and right=trmr using operator=+ yields value=7
# Monkey djdr knowns left=dqlg and right=ccvr using operator=+ yields value=7
# Monkey tddz knowns left=jjfd and right=rbcd using operator=* yields value=6
# Monkey qqgw knowns left=mcpl and right=jtnt using operator=* yields value=9
# Monkey phls knowns left=jttg and right=jwgh using operator=* yields value=8
# Monkey jzzh knowns left=wwll and right=lbgq using operator=* yields value=12
# Monkey mmpj knowns left=lqfh and right=lzqp using operator=+ yields value=11
# Monkey szgp knowns left=qpjd and right=lstn using operator=* yields value=10
# Monkey vthl knowns left=bgrw and right=lcns using operator=* yields value=8
# Monkey gzrw knowns left=hwfp and right=fbrg using operator=* yields value=25
# Monkey mwwd knowns left=hbzr and right=pdqp using operator=- yields value=6
# Monkey nqmj knowns left=jdlr and right=zfwl using operator=* yields value=26
# Monkey cprv knowns left=rpjw and right=thgc using operator=* yields value=10
# Monkey mmwv knowns left=cwsb and right=ljsm using operator=* yields value=15
# Monkey vwmv knowns left=jnqw and right=cjzz using operator=* yields value=14
# Monkey stcm knowns left=vcsj and right=cgsv using operator=* yields value=39
# Monkey mgvl knowns left=trdc and right=gnbw using operator=* yields value=20
# Monkey lnlf knowns left=hcpn and right=qrlm using operator=* yields value=6
# Monkey qjlf knowns left=lvqd and right=zfjr using operator=+ yields value=11
# Monkey ncqz knowns left=pnqb and right=fcdr using operator=* yields value=78
# Monkey nlht knowns left=drwv and right=ljst using operator=* yields value=10
# Monkey mtdc knowns left=pgnc and right=ddzs using operator=* yields value=9
# Monkey qgwz knowns left=bvnh and right=lzhw using operator=+ yields value=20
# Monkey dgvh knowns left=vlmm and right=mgwh using operator=* yields value=35
# Monkey jhgt knowns left=dgvh and right=cswb using operator=- yields value=31
# Monkey hrzc knowns left=hhpb and right=chlh using operator=+ yields value=13
# Monkey wffd knowns left=gfjp and right=rpnd using operator=* yields value=10
# Monkey mcct knowns left=nbqr and right=shmh using operator=* yields value=12
# Monkey vbpc knowns left=lwml and right=lssr using operator=+ yields value=7
# Monkey ghpb knowns left=zlfl and right=qsgm using operator=* yields value=52
# Monkey vvlg knowns left=ztvd and right=zdrh using operator=+ yields value=7
# Monkey jjbl knowns left=mtcd and right=brdj using operator=* yields value=28
# Monkey tvfq knowns left=rrsd and right=zsrr using operator=+ yields value=23
# Monkey ltzh knowns left=ftwz and right=cwjt using operator=+ yields value=7
# Monkey rqtf knowns left=fhqw and right=vmfn using operator=- yields value=10
# Monkey lpnp knowns left=fvwj and right=jbnh using operator=* yields value=15
# Monkey nmcd knowns left=qpln and right=bzbq using operator=+ yields value=10
# Monkey cnsb knowns left=zwqt and right=fdgq using operator=* yields value=48
# Monkey ljhz knowns left=dqdt and right=zjrz using operator=+ yields value=11
# Monkey npvn knowns left=hgqr and right=wlvl using operator=* yields value=56
# Monkey rsrp knowns left=znqv and right=hclm using operator=+ yields value=13
# Monkey pnsp knowns left=rdpl and right=qtth using operator=+ yields value=7
# Monkey ncvz knowns left=cwtz and right=qrvp using operator=* yields value=14
# Monkey pjmq knowns left=dwws and right=jvhm using operator=* yields value=6
# Monkey gzrw knowns left=hwfp and right=fbrg using operator=* yields value=25
# Monkey cfwt knowns left=pfgn and right=qrcq using operator=* yields value=6
# Monkey gwts knowns left=rzjb and right=vvsd using operator=+ yields value=18
# Monkey mdjz knowns left=bdfj and right=bpdb using operator=* yields value=26
# Monkey zptn knowns left=hmtq and right=bmmv using operator=+ yields value=18
# Monkey jdsp knowns left=nnmf and right=stgv using operator=* yields value=119
# Monkey mwwd knowns left=hbzr and right=pdqp using operator=- yields value=6
# Monkey pvnr knowns left=pbpg and right=qbbt using operator=* yields value=12
# Monkey mbml knowns left=dmtn and right=bvhz using operator=* yields value=12
# Monkey vgjb knowns left=jhwq and right=tzbm using operator=+ yields value=29
# Monkey gzzq knowns left=lpnp and right=fnfr using operator=+ yields value=22
# Monkey mhfq knowns left=bflt and right=lzcd using operator=* yields value=30
# Monkey cbqr knowns left=vrjz and right=qblq using operator=* yields value=6
# Monkey gmpg knowns left=dghv and right=ddvc using operator=* yields value=8
# Monkey nsqh knowns left=mcjd and right=zlvl using operator=* yields value=32
# Monkey fjmh knowns left=djwd and right=cpcs using operator=* yields value=16
# Monkey bbsm knowns left=vlgr and right=vjnj using operator=+ yields value=61
# Monkey hfrj knowns left=fjcd and right=nzzh using operator=- yields value=51
# Monkey jhvz knowns left=sljs and right=lbqh using operator=+ yields value=17
# Monkey vsbn knowns left=plnn and right=twfg using operator=+ yields value=7
# Monkey mmpj knowns left=lqfh and right=lzqp using operator=+ yields value=11
# Monkey rflf knowns left=zlsv and right=pstm using operator=+ yields value=13
# Monkey dpqt knowns left=rmsz and right=vbnq using operator=- yields value=11
# Monkey nmvc knowns left=fccf and right=frqq using operator=* yields value=90
# Monkey lqzw knowns left=zbqd and right=shbf using operator=* yields value=51
# Monkey bpdd knowns left=tgvq and right=shbq using operator=+ yields value=7
# Monkey mldt knowns left=llfc and right=cmch using operator=+ yields value=7
# Monkey fjmh knowns left=djwd and right=cpcs using operator=* yields value=16
# Monkey tvfq knowns left=rrsd and right=zsrr using operator=+ yields value=23
# Monkey rzvs knowns left=dbtz and right=glth using operator=* yields value=40
# Monkey mfmt knowns left=jsbb and right=fbwn using operator=- yields value=43
# Monkey dwcd knowns left=fqmg and right=nhnd using operator=+ yields value=14
# Monkey qvvc knowns left=zhjw and right=znrp using operator=* yields value=9
# Monkey stcm knowns left=vcsj and right=cgsv using operator=* yields value=39
# Monkey qslq knowns left=wjzp and right=bjfr using operator=+ yields value=7
# Monkey ctvr knowns left=ljpd and right=vzhg using operator=* yields value=25
# Monkey gjcr knowns left=dwwn and right=trmr using operator=+ yields value=7
# Monkey ncvz knowns left=cwtz and right=qrvp using operator=* yields value=14
# Monkey zcwd knowns left=wgrj and right=mzpt using operator=* yields value=39
# Monkey bmzh knowns left=jpcv and right=lcbt using operator=+ yields value=7
# Monkey vqqj knowns left=hnfs and right=dntv using operator=* yields value=18
# Monkey zchs knowns left=qdbn and right=ttmw using operator=* yields value=15
# Monkey phmj knowns left=cnsb and right=lzhl using operator=/ yields value=24.0
# Monkey glnn knowns left=brqb and right=hflc using operator=* yields value=22
# Monkey bfqc knowns left=dzns and right=pjpz using operator=- yields value=13
# Monkey sbbz knowns left=zbgh and right=dnrv using operator=+ yields value=9
# Monkey qjlf knowns left=lvqd and right=zfjr using operator=+ yields value=11
# Monkey znjm knowns left=tgqt and right=wrzg using operator=+ yields value=17
# Monkey trtv knowns left=cvbt and right=ssst using operator=+ yields value=8
# Monkey hzzb knowns left=tcfm and right=jhqt using operator=+ yields value=31
# Monkey nwvp knowns left=qmdl and right=stpz using operator=* yields value=16
# Monkey fjcz knowns left=fvtj and right=bnhv using operator=* yields value=24
# Monkey csbp knowns left=wpfr and right=zsgt using operator=+ yields value=19
# Monkey jrhj knowns left=dlzc and right=fvgv using operator=+ yields value=37
# Monkey srzf knowns left=djdr and right=jgjl using operator=* yields value=21
# Monkey dvgh knowns left=mbmz and right=hztl using operator=* yields value=16
# Monkey dwcd knowns left=fqmg and right=nhnd using operator=+ yields value=14
# Monkey fqqn knowns left=jszt and right=ltzh using operator=* yields value=14
# Monkey jnrl knowns left=lrtm and right=ftnc using operator=+ yields value=32
# Monkey wjlc knowns left=dzbw and right=spnq using operator=* yields value=8
# Monkey rqzg knowns left=gtbw and right=qtgg using operator=* yields value=323
# Monkey zvgf knowns left=vbcf and right=rcnw using operator=* yields value=42
# Monkey qphs knowns left=mmmd and right=rlcm using operator=* yields value=28
# Monkey mgrq knowns left=znpm and right=szss using operator=* yields value=6
# Monkey fplb knowns left=qjgc and right=vfqz using operator=* yields value=32
# Monkey pmrn knowns left=pcjr and right=glnn using operator=+ yields value=30
# Monkey pqft knowns left=snjb and right=slnt using operator=* yields value=6
# Monkey srnq knowns left=pjmg and right=fgqr using operator=+ yields value=27
# Monkey jsvw knowns left=rtlr and right=pqpr using operator=+ yields value=23
# Monkey dlwc knowns left=mqsp and right=vhpg using operator=+ yields value=9
# Monkey mwrh knowns left=dvmh and right=tbjb using operator=* yields value=60
# Monkey qzwn knowns left=mbrg and right=ffdf using operator=* yields value=18
# Monkey vffr knowns left=jmph and right=mcpc using operator=+ yields value=11
# Monkey nzmt knowns left=jsqh and right=cdlz using operator=* yields value=6
# Monkey mmwv knowns left=cwsb and right=ljsm using operator=* yields value=15
# Monkey wcgb knowns left=pwhn and right=djnb using operator=+ yields value=7
# Monkey tcfm knowns left=btmp and right=lbfb using operator=* yields value=15
# Monkey qhbm knowns left=fvgc and right=mjlv using operator=* yields value=15
# Monkey zszw knowns left=lbrs and right=llhb using operator=* yields value=25
# Monkey fhmm knowns left=ntgj and right=cnlq using operator=+ yields value=8
# Monkey qwvl knowns left=dhqb and right=zsmz using operator=- yields value=17
# Monkey fcrd knowns left=szdq and right=pdrr using operator=* yields value=18
# Monkey ndsc knowns left=fjmh and right=ccsm using operator=+ yields value=17
# Monkey wsmf knowns left=cgsw and right=wmqf using operator=* yields value=40
# Monkey srsw knowns left=ghzz and right=djwh using operator=+ yields value=15
# Monkey chtq knowns left=sphf and right=wblq using operator=* yields value=18
# Monkey vljj knowns left=jgjc and right=qdcs using operator=* yields value=21
# Monkey wwgq knowns left=jjcp and right=gltp using operator=* yields value=143
# Monkey wtcz knowns left=jfhm and right=gbbw using operator=+ yields value=9
# Monkey ctgg knowns left=pqcz and right=qbvv using operator=* yields value=12
# Monkey lnbg knowns left=djln and right=czrq using operator=+ yields value=7
# Monkey vgrt knowns left=lwzf and right=njwn using operator=* yields value=98
# Monkey dpcw knowns left=tpmq and right=nqpv using operator=* yields value=6
# Monkey zbdv knowns left=lrbp and right=rsmp using operator=+ yields value=7
# Monkey rcdc knowns left=lfvp and right=msbt using operator=* yields value=35
# Monkey zjrg knowns left=pncm and right=gmbc using operator=+ yields value=7
# Monkey jnwb knowns left=hsmr and right=zfnr using operator=* yields value=6
# Monkey pcph knowns left=fdtl and right=hmcc using operator=+ yields value=6
# Monkey ssjd knowns left=rvgs and right=wwwf using operator=* yields value=30
# Monkey qnmz knowns left=hnzj and right=vbfh using operator=/ yields value=10.0
# Monkey trtv knowns left=cvbt and right=ssst using operator=+ yields value=8
# Monkey vnwg knowns left=wvmq and right=znjm using operator=* yields value=51
# Monkey njjn knowns left=wrzm and right=nszs using operator=* yields value=24
# Monkey gtfn knowns left=tpcs and right=chhr using operator=* yields value=28
# Monkey jwjv knowns left=sbgs and right=gmqc using operator=+ yields value=11
# Monkey pcph knowns left=fdtl and right=hmcc using operator=+ yields value=6
# Monkey cqjn knowns left=vfvl and right=mmtb using operator=+ yields value=17
# Monkey vvlg knowns left=ztvd and right=zdrh using operator=+ yields value=7
# Monkey fplb knowns left=qjgc and right=vfqz using operator=* yields value=32
# Monkey fjhc knowns left=lgnb and right=rmrc using operator=* yields value=8
# Monkey pgrp knowns left=psvq and right=mnrt using operator=+ yields value=17
# Monkey lhhm knowns left=wmfc and right=vbfr using operator=* yields value=21
# Monkey plwt knowns left=zbmd and right=qqrd using operator=* yields value=15
# Monkey lppt knowns left=jsfz and right=trbw using operator=* yields value=6
# Monkey btjv knowns left=gggv and right=lbtd using operator=+ yields value=9
# Monkey jjpb knowns left=rspw and right=qcmh using operator=+ yields value=11
# Monkey qtrj knowns left=qmmf and right=zmfg using operator=+ yields value=41
# Monkey ccwh knowns left=stqb and right=hcqr using operator=+ yields value=11
# Monkey jlzg knowns left=nrrr and right=mtdc using operator=* yields value=27
# Monkey rmmf knowns left=pvtc and right=gcff using operator=* yields value=50
# Monkey fvtj knowns left=gmlp and right=njnl using operator=* yields value=8
# Monkey gwrm knowns left=jwqm and right=qgwj using operator=+ yields value=9
# Monkey jfsr knowns left=gbrc and right=hjft using operator=+ yields value=19
# Monkey pvfg knowns left=hbhf and right=ghsw using operator=* yields value=12
# Monkey vjvp knowns left=tspn and right=fljz using operator=* yields value=8
# Monkey wffd knowns left=gfjp and right=rpnd using operator=* yields value=10
# Monkey fnhm knowns left=qphs and right=fqpt using operator=+ yields value=36
# Monkey gnzr knowns left=fgwj and right=tbcs using operator=* yields value=34
# Monkey zttm knowns left=gwdt and right=lwgt using operator=- yields value=13
# Monkey smqs knowns left=ztjh and right=mbtg using operator=* yields value=65
# Monkey snrm knowns left=mqpv and right=flwr using operator=+ yields value=22
# Monkey lvfn knowns left=zzbh and right=csfn using operator=+ yields value=19
# Monkey nrrp knowns left=fmqq and right=fnvh using operator=+ yields value=17
# Monkey pjmq knowns left=dwws and right=jvhm using operator=* yields value=6
# Monkey dzns knowns left=lmfv and right=hdrh using operator=* yields value=18
# Monkey qlzh knowns left=rswz and right=mcrj using operator=+ yields value=7
# Monkey bmbl knowns left=tbnv and right=pwsg using operator=* yields value=27
# Monkey flvd knowns left=zrrm and right=bvlg using operator=+ yields value=7
# Monkey lwqz knowns left=dqdc and right=qfpg using operator=+ yields value=11
# Monkey gmsp knowns left=nqmj and right=nlfs using operator=/ yields value=13.0
# Monkey rbtf knowns left=jndl and right=jsvw using operator=+ yields value=26
# Monkey hcqn knowns left=ztgp and right=cbzb using operator=* yields value=32
# Monkey tbgw knowns left=dwgn and right=rbtg using operator=* yields value=221
# Monkey pwvd knowns left=wdvm and right=wzsg using operator=* yields value=42
# Monkey rrbw knowns left=zbch and right=qsvd using operator=* yields value=16
# Monkey dlth knowns left=mpgh and right=zpqc using operator=/ yields value=7.0
# Monkey rzvs knowns left=dbtz and right=glth using operator=* yields value=40
# Monkey rhvb knowns left=bvfp and right=vvjw using operator=* yields value=50
# Monkey dpqt knowns left=rmsz and right=vbnq using operator=- yields value=11
# Monkey mdtn knowns left=hbnv and right=sqfb using operator=+ yields value=21
# Monkey mfnw knowns left=rmsr and right=hpgb using operator=* yields value=16
# Monkey tsvh knowns left=jnwb and right=zbpf using operator=+ yields value=11
# Monkey sqjb knowns left=gndb and right=wzvr using operator=+ yields value=11
# Monkey jznz knowns left=vsnq and right=nhcf using operator=* yields value=16
# Monkey cqwz knowns left=mpcs and right=bhjq using operator=* yields value=26
# Monkey fntb knowns left=fclw and right=bfqc using operator=* yields value=26
# Monkey zswj knowns left=nzwv and right=lwft using operator=* yields value=119
# Monkey trmt knowns left=nwpl and right=qvvc using operator=* yields value=36
# Monkey mwhd knowns left=vqhl and right=tvwp using operator=* yields value=21
# Monkey jzgt knowns left=fhbf and right=hmcm using operator=* yields value=6
# Monkey hmbh knowns left=swtl and right=zchv using operator=+ yields value=13
# Monkey dfnw knowns left=lgfh and right=vsjb using operator=+ yields value=19
# Monkey fdhb knowns left=bdcb and right=hfnt using operator=* yields value=12
# Monkey vwgt knowns left=hcrq and right=qzdt using operator=* yields value=9
# Monkey sqfb knowns left=cdsr and right=dmrl using operator=* yields value=12
# Monkey zhww knowns left=mwgt and right=vwpn using operator=+ yields value=7
# Monkey gcff knowns left=vvqz and right=fgbq using operator=* yields value=25
# Monkey cvfc knowns left=lrlz and right=zwhr using operator=* yields value=22
# Monkey lldd knowns left=dbgp and right=twtm using operator=+ yields value=13
# Monkey ntmg knowns left=mjhq and right=njzm using operator=* yields value=14
# Monkey qdcs knowns left=dmhc and right=zvvr using operator=+ yields value=7
# Monkey zljz knowns left=gddv and right=dmlf using operator=+ yields value=17
# Monkey nhdj knowns left=tqwv and right=zpsn using operator=* yields value=6
# Monkey nzpn knowns left=wdjw and right=tpbf using operator=* yields value=60
# Monkey zswj knowns left=nzwv and right=lwft using operator=* yields value=119
# Monkey qlct knowns left=dgtz and right=mmpj using operator=* yields value=22
# Monkey tnmn knowns left=hfmg and right=mvgw using operator=* yields value=8
# Monkey tppg knowns left=bsct and right=cvcz using operator=* yields value=180
# Monkey gmgz knowns left=lvbf and right=jzct using operator=* yields value=12
# Monkey fllb knowns left=hnqh and right=vzms using operator=* yields value=24
# Monkey vwqz knowns left=ngcc and right=jghj using operator=+ yields value=7
# Monkey pbmr knowns left=dpqt and right=jlvm using operator=+ yields value=23
# Monkey zztn knowns left=wtlc and right=jmlb using operator=* yields value=6
# Monkey dhbm knowns left=gtfn and right=gmhp using operator=- yields value=20
# Monkey bqmg knowns left=vbcn and right=dwcd using operator=* yields value=28
# Monkey fjhc knowns left=lgnb and right=rmrc using operator=* yields value=8
# Monkey qfpg knowns left=lbzr and right=plwd using operator=+ yields value=7
# Monkey sgnb knowns left=qzhp and right=zsvt using operator=* yields value=16
# Monkey fqqg knowns left=jghw and right=dhbm using operator=+ yields value=23
# Monkey vdqh knowns left=gzcn and right=mrsn using operator=+ yields value=7
# Monkey gmnn knowns left=mjcr and right=tgpt using operator=* yields value=30
# Monkey lpgc knowns left=nqrd and right=jhvz using operator=* yields value=34
# Monkey sjqp knowns left=hbqg and right=nwmm using operator=* yields value=187
# Monkey rmwc knowns left=lqdh and right=vwgp using operator=+ yields value=9
# Monkey snfr knowns left=vrdn and right=fqvh using operator=* yields value=28
# Monkey tgbt knowns left=fsnz and right=rpcn using operator=* yields value=28
# Monkey ncqz knowns left=pnqb and right=fcdr using operator=* yields value=78
# Monkey wbqd knowns left=zptn and right=tnbb using operator=+ yields value=38
# Monkey rbmg knowns left=fzlz and right=nzcc using operator=- yields value=10
# Monkey jnrj knowns left=trqt and right=qhhf using operator=* yields value=25
# Monkey mnsh knowns left=dngf and right=mvgl using operator=+ yields value=10
# Monkey jntr knowns left=vnwr and right=lslv using operator=+ yields value=29
# Monkey vqqj knowns left=hnfs and right=dntv using operator=* yields value=18
# Monkey vrmv knowns left=bthj and right=fqhq using operator=* yields value=12
# Monkey lnbg knowns left=djln and right=czrq using operator=+ yields value=7
# Monkey spsz knowns left=pvsz and right=pfsg using operator=* yields value=54
# Monkey rdpl knowns left=lmqr and right=fsmq using operator=* yields value=6
# Monkey lwbn knowns left=mcdp and right=csdg using operator=* yields value=62
# Monkey dmbm knowns left=nvgt and right=tvtf using operator=- yields value=8
# Monkey tmsz knowns left=nzmt and right=twjw using operator=+ yields value=11
# Monkey zjll knowns left=jwjh and right=pbfd using operator=* yields value=12
# Monkey hzdp knowns left=gmpd and right=vnfb using operator=/ yields value=11.0
# Monkey rswg knowns left=mhfq and right=gdfp using operator=+ yields value=46
# Monkey mldt knowns left=llfc and right=cmch using operator=+ yields value=7
# Monkey tncw knowns left=nwwz and right=lzmn using operator=+ yields value=8
# Monkey rdtm knowns left=qbnn and right=lsqb using operator=+ yields value=11
# Monkey snfr knowns left=vrdn and right=fqvh using operator=* yields value=28
# Monkey dbwj knowns left=mplc and right=vbpc using operator=+ yields value=17
# Monkey wcwd knowns left=llmf and right=mjsl using operator=* yields value=6
# Monkey snrm knowns left=mqpv and right=flwr using operator=+ yields value=22
# Monkey npsr knowns left=srjf and right=czmz using operator=* yields value=26
# Monkey rvdr knowns left=mdbc and right=bfhw using operator=* yields value=8
# Monkey djdr knowns left=dqlg and right=ccvr using operator=+ yields value=7
# Monkey rdtm knowns left=qbnn and right=lsqb using operator=+ yields value=11
# Monkey hlzb knowns left=lqzw and right=pwwp using operator=- yields value=43
# Monkey ctgg knowns left=pqcz and right=qbvv using operator=* yields value=12
# Monkey mjlf knowns left=pffd and right=bzzz using operator=* yields value=21
# Monkey rjfb knowns left=ndsb and right=ztrz using operator=* yields value=36
# Monkey gcsv knowns left=hqhw and right=nbrf using operator=* yields value=6
# Monkey qpbj knowns left=gfrq and right=tsvh using operator=* yields value=33
# Monkey fqtb knowns left=zhfq and right=bfnj using operator=* yields value=8
# Monkey vbpt knowns left=pdcw and right=tvrt using operator=* yields value=36
# Monkey snbz knowns left=pfrf and right=smqm using operator=* yields value=25
# Monkey lppt knowns left=jsfz and right=trbw using operator=* yields value=6
# Monkey phls knowns left=jttg and right=jwgh using operator=* yields value=8
# Monkey qzvw knowns left=rvbr and right=jhlh using operator=+ yields value=6
# Monkey mwrh knowns left=dvmh and right=tbjb using operator=* yields value=60
# Monkey btvj knowns left=dblw and right=dzfw using operator=+ yields value=12
# Monkey nlfw knowns left=chpb and right=gwrm using operator=* yields value=18
# Monkey glcq knowns left=jfgg and right=thzv using operator=* yields value=10
# Monkey mlsj knowns left=pdqw and right=ftqc using operator=* yields value=102
# Monkey fhmm knowns left=ntgj and right=cnlq using operator=+ yields value=8
# Monkey hnss knowns left=wrcz and right=zjrg using operator=+ yields value=11
# Monkey hnzj knowns left=dncv and right=tvgg using operator=* yields value=20
# Monkey gcdq knowns left=dgfb and right=rpqg using operator=+ yields value=17
# Monkey qvvc knowns left=zhjw and right=znrp using operator=* yields value=9
# Monkey vwmc knowns left=vhbb and right=rqcl using operator=* yields value=24
# Monkey wdjw knowns left=dbdj and right=drsj using operator=* yields value=15
# Monkey tqwq knowns left=rnjv and right=rjsr using operator=* yields value=9
# Monkey vtfh knowns left=pfnq and right=zljz using operator=* yields value=34
# Monkey bpdd knowns left=tgvq and right=shbq using operator=+ yields value=7
# Monkey jtvj knowns left=nlbr and right=cldt using operator=* yields value=34
# Monkey vwmv knowns left=jnqw and right=cjzz using operator=* yields value=14
# Monkey tdds knowns left=chdt and right=wczl using operator=+ yields value=9
# Monkey nhdj knowns left=tqwv and right=zpsn using operator=* yields value=6
# Monkey qhbm knowns left=fvgc and right=mjlv using operator=* yields value=15
# Monkey hcvc knowns left=nvsm and right=ptpl using operator=* yields value=15
# Monkey prjh knowns left=glzr and right=rvmp using operator=- yields value=7
# Monkey gvzc knowns left=prqq and right=pjmq using operator=* yields value=30
# Monkey vqht knowns left=sznw and right=rlmp using operator=* yields value=93
# Monkey qfdz knowns left=fdms and right=wsjg using operator=+ yields value=17
# Monkey cbcr knowns left=lhcs and right=vcnm using operator=+ yields value=10
# Monkey dlvr knowns left=jlgh and right=tzhs using operator=+ yields value=13
# Monkey sprb knowns left=pttb and right=wllf using operator=- yields value=7
# Monkey dmbm knowns left=nvgt and right=tvtf using operator=- yields value=8
# Monkey rfvb knowns left=jvwt and right=ghlq using operator=* yields value=6
# Monkey zcsh knowns left=bsqb and right=fttg using operator=* yields value=42
# Monkey rjvn knowns left=nwbv and right=jtzp using operator=+ yields value=21
# Monkey gglg knowns left=zsdb and right=fwtq using operator=* yields value=18
# Monkey pndh knowns left=srvp and right=svvr using operator=+ yields value=7
# Monkey mcct knowns left=nbqr and right=shmh using operator=* yields value=12
# Monkey sgnb knowns left=qzhp and right=zsvt using operator=* yields value=16
# Monkey pgrp knowns left=psvq and right=mnrt using operator=+ yields value=17
# Monkey lgph knowns left=gwbl and right=pnsp using operator=* yields value=14
# Monkey jpsp knowns left=tgbh and right=ctpf using operator=* yields value=8
# Monkey dgdr knowns left=vcjp and right=mltm using operator=+ yields value=6
# Monkey lljd knowns left=rhcf and right=rbpl using operator=* yields value=88
# Monkey ljhz knowns left=dqdt and right=zjrz using operator=+ yields value=11
# Monkey njwn knowns left=fhmg and right=cczh using operator=* yields value=14
# Monkey mtdc knowns left=pgnc and right=ddzs using operator=* yields value=9
# Monkey dnjs knowns left=vlrs and right=ghcl using operator=+ yields value=7
# Monkey vdqh knowns left=gzcn and right=mrsn using operator=+ yields value=7
# Monkey ntsg knowns left=rswg and right=zvgp using operator=+ yields value=59
# Monkey pvdp knowns left=prtt and right=ddcq using operator=* yields value=14
# Monkey tdds knowns left=chdt and right=wczl using operator=+ yields value=9
# Monkey lbdc knowns left=jngq and right=tvzd using operator=+ yields value=10
# Monkey pmdp knowns left=dwst and right=mwhd using operator=+ yields value=24
# Monkey wtcz knowns left=jfhm and right=gbbw using operator=+ yields value=9
# Monkey mpbh knowns left=rcqt and right=qjrd using operator=* yields value=55
# Monkey smqs knowns left=ztjh and right=mbtg using operator=* yields value=65
# Monkey tsrd knowns left=fqtb and right=ncfp using operator=* yields value=32
# Monkey jznz knowns left=vsnq and right=nhcf using operator=* yields value=16
# Monkey mdgv knowns left=bntf and right=mvlh using operator=* yields value=121
# Monkey nqmj knowns left=jdlr and right=zfwl using operator=* yields value=26
# Monkey fqtb knowns left=zhfq and right=bfnj using operator=* yields value=8
# Monkey ndln knowns left=hlbn and right=vprq using operator=* yields value=25
# Monkey bmmv knowns left=gwdv and right=bthc using operator=* yields value=14
# Monkey swsd knowns left=nmcd and right=zgpd using operator=- yields value=7
# Monkey qqgw knowns left=mcpl and right=jtnt using operator=* yields value=9
# ...
# Monkey ltwl knowns left=tlmf and right=nstb using operator=* yields value=49072.0
# Monkey ltwl knowns left=tlmf and right=nstb using operator=* yields value=49072.0
# Monkey hfrn knowns left=ltwl and right=tvjg using operator=- yields value=48589.0
# Monkey hfrn knowns left=ltwl and right=tvjg using operator=- yields value=48589.0
# Monkey hfrn knowns left=ltwl and right=tvjg using operator=- yields value=48589.0
# Monkey hfrn knowns left=ltwl and right=tvjg using operator=- yields value=48589.0
# Monkey hfrn knowns left=ltwl and right=tvjg using operator=- yields value=48589.0
# Monkey qdtf knowns left=qdjt and right=hfrn using operator=+ yields value=49509.0
# Monkey qdtf knowns left=qdjt and right=hfrn using operator=+ yields value=49509.0
# Monkey qdtf knowns left=qdjt and right=hfrn using operator=+ yields value=49509.0
# Monkey qdtf knowns left=qdjt and right=hfrn using operator=+ yields value=49509.0
# Monkey qdtf knowns left=qdjt and right=hfrn using operator=+ yields value=49509.0
# Monkey vszv knowns left=qdtf and right=mppg using operator=/ yields value=16503.0
# Monkey vszv knowns left=qdtf and right=mppg using operator=/ yields value=16503.0
# Monkey vszv knowns left=qdtf and right=mppg using operator=/ yields value=16503.0
# Monkey vszv knowns left=qdtf and right=mppg using operator=/ yields value=16503.0
# Monkey vszv knowns left=qdtf and right=mppg using operator=/ yields value=16503.0
# Monkey jlpj knowns left=vszv and right=qcgg using operator=+ yields value=17376.0
# Monkey jlpj knowns left=vszv and right=qcgg using operator=+ yields value=17376.0
# Monkey jlpj knowns left=vszv and right=qcgg using operator=+ yields value=17376.0
# Monkey jlpj knowns left=vszv and right=qcgg using operator=+ yields value=17376.0
# Monkey jlpj knowns left=vszv and right=qcgg using operator=+ yields value=17376.0
# Monkey ghhp knowns left=jlpj and right=tdhr using operator=* yields value=34752.0
# Monkey ghhp knowns left=jlpj and right=tdhr using operator=* yields value=34752.0
# Monkey ghhp knowns left=jlpj and right=tdhr using operator=* yields value=34752.0
# Monkey ghhp knowns left=jlpj and right=tdhr using operator=* yields value=34752.0
# Monkey ghhp knowns left=jlpj and right=tdhr using operator=* yields value=34752.0
# Monkey tfwp knowns left=ghhp and right=jphm using operator=- yields value=33870.0
# Monkey tfwp knowns left=ghhp and right=jphm using operator=- yields value=33870.0
# Monkey tfwp knowns left=ghhp and right=jphm using operator=- yields value=33870.0
# Monkey tfwp knowns left=ghhp and right=jphm using operator=- yields value=33870.0
# Monkey tfwp knowns left=ghhp and right=jphm using operator=- yields value=33870.0
# Monkey dhzz knowns left=tfwp and right=grpd using operator=/ yields value=5645.0
# Monkey dhzz knowns left=tfwp and right=grpd using operator=/ yields value=5645.0
# Monkey dhzz knowns left=tfwp and right=grpd using operator=/ yields value=5645.0
# Monkey dhzz knowns left=tfwp and right=grpd using operator=/ yields value=5645.0
# Monkey dhzz knowns left=tfwp and right=grpd using operator=/ yields value=5645.0
# Monkey wsrp knowns left=dhzz and right=rnpm using operator=+ yields value=6043.0
# Monkey wsrp knowns left=dhzz and right=rnpm using operator=+ yields value=6043.0
# Monkey wsrp knowns left=dhzz and right=rnpm using operator=+ yields value=6043.0
# Monkey wsrp knowns left=dhzz and right=rnpm using operator=+ yields value=6043.0
# Monkey wsrp knowns left=dhzz and right=rnpm using operator=+ yields value=6043.0
# Monkey pwzv knowns left=wsrp and right=rbzl using operator=* yields value=18129.0
# Monkey pwzv knowns left=wsrp and right=rbzl using operator=* yields value=18129.0
# Monkey pwzv knowns left=wsrp and right=rbzl using operator=* yields value=18129.0
# Monkey pwzv knowns left=wsrp and right=rbzl using operator=* yields value=18129.0
# Monkey pwzv knowns left=wsrp and right=rbzl using operator=* yields value=18129.0
# Monkey rwwf knowns left=pwzv and right=flbq using operator=- yields value=17831.0
# Monkey rwwf knowns left=pwzv and right=flbq using operator=- yields value=17831.0
# Monkey rwwf knowns left=pwzv and right=flbq using operator=- yields value=17831.0
# Monkey rwwf knowns left=pwzv and right=flbq using operator=- yields value=17831.0
# Monkey rwwf knowns left=pwzv and right=flbq using operator=- yields value=17831.0
# Monkey qmsf knowns left=rwwf and right=bccn using operator=+ yields value=17835.0
# Monkey qmsf knowns left=rwwf and right=bccn using operator=+ yields value=17835.0
# Monkey qmsf knowns left=rwwf and right=bccn using operator=+ yields value=17835.0
# Monkey qmsf knowns left=rwwf and right=bccn using operator=+ yields value=17835.0
# Monkey qmsf knowns left=rwwf and right=bccn using operator=+ yields value=17835.0
# Monkey fzct knowns left=qmsf and right=gtwf using operator=/ yields value=5945.0
# Monkey fzct knowns left=qmsf and right=gtwf using operator=/ yields value=5945.0
# Monkey fzct knowns left=qmsf and right=gtwf using operator=/ yields value=5945.0
# Monkey fzct knowns left=qmsf and right=gtwf using operator=/ yields value=5945.0
# Monkey fzct knowns left=qmsf and right=gtwf using operator=/ yields value=5945.0
# Monkey bdtz knowns left=fzct and right=qrpm using operator=+ yields value=6672.0
# Monkey bdtz knowns left=fzct and right=qrpm using operator=+ yields value=6672.0
# Monkey bdtz knowns left=fzct and right=qrpm using operator=+ yields value=6672.0
# Monkey bdtz knowns left=fzct and right=qrpm using operator=+ yields value=6672.0
# Monkey bdtz knowns left=fzct and right=qrpm using operator=+ yields value=6672.0
# Monkey nvvm knowns left=bdtz and right=bfvt using operator=* yields value=13344.0
# Monkey nvvm knowns left=bdtz and right=bfvt using operator=* yields value=13344.0
# Monkey nvvm knowns left=bdtz and right=bfvt using operator=* yields value=13344.0
# Monkey nvvm knowns left=bdtz and right=bfvt using operator=* yields value=13344.0
# Monkey nvvm knowns left=bdtz and right=bfvt using operator=* yields value=13344.0
# Monkey lmnp knowns left=nvvm and right=tmnt using operator=- yields value=12978.0
# Monkey lmnp knowns left=nvvm and right=tmnt using operator=- yields value=12978.0
# Monkey lmnp knowns left=nvvm and right=tmnt using operator=- yields value=12978.0
# Monkey lmnp knowns left=nvvm and right=tmnt using operator=- yields value=12978.0
# Monkey lmnp knowns left=nvvm and right=tmnt using operator=- yields value=12978.0
# Monkey frrs knowns left=lmnp and right=mzwd using operator=/ yields value=4326.0
# Monkey frrs knowns left=lmnp and right=mzwd using operator=/ yields value=4326.0
# Monkey frrs knowns left=lmnp and right=mzwd using operator=/ yields value=4326.0
# Monkey frrs knowns left=lmnp and right=mzwd using operator=/ yields value=4326.0
# Monkey frrs knowns left=lmnp and right=mzwd using operator=/ yields value=4326.0
# Monkey qllv knowns left=tvbh and right=frrs using operator=+ yields value=4911.0
# Monkey qllv knowns left=tvbh and right=frrs using operator=+ yields value=4911.0
# Monkey qllv knowns left=tvbh and right=frrs using operator=+ yields value=4911.0
# Monkey qllv knowns left=tvbh and right=frrs using operator=+ yields value=4911.0
# Monkey qllv knowns left=tvbh and right=frrs using operator=+ yields value=4911.0
# Monkey mhcv knowns left=qllv and right=sqlv using operator=* yields value=49110.0
# Monkey mhcv knowns left=qllv and right=sqlv using operator=* yields value=49110.0
# Monkey mhcv knowns left=qllv and right=sqlv using operator=* yields value=49110.0
# Monkey mhcv knowns left=qllv and right=sqlv using operator=* yields value=49110.0
# Monkey mhcv knowns left=qllv and right=sqlv using operator=* yields value=49110.0
# Monkey dqdl knowns left=mhcv and right=mgdh using operator=- yields value=48587.0
# Monkey dqdl knowns left=mhcv and right=mgdh using operator=- yields value=48587.0
# Monkey dqdl knowns left=mhcv and right=mgdh using operator=- yields value=48587.0
# Monkey dqdl knowns left=mhcv and right=mgdh using operator=- yields value=48587.0
# Monkey dqdl knowns left=mhcv and right=mgdh using operator=- yields value=48587.0
# Monkey zmpd knowns left=gfgp and right=dqdl using operator=+ yields value=48697.0
# Monkey zmpd knowns left=gfgp and right=dqdl using operator=+ yields value=48697.0
# Monkey zmpd knowns left=gfgp and right=dqdl using operator=+ yields value=48697.0
# Monkey zmpd knowns left=gfgp and right=dqdl using operator=+ yields value=48697.0
# Monkey zmpd knowns left=gfgp and right=dqdl using operator=+ yields value=48697.0
# Monkey zdbv knowns left=mrsj and right=zmpd using operator=+ yields value=49485.0
# Monkey zdbv knowns left=mrsj and right=zmpd using operator=+ yields value=49485.0
# Monkey zdbv knowns left=mrsj and right=zmpd using operator=+ yields value=49485.0
# Monkey zdbv knowns left=mrsj and right=zmpd using operator=+ yields value=49485.0
# Monkey zdbv knowns left=mrsj and right=zmpd using operator=+ yields value=49485.0
# Monkey vqhd knowns left=zdbv and right=hgcq using operator=/ yields value=16495.0
# Monkey vqhd knowns left=zdbv and right=hgcq using operator=/ yields value=16495.0
# Monkey vqhd knowns left=zdbv and right=hgcq using operator=/ yields value=16495.0
# Monkey vqhd knowns left=zdbv and right=hgcq using operator=/ yields value=16495.0
# Monkey vqhd knowns left=zdbv and right=hgcq using operator=/ yields value=16495.0
# Monkey qtzv knowns left=vqhd and right=ggld using operator=- yields value=15818.0
# Monkey qtzv knowns left=vqhd and right=ggld using operator=- yields value=15818.0
# Monkey qtzv knowns left=vqhd and right=ggld using operator=- yields value=15818.0
# Monkey qtzv knowns left=vqhd and right=ggld using operator=- yields value=15818.0
# Monkey qtzv knowns left=vqhd and right=ggld using operator=- yields value=15818.0
# Monkey lngc knowns left=qtzv and right=hllr using operator=/ yields value=7909.0
# Monkey lngc knowns left=qtzv and right=hllr using operator=/ yields value=7909.0
# Monkey lngc knowns left=qtzv and right=hllr using operator=/ yields value=7909.0
# Monkey lngc knowns left=qtzv and right=hllr using operator=/ yields value=7909.0
# Monkey lngc knowns left=qtzv and right=hllr using operator=/ yields value=7909.0
# Monkey drtz knowns left=btpb and right=lngc using operator=+ yields value=8245.0
# Monkey drtz knowns left=btpb and right=lngc using operator=+ yields value=8245.0
# Monkey drtz knowns left=btpb and right=lngc using operator=+ yields value=8245.0
# Monkey drtz knowns left=btpb and right=lngc using operator=+ yields value=8245.0
# Monkey drtz knowns left=btpb and right=lngc using operator=+ yields value=8245.0
# Monkey vpbs knowns left=nbvp and right=drtz using operator=* yields value=24735.0
# Monkey vpbs knowns left=nbvp and right=drtz using operator=* yields value=24735.0
# Monkey vpbs knowns left=nbvp and right=drtz using operator=* yields value=24735.0
# Monkey vpbs knowns left=nbvp and right=drtz using operator=* yields value=24735.0
# Monkey vpbs knowns left=nbvp and right=drtz using operator=* yields value=24735.0
# Monkey zgmb knowns left=vpbs and right=mdgv using operator=+ yields value=24856.0
# Monkey zgmb knowns left=vpbs and right=mdgv using operator=+ yields value=24856.0
# Monkey zgmb knowns left=vpbs and right=mdgv using operator=+ yields value=24856.0
# Monkey zgmb knowns left=vpbs and right=mdgv using operator=+ yields value=24856.0
# Monkey zgmb knowns left=vpbs and right=mdgv using operator=+ yields value=24856.0
# Monkey gpnc knowns left=zgmb and right=tglj using operator=/ yields value=12428.0
# Monkey gpnc knowns left=zgmb and right=tglj using operator=/ yields value=12428.0
# Monkey gpnc knowns left=zgmb and right=tglj using operator=/ yields value=12428.0
# Monkey gpnc knowns left=zgmb and right=tglj using operator=/ yields value=12428.0
# Monkey gpnc knowns left=zgmb and right=tglj using operator=/ yields value=12428.0
# Monkey njdr knowns left=gpnc and right=ztvf using operator=- yields value=12191.0
# Monkey njdr knowns left=gpnc and right=ztvf using operator=- yields value=12191.0
# Monkey njdr knowns left=gpnc and right=ztvf using operator=- yields value=12191.0
# Monkey njdr knowns left=gpnc and right=ztvf using operator=- yields value=12191.0
# Monkey njdr knowns left=gpnc and right=ztvf using operator=- yields value=12191.0
# Monkey mvdn knowns left=njdr and right=frvg using operator=* yields value=36573.0
# Monkey mvdn knowns left=njdr and right=frvg using operator=* yields value=36573.0
# Monkey mvdn knowns left=njdr and right=frvg using operator=* yields value=36573.0
# Monkey mvdn knowns left=njdr and right=frvg using operator=* yields value=36573.0
# Monkey mvdn knowns left=njdr and right=frvg using operator=* yields value=36573.0
# Monkey qwhh knowns left=mvdn and right=jvvd using operator=- yields value=36159.0
# Monkey qwhh knowns left=mvdn and right=jvvd using operator=- yields value=36159.0
# Monkey qwhh knowns left=mvdn and right=jvvd using operator=- yields value=36159.0
# Monkey qwhh knowns left=mvdn and right=jvvd using operator=- yields value=36159.0
# Monkey qwhh knowns left=mvdn and right=jvvd using operator=- yields value=36159.0
# Monkey bjpg knowns left=qwhh and right=wbdw using operator=* yields value=72318.0
# Monkey bjpg knowns left=qwhh and right=wbdw using operator=* yields value=72318.0
# Monkey bjpg knowns left=qwhh and right=wbdw using operator=* yields value=72318.0
# Monkey bjpg knowns left=qwhh and right=wbdw using operator=* yields value=72318.0
# Monkey bjpg knowns left=qwhh and right=wbdw using operator=* yields value=72318.0
# Monkey mgct knowns left=bjpg and right=mrgg using operator=+ yields value=73074.0
# Monkey mgct knowns left=bjpg and right=mrgg using operator=+ yields value=73074.0
# Monkey mgct knowns left=bjpg and right=mrgg using operator=+ yields value=73074.0
# Monkey mgct knowns left=bjpg and right=mrgg using operator=+ yields value=73074.0
# Monkey mgct knowns left=bjpg and right=mrgg using operator=+ yields value=73074.0
# Monkey bzrh knowns left=mgct and right=rpgv using operator=/ yields value=24358.0
# Monkey bzrh knowns left=mgct and right=rpgv using operator=/ yields value=24358.0
# Monkey bzrh knowns left=mgct and right=rpgv using operator=/ yields value=24358.0
# Monkey bzrh knowns left=mgct and right=rpgv using operator=/ yields value=24358.0
# Monkey bzrh knowns left=mgct and right=rpgv using operator=/ yields value=24358.0
# Monkey czst knowns left=pbgh and right=bzrh using operator=+ yields value=24885.0
# Monkey czst knowns left=pbgh and right=bzrh using operator=+ yields value=24885.0
# Monkey czst knowns left=pbgh and right=bzrh using operator=+ yields value=24885.0
# Monkey czst knowns left=pbgh and right=bzrh using operator=+ yields value=24885.0
# Monkey czst knowns left=pbgh and right=bzrh using operator=+ yields value=24885.0
# Monkey rmct knowns left=czst and right=stpp using operator=/ yields value=8295.0
# Monkey rmct knowns left=czst and right=stpp using operator=/ yields value=8295.0
# Monkey rmct knowns left=czst and right=stpp using operator=/ yields value=8295.0
# Monkey rmct knowns left=czst and right=stpp using operator=/ yields value=8295.0
# Monkey rmct knowns left=czst and right=stpp using operator=/ yields value=8295.0
# Monkey fhld knowns left=fggv and right=rmct using operator=- yields value=37906634585638.0
# Monkey fhld knowns left=fggv and right=rmct using operator=- yields value=37906634585638.0
# Monkey fhld knowns left=fggv and right=rmct using operator=- yields value=37906634585638.0
# Monkey fhld knowns left=fggv and right=rmct using operator=- yields value=37906634585638.0
# Monkey fhld knowns left=fggv and right=rmct using operator=- yields value=37906634585638.0
# Monkey pqpw knowns left=vprc and right=fhld using operator=* yields value=113719903756914.0
# Monkey pqpw knowns left=vprc and right=fhld using operator=* yields value=113719903756914.0
# Monkey pqpw knowns left=vprc and right=fhld using operator=* yields value=113719903756914.0
# Monkey pqpw knowns left=vprc and right=fhld using operator=* yields value=113719903756914.0
# Monkey pqpw knowns left=vprc and right=fhld using operator=* yields value=113719903756914.0
# Monkey root knowns left=pqpw and right=vqmv using operator=+ yields value=170237589447588.0
# Root value found: 170237589447588.0
# Monkeys have run out of chat
