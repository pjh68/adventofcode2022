# %% [markdown]
# # Day 18 : Boiling Boulders
#
# Ok, so today we're moving into 3D.
# It's all 1unit^3 cubes
# We need to find surface area - which is a count of exposed faces
#
# Cube can have 6 sides. Side is exposed if there is no cube in space adjacent to that face.
#
# So a cube in (2,2,2) has potential face-blocking neighbouring cubes at:
# (2,2,1)
# (2,1,2)
# (1,2,2)
# (3,2,2)
# (2,3,2)
# (2,2,3)
#
# Which boils down to: -1 on each of x,y,z then +1 on each of x,y,z

# %%
testData = """2,2,2
1,2,2
3,2,2
2,1,2
2,3,2
2,2,1
2,2,3
2,2,4
2,2,6
1,2,5
3,2,5
2,1,5
2,3,5"""

def process(input:str):
    output = set()
    for l in input.splitlines():
        x,y,z = l.split(',')
        output.add((int(x),int(y),int(z)))
    return output

#test
testCubes = process(testData)
print(testCubes)
# Out:
# {(2, 2, 3), (2, 2, 6), (2, 2, 2), (2, 3, 2), (3, 2, 2), (3, 2, 5), (2, 3, 5), (1, 2, 2), (2, 1, 2), (2, 2, 4), (2, 2, 1), (1, 2, 5), (2, 1, 5)}

# %%
neighbours = [  (0,0,1),
                (0,1,0),
                (1,0,0),
                (0,0,-1),
                (0,-1,0),
                (-1,0,0),

            ]
print(neighbours)

import operator

def countSurfaceArea(cubes)->int:
    runningTotal = 0
    for cube in cubes:
        for n in neighbours:
            ncoord = tuple(map(operator.add, cube, n))
            if not ncoord in cubes:
                runningTotal += 1
    return runningTotal

#test
area = countSurfaceArea(testCubes)
print(area)
# Out:
# [(0, 0, 1), (0, 1, 0), (1, 0, 0), (0, 0, -1), (0, -1, 0), (-1, 0, 0)]
# 64

# %%
#puzzle input
puzzle = open('day18input.txt').read()
cubes = process(puzzle)
area = countSurfaceArea(cubes)
print(area)
# Out:
# 3500

# %% [markdown]
# # Part 2
#
# Model this as steam moving out from (0,0,0) -> it's not in the test data nor puzzle, and all coords are positive and greater than 1 (which means we cover the min edges)

# %%
def maxCoords(cubes):
    #find the max x,y,z or all our cubes and +1 on all of them, so we cover the max edges too
    x = 0
    y = 0
    z = 0
    for a,b,c in cubes:
        x = max(x,a)
        y = max(y,b)
        z = max(z,c)
    return (x+1,y+1,z+1)

#test
print(maxCoords(testCubes))
# Out:
# (4, 4, 7)

# %%
def exteriorSurface(cubes):
    mx,my,mz = maxCoords(cubes)
    print('Max coordinates ' + str((mx,my,mz)) + ' containing ' + str(len(cubes)) + ' cubes of molten lava, so searching up to ' + str(mx*my*mz-len(cubes)) + 'cubes of space')
    
    start = (-1,-1,-1)
    #steam can expand in 6 possible directions - neighbours provides an array of tuple translations
    searchSpace = set()
    searchSpace.add(start)
    searched = set()
    surfaces = 0

    while len(searchSpace) > 0:
        print('In the loop. Search space: ' + str(len(searchSpace)) + ' Searched: '+ str(len(searched)))
        cube = searchSpace.pop()
        #print(cube)
        searched.add(cube)
        for n in neighbours:
            ncoord = tuple(map(operator.add, cube, n))
            x,y,z = ncoord
            if x>=-1 and x<=mx and y>=-1 and y<=my and z>=-1 and z<=mz and not ncoord in searched: #in the field of play
                if ncoord in cubes:
                    #we've hit an edge
                    print('## Found edge! Between '+str(cube) +' and ' + str(ncoord))
                    surfaces += 1
                else:
                    #we've not hit an edge, so add to search space
                    searchSpace.add(ncoord)
    return surfaces

#test data
print(exteriorSurface(testCubes))
# Out:
# Max coordinates (4, 4, 7) containing 13 cubes of molten lava, so searching up to 99cubes of space
# In the loop. Search space: 1 Searched: 0
# In the loop. Search space: 3 Searched: 1
# In the loop. Search space: 5 Searched: 2
# In the loop. Search space: 6 Searched: 3
# In the loop. Search space: 8 Searched: 4
# In the loop. Search space: 9 Searched: 5
# In the loop. Search space: 9 Searched: 6
# In the loop. Search space: 11 Searched: 7
# In the loop. Search space: 14 Searched: 8
# In the loop. Search space: 15 Searched: 9
# In the loop. Search space: 16 Searched: 10
# In the loop. Search space: 17 Searched: 11
# In the loop. Search space: 20 Searched: 12
# In the loop. Search space: 22 Searched: 13
# In the loop. Search space: 24 Searched: 14
# In the loop. Search space: 27 Searched: 15
# In the loop. Search space: 27 Searched: 16
# In the loop. Search space: 28 Searched: 17
# In the loop. Search space: 31 Searched: 18
# In the loop. Search space: 32 Searched: 19
# In the loop. Search space: 33 Searched: 20
# In the loop. Search space: 33 Searched: 21
# In the loop. Search space: 36 Searched: 22
# In the loop. Search space: 37 Searched: 23
# In the loop. Search space: 37 Searched: 24
# In the loop. Search space: 38 Searched: 25
# In the loop. Search space: 37 Searched: 26
# In the loop. Search space: 37 Searched: 27
# In the loop. Search space: 37 Searched: 28
# In the loop. Search space: 36 Searched: 29
# In the loop. Search space: 36 Searched: 30
# In the loop. Search space: 38 Searched: 31
# In the loop. Search space: 38 Searched: 32
# In the loop. Search space: 38 Searched: 33
# In the loop. Search space: 40 Searched: 34
# In the loop. Search space: 40 Searched: 35
# In the loop. Search space: 39 Searched: 36
# In the loop. Search space: 40 Searched: 37
# In the loop. Search space: 40 Searched: 38
# In the loop. Search space: 42 Searched: 39
# In the loop. Search space: 42 Searched: 40
# In the loop. Search space: 44 Searched: 41
# In the loop. Search space: 45 Searched: 42
# In the loop. Search space: 44 Searched: 43
# In the loop. Search space: 43 Searched: 44
# In the loop. Search space: 45 Searched: 45
# In the loop. Search space: 45 Searched: 46
# In the loop. Search space: 45 Searched: 47
# In the loop. Search space: 46 Searched: 48
# In the loop. Search space: 45 Searched: 49
# In the loop. Search space: 44 Searched: 50
# In the loop. Search space: 43 Searched: 51
# In the loop. Search space: 43 Searched: 52
# In the loop. Search space: 43 Searched: 53
# In the loop. Search space: 44 Searched: 54
# In the loop. Search space: 43 Searched: 55
# In the loop. Search space: 42 Searched: 56
# In the loop. Search space: 41 Searched: 57
# In the loop. Search space: 42 Searched: 58
# In the loop. Search space: 41 Searched: 59
# In the loop. Search space: 40 Searched: 60
# In the loop. Search space: 40 Searched: 61
# In the loop. Search space: 41 Searched: 62
# In the loop. Search space: 41 Searched: 63
# In the loop. Search space: 42 Searched: 64
# In the loop. Search space: 43 Searched: 65
# In the loop. Search space: 42 Searched: 66
# In the loop. Search space: 42 Searched: 67
# In the loop. Search space: 42 Searched: 68
# In the loop. Search space: 42 Searched: 69
# In the loop. Search space: 41 Searched: 70
# In the loop. Search space: 42 Searched: 71
# In the loop. Search space: 42 Searched: 72
# In the loop. Search space: 43 Searched: 73
# In the loop. Search space: 45 Searched: 74
# ## Found edge! Between (2, 2, 0) and (2, 2, 1)
# In the loop. Search space: 44 Searched: 75
# In the loop. Search space: 43 Searched: 76
# In the loop. Search space: 43 Searched: 77
# In the loop. Search space: 43 Searched: 78
# In the loop. Search space: 45 Searched: 79
# In the loop. Search space: 45 Searched: 80
# In the loop. Search space: 45 Searched: 81
# In the loop. Search space: 47 Searched: 82
# In the loop. Search space: 48 Searched: 83
# In the loop. Search space: 47 Searched: 84
# In the loop. Search space: 46 Searched: 85
# In the loop. Search space: 47 Searched: 86
# In the loop. Search space: 46 Searched: 87
# In the loop. Search space: 47 Searched: 88
# In the loop. Search space: 48 Searched: 89
# In the loop. Search space: 48 Searched: 90
# In the loop. Search space: 47 Searched: 91
# In the loop. Search space: 46 Searched: 92
# In the loop. Search space: 45 Searched: 93
# In the loop. Search space: 45 Searched: 94
# In the loop. Search space: 44 Searched: 95
# In the loop. Search space: 45 Searched: 96
# In the loop. Search space: 44 Searched: 97
# In the loop. Search space: 44 Searched: 98
# In the loop. Search space: 45 Searched: 99
# In the loop. Search space: 46 Searched: 100
# In the loop. Search space: 45 Searched: 101
# In the loop. Search space: 44 Searched: 102
# In the loop. Search space: 43 Searched: 103
# In the loop. Search space: 43 Searched: 104
# ## Found edge! Between (1, 2, 1) and (1, 2, 2)
# ## Found edge! Between (1, 2, 1) and (2, 2, 1)
# In the loop. Search space: 42 Searched: 105
# In the loop. Search space: 41 Searched: 106
# In the loop. Search space: 41 Searched: 107
# In the loop. Search space: 40 Searched: 108
# In the loop. Search space: 39 Searched: 109
# In the loop. Search space: 40 Searched: 110
# In the loop. Search space: 40 Searched: 111
# In the loop. Search space: 41 Searched: 112
# In the loop. Search space: 43 Searched: 113
# In the loop. Search space: 42 Searched: 114
# In the loop. Search space: 41 Searched: 115
# ## Found edge! Between (2, 1, 1) and (2, 1, 2)
# ## Found edge! Between (2, 1, 1) and (2, 2, 1)
# In the loop. Search space: 40 Searched: 116
# In the loop. Search space: 39 Searched: 117
# In the loop. Search space: 39 Searched: 118
# In the loop. Search space: 39 Searched: 119
# In the loop. Search space: 39 Searched: 120
# In the loop. Search space: 39 Searched: 121
# In the loop. Search space: 38 Searched: 122
# In the loop. Search space: 39 Searched: 123
# ## Found edge! Between (2, 3, 1) and (2, 3, 2)
# ## Found edge! Between (2, 3, 1) and (2, 2, 1)
# In the loop. Search space: 38 Searched: 124
# In the loop. Search space: 38 Searched: 125
# ## Found edge! Between (0, 2, 2) and (1, 2, 2)
# In the loop. Search space: 37 Searched: 126
# In the loop. Search space: 39 Searched: 127
# ## Found edge! Between (2, 0, 2) and (2, 1, 2)
# In the loop. Search space: 38 Searched: 128
# In the loop. Search space: 38 Searched: 129
# In the loop. Search space: 39 Searched: 130
# ## Found edge! Between (3, 2, 1) and (3, 2, 2)
# ## Found edge! Between (3, 2, 1) and (2, 2, 1)
# In the loop. Search space: 38 Searched: 131
# In the loop. Search space: 38 Searched: 132
# ## Found edge! Between (3, 3, 2) and (3, 2, 2)
# ## Found edge! Between (3, 3, 2) and (2, 3, 2)
# In the loop. Search space: 37 Searched: 133
# In the loop. Search space: 38 Searched: 134
# In the loop. Search space: 40 Searched: 135
# In the loop. Search space: 39 Searched: 136
# In the loop. Search space: 39 Searched: 137
# In the loop. Search space: 41 Searched: 138
# In the loop. Search space: 40 Searched: 139
# In the loop. Search space: 39 Searched: 140
# In the loop. Search space: 39 Searched: 141
# In the loop. Search space: 39 Searched: 142
# ## Found edge! Between (1, 3, 2) and (2, 3, 2)
# ## Found edge! Between (1, 3, 2) and (1, 2, 2)
# In the loop. Search space: 39 Searched: 143
# In the loop. Search space: 39 Searched: 144
# In the loop. Search space: 38 Searched: 145
# In the loop. Search space: 38 Searched: 146
# In the loop. Search space: 39 Searched: 147
# ## Found edge! Between (1, 1, 2) and (1, 2, 2)
# ## Found edge! Between (1, 1, 2) and (2, 1, 2)
# In the loop. Search space: 38 Searched: 148
# In the loop. Search space: 38 Searched: 149
# In the loop. Search space: 37 Searched: 150
# In the loop. Search space: 38 Searched: 151
# ## Found edge! Between (4, 2, 2) and (3, 2, 2)
# In the loop. Search space: 37 Searched: 152
# In the loop. Search space: 38 Searched: 153
# In the loop. Search space: 37 Searched: 154
# In the loop. Search space: 38 Searched: 155
# In the loop. Search space: 40 Searched: 156
# In the loop. Search space: 40 Searched: 157
# In the loop. Search space: 39 Searched: 158
# In the loop. Search space: 38 Searched: 159
# In the loop. Search space: 38 Searched: 160
# In the loop. Search space: 40 Searched: 161
# ## Found edge! Between (3, 1, 2) and (3, 2, 2)
# ## Found edge! Between (3, 1, 2) and (2, 1, 2)
# In the loop. Search space: 40 Searched: 162
# ## Found edge! Between (2, 4, 2) and (2, 3, 2)
# In the loop. Search space: 39 Searched: 163
# In the loop. Search space: 38 Searched: 164
# In the loop. Search space: 38 Searched: 165
# In the loop. Search space: 38 Searched: 166
# In the loop. Search space: 38 Searched: 167
# In the loop. Search space: 40 Searched: 168
# In the loop. Search space: 42 Searched: 169
# In the loop. Search space: 44 Searched: 170
# In the loop. Search space: 44 Searched: 171
# ## Found edge! Between (3, 2, 3) and (3, 2, 2)
# ## Found edge! Between (3, 2, 3) and (2, 2, 3)
# In the loop. Search space: 44 Searched: 172
# In the loop. Search space: 43 Searched: 173
# In the loop. Search space: 45 Searched: 174
# In the loop. Search space: 44 Searched: 175
# In the loop. Search space: 45 Searched: 176
# In the loop. Search space: 48 Searched: 177
# ## Found edge! Between (1, 1, 5) and (1, 2, 5)
# ## Found edge! Between (1, 1, 5) and (2, 1, 5)
# In the loop. Search space: 47 Searched: 178
# In the loop. Search space: 47 Searched: 179
# In the loop. Search space: 47 Searched: 180
# ## Found edge! Between (2, 1, 4) and (2, 1, 5)
# ## Found edge! Between (2, 1, 4) and (2, 2, 4)
# In the loop. Search space: 47 Searched: 181
# In the loop. Search space: 50 Searched: 182
# In the loop. Search space: 49 Searched: 183
# In the loop. Search space: 49 Searched: 184
# ## Found edge! Between (1, 2, 3) and (2, 2, 3)
# ## Found edge! Between (1, 2, 3) and (1, 2, 2)
# In the loop. Search space: 49 Searched: 185
# In the loop. Search space: 49 Searched: 186
# In the loop. Search space: 49 Searched: 187
# In the loop. Search space: 49 Searched: 188
# In the loop. Search space: 50 Searched: 189
# In the loop. Search space: 49 Searched: 190
# ## Found edge! Between (2, 1, 6) and (2, 2, 6)
# ## Found edge! Between (2, 1, 6) and (2, 1, 5)
# In the loop. Search space: 50 Searched: 191
# In the loop. Search space: 49 Searched: 192
# ## Found edge! Between (2, 1, 3) and (2, 2, 3)
# ## Found edge! Between (2, 1, 3) and (2, 1, 2)
# In the loop. Search space: 48 Searched: 193
# In the loop. Search space: 49 Searched: 194
# In the loop. Search space: 48 Searched: 195
# In the loop. Search space: 48 Searched: 196
# In the loop. Search space: 48 Searched: 197
# In the loop. Search space: 47 Searched: 198
# In the loop. Search space: 47 Searched: 199
# In the loop. Search space: 46 Searched: 200
# In the loop. Search space: 45 Searched: 201
# In the loop. Search space: 45 Searched: 202
# ## Found edge! Between (2, 3, 3) and (2, 3, 2)
# ## Found edge! Between (2, 3, 3) and (2, 2, 3)
# In the loop. Search space: 45 Searched: 203
# In the loop. Search space: 45 Searched: 204
# In the loop. Search space: 44 Searched: 205
# In the loop. Search space: 43 Searched: 206
# In the loop. Search space: 45 Searched: 207
# In the loop. Search space: 46 Searched: 208
# In the loop. Search space: 46 Searched: 209
# In the loop. Search space: 46 Searched: 210
# In the loop. Search space: 45 Searched: 211
# In the loop. Search space: 45 Searched: 212
# In the loop. Search space: 45 Searched: 213
# In the loop. Search space: 44 Searched: 214
# In the loop. Search space: 43 Searched: 215
# In the loop. Search space: 43 Searched: 216
# In the loop. Search space: 44 Searched: 217
# In the loop. Search space: 46 Searched: 218
# In the loop. Search space: 45 Searched: 219
# In the loop. Search space: 47 Searched: 220
# In the loop. Search space: 48 Searched: 221
# In the loop. Search space: 47 Searched: 222
# In the loop. Search space: 46 Searched: 223
# In the loop. Search space: 45 Searched: 224
# In the loop. Search space: 44 Searched: 225
# In the loop. Search space: 44 Searched: 226
# In the loop. Search space: 44 Searched: 227
# In the loop. Search space: 43 Searched: 228
# In the loop. Search space: 43 Searched: 229
# In the loop. Search space: 43 Searched: 230
# In the loop. Search space: 43 Searched: 231
# In the loop. Search space: 42 Searched: 232
# In the loop. Search space: 42 Searched: 233
# In the loop. Search space: 41 Searched: 234
# ## Found edge! Between (2, 0, 5) and (2, 1, 5)
# In the loop. Search space: 40 Searched: 235
# In the loop. Search space: 39 Searched: 236
# In the loop. Search space: 38 Searched: 237
# In the loop. Search space: 37 Searched: 238
# In the loop. Search space: 38 Searched: 239
# ## Found edge! Between (3, 2, 4) and (3, 2, 5)
# ## Found edge! Between (3, 2, 4) and (2, 2, 4)
# In the loop. Search space: 37 Searched: 240
# In the loop. Search space: 39 Searched: 241
# In the loop. Search space: 38 Searched: 242
# ## Found edge! Between (2, 3, 6) and (2, 3, 5)
# ## Found edge! Between (2, 3, 6) and (2, 2, 6)
# In the loop. Search space: 40 Searched: 243
# In the loop. Search space: 41 Searched: 244
# In the loop. Search space: 41 Searched: 245
# In the loop. Search space: 40 Searched: 246
# In the loop. Search space: 43 Searched: 247
# In the loop. Search space: 42 Searched: 248
# In the loop. Search space: 43 Searched: 249
# ## Found edge! Between (1, 2, 4) and (1, 2, 5)
# ## Found edge! Between (1, 2, 4) and (2, 2, 4)
# In the loop. Search space: 42 Searched: 250
# In the loop. Search space: 41 Searched: 251
# In the loop. Search space: 41 Searched: 252
# ## Found edge! Between (1, 3, 5) and (2, 3, 5)
# ## Found edge! Between (1, 3, 5) and (1, 2, 5)
# In the loop. Search space: 40 Searched: 253
# In the loop. Search space: 39 Searched: 254
# In the loop. Search space: 38 Searched: 255
# In the loop. Search space: 38 Searched: 256
# In the loop. Search space: 37 Searched: 257
# ## Found edge! Between (4, 2, 5) and (3, 2, 5)
# In the loop. Search space: 38 Searched: 258
# ## Found edge! Between (1, 2, 6) and (2, 2, 6)
# ## Found edge! Between (1, 2, 6) and (1, 2, 5)
# In the loop. Search space: 38 Searched: 259
# In the loop. Search space: 38 Searched: 260
# In the loop. Search space: 37 Searched: 261
# In the loop. Search space: 37 Searched: 262
# ## Found edge! Between (2, 3, 4) and (2, 3, 5)
# ## Found edge! Between (2, 3, 4) and (2, 2, 4)
# In the loop. Search space: 36 Searched: 263
# ## Found edge! Between (0, 2, 5) and (1, 2, 5)
# In the loop. Search space: 35 Searched: 264
# In the loop. Search space: 35 Searched: 265
# In the loop. Search space: 34 Searched: 266
# In the loop. Search space: 34 Searched: 267
# In the loop. Search space: 33 Searched: 268
# In the loop. Search space: 32 Searched: 269
# In the loop. Search space: 32 Searched: 270
# ## Found edge! Between (3, 3, 5) and (3, 2, 5)
# ## Found edge! Between (3, 3, 5) and (2, 3, 5)
# In the loop. Search space: 31 Searched: 271
# In the loop. Search space: 31 Searched: 272
# ## Found edge! Between (3, 1, 5) and (3, 2, 5)
# ## Found edge! Between (3, 1, 5) and (2, 1, 5)
# In the loop. Search space: 30 Searched: 273
# ## Found edge! Between (2, 4, 5) and (2, 3, 5)
# In the loop. Search space: 29 Searched: 274
# In the loop. Search space: 28 Searched: 275
# In the loop. Search space: 27 Searched: 276
# ## Found edge! Between (2, 2, 7) and (2, 2, 6)
# In the loop. Search space: 27 Searched: 277
# In the loop. Search space: 26 Searched: 278
# In the loop. Search space: 26 Searched: 279
# In the loop. Search space: 25 Searched: 280
# In the loop. Search space: 25 Searched: 281
# In the loop. Search space: 25 Searched: 282
# In the loop. Search space: 24 Searched: 283
# In the loop. Search space: 23 Searched: 284
# In the loop. Search space: 24 Searched: 285
# In the loop. Search space: 23 Searched: 286
# In the loop. Search space: 22 Searched: 287
# In the loop. Search space: 21 Searched: 288
# In the loop. Search space: 20 Searched: 289
# In the loop. Search space: 19 Searched: 290
# In the loop. Search space: 18 Searched: 291
# In the loop. Search space: 18 Searched: 292
# In the loop. Search space: 17 Searched: 293
# In the loop. Search space: 16 Searched: 294
# In the loop. Search space: 15 Searched: 295
# In the loop. Search space: 14 Searched: 296
# In the loop. Search space: 13 Searched: 297
# In the loop. Search space: 12 Searched: 298
# In the loop. Search space: 11 Searched: 299
# In the loop. Search space: 10 Searched: 300
# In the loop. Search space: 9 Searched: 301
# In the loop. Search space: 8 Searched: 302
# ## Found edge! Between (3, 2, 6) and (3, 2, 5)
# ## Found edge! Between (3, 2, 6) and (2, 2, 6)
# In the loop. Search space: 7 Searched: 303
# In the loop. Search space: 6 Searched: 304
# In the loop. Search space: 5 Searched: 305
# In the loop. Search space: 4 Searched: 306
# In the loop. Search space: 3 Searched: 307
# In the loop. Search space: 2 Searched: 308
# In the loop. Search space: 1 Searched: 309
# 58

# %%
#real puzzle
print(exteriorSurface(cubes))
# Out:
# Max coordinates (20, 20, 20) containing 2117 cubes of molten lava, so searching up to 5883cubes of space
# In the loop. Search space: 1 Searched: 0
# In the loop. Search space: 3 Searched: 1
# In the loop. Search space: 5 Searched: 2
# In the loop. Search space: 6 Searched: 3
# In the loop. Search space: 8 Searched: 4
# In the loop. Search space: 9 Searched: 5
# In the loop. Search space: 9 Searched: 6
# In the loop. Search space: 11 Searched: 7
# In the loop. Search space: 14 Searched: 8
# In the loop. Search space: 15 Searched: 9
# In the loop. Search space: 16 Searched: 10
# In the loop. Search space: 17 Searched: 11
# In the loop. Search space: 20 Searched: 12
# In the loop. Search space: 23 Searched: 13
# In the loop. Search space: 25 Searched: 14
# In the loop. Search space: 28 Searched: 15
# In the loop. Search space: 28 Searched: 16
# In the loop. Search space: 29 Searched: 17
# In the loop. Search space: 32 Searched: 18
# In the loop. Search space: 33 Searched: 19
# In the loop. Search space: 34 Searched: 20
# In the loop. Search space: 34 Searched: 21
# In the loop. Search space: 37 Searched: 22
# In the loop. Search space: 38 Searched: 23
# In the loop. Search space: 39 Searched: 24
# In the loop. Search space: 40 Searched: 25
# In the loop. Search space: 39 Searched: 26
# In the loop. Search space: 39 Searched: 27
# In the loop. Search space: 39 Searched: 28
# In the loop. Search space: 38 Searched: 29
# In the loop. Search space: 39 Searched: 30
# In the loop. Search space: 42 Searched: 31
# In the loop. Search space: 43 Searched: 32
# In the loop. Search space: 43 Searched: 33
# In the loop. Search space: 46 Searched: 34
# In the loop. Search space: 48 Searched: 35
# In the loop. Search space: 48 Searched: 36
# In the loop. Search space: 50 Searched: 37
# In the loop. Search space: 50 Searched: 38
# In the loop. Search space: 52 Searched: 39
# In the loop. Search space: 52 Searched: 40
# In the loop. Search space: 54 Searched: 41
# In the loop. Search space: 55 Searched: 42
# In the loop. Search space: 56 Searched: 43
# In the loop. Search space: 59 Searched: 44
# In the loop. Search space: 60 Searched: 45
# In the loop. Search space: 60 Searched: 46
# In the loop. Search space: 63 Searched: 47
# In the loop. Search space: 62 Searched: 48
# In the loop. Search space: 63 Searched: 49
# In the loop. Search space: 64 Searched: 50
# In the loop. Search space: 63 Searched: 51
# In the loop. Search space: 63 Searched: 52
# In the loop. Search space: 64 Searched: 53
# In the loop. Search space: 64 Searched: 54
# In the loop. Search space: 64 Searched: 55
# In the loop. Search space: 63 Searched: 56
# In the loop. Search space: 64 Searched: 57
# In the loop. Search space: 64 Searched: 58
# In the loop. Search space: 64 Searched: 59
# In the loop. Search space: 65 Searched: 60
# In the loop. Search space: 67 Searched: 61
# In the loop. Search space: 70 Searched: 62
# In the loop. Search space: 72 Searched: 63
# In the loop. Search space: 71 Searched: 64
# In the loop. Search space: 72 Searched: 65
# In the loop. Search space: 74 Searched: 66
# In the loop. Search space: 76 Searched: 67
# In the loop. Search space: 78 Searched: 68
# In the loop. Search space: 77 Searched: 69
# In the loop. Search space: 77 Searched: 70
# In the loop. Search space: 77 Searched: 71
# In the loop. Search space: 77 Searched: 72
# In the loop. Search space: 80 Searched: 73
# In the loop. Search space: 80 Searched: 74
# In the loop. Search space: 81 Searched: 75
# In the loop. Search space: 81 Searched: 76
# In the loop. Search space: 81 Searched: 77
# In the loop. Search space: 81 Searched: 78
# In the loop. Search space: 82 Searched: 79
# In the loop. Search space: 82 Searched: 80
# In the loop. Search space: 81 Searched: 81
# In the loop. Search space: 81 Searched: 82
# In the loop. Search space: 83 Searched: 83
# In the loop. Search space: 82 Searched: 84
# In the loop. Search space: 82 Searched: 85
# In the loop. Search space: 81 Searched: 86
# In the loop. Search space: 80 Searched: 87
# In the loop. Search space: 83 Searched: 88
# In the loop. Search space: 85 Searched: 89
# In the loop. Search space: 84 Searched: 90
# In the loop. Search space: 85 Searched: 91
# In the loop. Search space: 85 Searched: 92
# In the loop. Search space: 86 Searched: 93
# In the loop. Search space: 85 Searched: 94
# In the loop. Search space: 85 Searched: 95
# In the loop. Search space: 85 Searched: 96
# In the loop. Search space: 86 Searched: 97
# In the loop. Search space: 87 Searched: 98
# In the loop. Search space: 88 Searched: 99
# In the loop. Search space: 87 Searched: 100
# In the loop. Search space: 88 Searched: 101
# In the loop. Search space: 87 Searched: 102
# In the loop. Search space: 87 Searched: 103
# In the loop. Search space: 89 Searched: 104
# In the loop. Search space: 88 Searched: 105
# In the loop. Search space: 88 Searched: 106
# In the loop. Search space: 88 Searched: 107
# In the loop. Search space: 87 Searched: 108
# In the loop. Search space: 88 Searched: 109
# In the loop. Search space: 87 Searched: 110
# In the loop. Search space: 86 Searched: 111
# In the loop. Search space: 86 Searched: 112
# In the loop. Search space: 86 Searched: 113
# In the loop. Search space: 86 Searched: 114
# In the loop. Search space: 86 Searched: 115
# In the loop. Search space: 86 Searched: 116
# In the loop. Search space: 85 Searched: 117
# In the loop. Search space: 84 Searched: 118
# In the loop. Search space: 84 Searched: 119
# In the loop. Search space: 84 Searched: 120
# In the loop. Search space: 84 Searched: 121
# In the loop. Search space: 84 Searched: 122
# In the loop. Search space: 84 Searched: 123
# In the loop. Search space: 83 Searched: 124
# In the loop. Search space: 83 Searched: 125
# In the loop. Search space: 82 Searched: 126
# In the loop. Search space: 84 Searched: 127
# In the loop. Search space: 84 Searched: 128
# In the loop. Search space: 85 Searched: 129
# In the loop. Search space: 86 Searched: 130
# In the loop. Search space: 87 Searched: 131
# In the loop. Search space: 87 Searched: 132
# In the loop. Search space: 88 Searched: 133
# In the loop. Search space: 89 Searched: 134
# In the loop. Search space: 91 Searched: 135
# In the loop. Search space: 90 Searched: 136
# In the loop. Search space: 90 Searched: 137
# In the loop. Search space: 89 Searched: 138
# In the loop. Search space: 88 Searched: 139
# In the loop. Search space: 88 Searched: 140
# In the loop. Search space: 90 Searched: 141
# In the loop. Search space: 91 Searched: 142
# In the loop. Search space: 93 Searched: 143
# In the loop. Search space: 93 Searched: 144
# In the loop. Search space: 93 Searched: 145
# In the loop. Search space: 95 Searched: 146
# In the loop. Search space: 95 Searched: 147
# In the loop. Search space: 99 Searched: 148
# In the loop. Search space: 100 Searched: 149
# In the loop. Search space: 102 Searched: 150
# In the loop. Search space: 104 Searched: 151
# In the loop. Search space: 105 Searched: 152
# In the loop. Search space: 104 Searched: 153
# In the loop. Search space: 105 Searched: 154
# In the loop. Search space: 104 Searched: 155
# In the loop. Search space: 106 Searched: 156
# In the loop. Search space: 106 Searched: 157
# In the loop. Search space: 107 Searched: 158
# In the loop. Search space: 108 Searched: 159
# In the loop. Search space: 108 Searched: 160
# In the loop. Search space: 110 Searched: 161
# In the loop. Search space: 111 Searched: 162
# In the loop. Search space: 111 Searched: 163
# In the loop. Search space: 111 Searched: 164
# In the loop. Search space: 112 Searched: 165
# In the loop. Search space: 113 Searched: 166
# In the loop. Search space: 114 Searched: 167
# In the loop. Search space: 116 Searched: 168
# In the loop. Search space: 116 Searched: 169
# In the loop. Search space: 116 Searched: 170
# In the loop. Search space: 116 Searched: 171
# In the loop. Search space: 117 Searched: 172
# In the loop. Search space: 118 Searched: 173
# In the loop. Search space: 119 Searched: 174
# In the loop. Search space: 119 Searched: 175
# In the loop. Search space: 120 Searched: 176
# In the loop. Search space: 123 Searched: 177
# In the loop. Search space: 124 Searched: 178
# In the loop. Search space: 125 Searched: 179
# In the loop. Search space: 125 Searched: 180
# In the loop. Search space: 127 Searched: 181
# In the loop. Search space: 131 Searched: 182
# In the loop. Search space: 131 Searched: 183
# In the loop. Search space: 132 Searched: 184
# In the loop. Search space: 131 Searched: 185
# In the loop. Search space: 132 Searched: 186
# In the loop. Search space: 134 Searched: 187
# In the loop. Search space: 134 Searched: 188
# In the loop. Search space: 133 Searched: 189
# In the loop. Search space: 133 Searched: 190
# In the loop. Search space: 134 Searched: 191
# In the loop. Search space: 134 Searched: 192
# In the loop. Search space: 134 Searched: 193
# In the loop. Search space: 134 Searched: 194
# In the loop. Search space: 135 Searched: 195
# In the loop. Search space: 135 Searched: 196
# In the loop. Search space: 138 Searched: 197
# In the loop. Search space: 138 Searched: 198
# In the loop. Search space: 141 Searched: 199
# In the loop. Search space: 141 Searched: 200
# In the loop. Search space: 143 Searched: 201
# In the loop. Search space: 144 Searched: 202
# In the loop. Search space: 144 Searched: 203
# In the loop. Search space: 144 Searched: 204
# In the loop. Search space: 144 Searched: 205
# In the loop. Search space: 143 Searched: 206
# In the loop. Search space: 142 Searched: 207
# In the loop. Search space: 141 Searched: 208
# In the loop. Search space: 143 Searched: 209
# In the loop. Search space: 145 Searched: 210
# In the loop. Search space: 147 Searched: 211
# In the loop. Search space: 146 Searched: 212
# In the loop. Search space: 146 Searched: 213
# In the loop. Search space: 145 Searched: 214
# In the loop. Search space: 146 Searched: 215
# In the loop. Search space: 146 Searched: 216
# In the loop. Search space: 145 Searched: 217
# In the loop. Search space: 145 Searched: 218
# In the loop. Search space: 145 Searched: 219
# In the loop. Search space: 145 Searched: 220
# In the loop. Search space: 145 Searched: 221
# In the loop. Search space: 144 Searched: 222
# In the loop. Search space: 145 Searched: 223
# In the loop. Search space: 145 Searched: 224
# In the loop. Search space: 145 Searched: 225
# In the loop. Search space: 146 Searched: 226
# In the loop. Search space: 146 Searched: 227
# In the loop. Search space: 146 Searched: 228
# In the loop. Search space: 147 Searched: 229
# In the loop. Search space: 146 Searched: 230
# In the loop. Search space: 147 Searched: 231
# In the loop. Search space: 146 Searched: 232
# In the loop. Search space: 145 Searched: 233
# In the loop. Search space: 145 Searched: 234
# In the loop. Search space: 146 Searched: 235
# In the loop. Search space: 145 Searched: 236
# In the loop. Search space: 148 Searched: 237
# In the loop. Search space: 147 Searched: 238
# In the loop. Search space: 146 Searched: 239
# In the loop. Search space: 145 Searched: 240
# In the loop. Search space: 145 Searched: 241
# In the loop. Search space: 146 Searched: 242
# In the loop. Search space: 146 Searched: 243
# In the loop. Search space: 146 Searched: 244
# In the loop. Search space: 146 Searched: 245
# In the loop. Search space: 145 Searched: 246
# In the loop. Search space: 145 Searched: 247
# In the loop. Search space: 144 Searched: 248
# In the loop. Search space: 144 Searched: 249
# In the loop. Search space: 146 Searched: 250
# In the loop. Search space: 145 Searched: 251
# In the loop. Search space: 146 Searched: 252
# In the loop. Search space: 148 Searched: 253
# In the loop. Search space: 149 Searched: 254
# In the loop. Search space: 149 Searched: 255
# In the loop. Search space: 150 Searched: 256
# In the loop. Search space: 153 Searched: 257
# In the loop. Search space: 152 Searched: 258
# In the loop. Search space: 152 Searched: 259
# ## Found edge! Between (7, 5, 1) and (7, 5, 2)
# In the loop. Search space: 153 Searched: 260
# In the loop. Search space: 153 Searched: 261
# In the loop. Search space: 152 Searched: 262
# In the loop. Search space: 153 Searched: 263
# ## Found edge! Between (6, 4, 2) and (6, 4, 3)
# In the loop. Search space: 153 Searched: 264
# In the loop. Search space: 153 Searched: 265
# In the loop. Search space: 155 Searched: 266
# In the loop. Search space: 156 Searched: 267
# In the loop. Search space: 155 Searched: 268
# In the loop. Search space: 154 Searched: 269
# In the loop. Search space: 156 Searched: 270
# In the loop. Search space: 156 Searched: 271
# In the loop. Search space: 155 Searched: 272
# In the loop. Search space: 154 Searched: 273
# In the loop. Search space: 153 Searched: 274
# In the loop. Search space: 153 Searched: 275
# In the loop. Search space: 153 Searched: 276
# In the loop. Search space: 153 Searched: 277
# In the loop. Search space: 152 Searched: 278
# In the loop. Search space: 151 Searched: 279
# In the loop. Search space: 150 Searched: 280
# In the loop. Search space: 149 Searched: 281
# In the loop. Search space: 149 Searched: 282
# In the loop. Search space: 149 Searched: 283
# In the loop. Search space: 148 Searched: 284
# In the loop. Search space: 149 Searched: 285
# In the loop. Search space: 152 Searched: 286
# In the loop. Search space: 156 Searched: 287
# In the loop. Search space: 157 Searched: 288
# In the loop. Search space: 157 Searched: 289
# In the loop. Search space: 156 Searched: 290
# In the loop. Search space: 157 Searched: 291
# In the loop. Search space: 156 Searched: 292
# In the loop. Search space: 156 Searched: 293
# In the loop. Search space: 155 Searched: 294
# In the loop. Search space: 155 Searched: 295
# In the loop. Search space: 156 Searched: 296
# In the loop. Search space: 158 Searched: 297
# In the loop. Search space: 157 Searched: 298
# In the loop. Search space: 157 Searched: 299
# In the loop. Search space: 157 Searched: 300
# In the loop. Search space: 157 Searched: 301
# In the loop. Search space: 157 Searched: 302
# In the loop. Search space: 157 Searched: 303
# In the loop. Search space: 157 Searched: 304
# In the loop. Search space: 157 Searched: 305
# In the loop. Search space: 157 Searched: 306
# In the loop. Search space: 157 Searched: 307
# In the loop. Search space: 157 Searched: 308
# In the loop. Search space: 156 Searched: 309
# In the loop. Search space: 155 Searched: 310
# In the loop. Search space: 154 Searched: 311
# In the loop. Search space: 155 Searched: 312
# In the loop. Search space: 155 Searched: 313
# In the loop. Search space: 155 Searched: 314
# In the loop. Search space: 154 Searched: 315
# In the loop. Search space: 153 Searched: 316
# In the loop. Search space: 152 Searched: 317
# In the loop. Search space: 152 Searched: 318
# In the loop. Search space: 152 Searched: 319
# In the loop. Search space: 153 Searched: 320
# In the loop. Search space: 154 Searched: 321
# In the loop. Search space: 155 Searched: 322
# In the loop. Search space: 157 Searched: 323
# In the loop. Search space: 157 Searched: 324
# In the loop. Search space: 157 Searched: 325
# In the loop. Search space: 156 Searched: 326
# In the loop. Search space: 156 Searched: 327
# In the loop. Search space: 155 Searched: 328
# In the loop. Search space: 154 Searched: 329
# In the loop. Search space: 155 Searched: 330
# In the loop. Search space: 156 Searched: 331
# In the loop. Search space: 156 Searched: 332
# In the loop. Search space: 158 Searched: 333
# In the loop. Search space: 157 Searched: 334
# In the loop. Search space: 160 Searched: 335
# In the loop. Search space: 160 Searched: 336
# In the loop. Search space: 159 Searched: 337
# In the loop. Search space: 159 Searched: 338
# In the loop. Search space: 158 Searched: 339
# In the loop. Search space: 158 Searched: 340
# In the loop. Search space: 157 Searched: 341
# In the loop. Search space: 158 Searched: 342
# In the loop. Search space: 157 Searched: 343
# ## Found edge! Between (3, 7, 3) and (3, 7, 4)
# ## Found edge! Between (3, 7, 3) and (3, 8, 3)
# ## Found edge! Between (3, 7, 3) and (4, 7, 3)
# In the loop. Search space: 157 Searched: 344
# In the loop. Search space: 158 Searched: 345
# In the loop. Search space: 158 Searched: 346
# In the loop. Search space: 159 Searched: 347
# In the loop. Search space: 160 Searched: 348
# In the loop. Search space: 162 Searched: 349
# In the loop. Search space: 162 Searched: 350
# In the loop. Search space: 161 Searched: 351
# In the loop. Search space: 160 Searched: 352
# In the loop. Search space: 161 Searched: 353
# ## Found edge! Between (5, 4, 3) and (5, 4, 4)
# ## Found edge! Between (5, 4, 3) and (5, 5, 3)
# ## Found edge! Between (5, 4, 3) and (6, 4, 3)
# In the loop. Search space: 160 Searched: 354
# In the loop. Search space: 161 Searched: 355
# In the loop. Search space: 163 Searched: 356
# In the loop. Search space: 164 Searched: 357
# ## Found edge! Between (6, 3, 3) and (6, 3, 4)
# ## Found edge! Between (6, 3, 3) and (6, 4, 3)
# In the loop. Search space: 164 Searched: 358
# In the loop. Search space: 163 Searched: 359
# In the loop. Search space: 166 Searched: 360
# In the loop. Search space: 168 Searched: 361
# In the loop. Search space: 168 Searched: 362
# In the loop. Search space: 170 Searched: 363
# In the loop. Search space: 170 Searched: 364
# In the loop. Search space: 171 Searched: 365
# In the loop. Search space: 172 Searched: 366
# In the loop. Search space: 173 Searched: 367
# ## Found edge! Between (4, 4, 4) and (5, 4, 4)
# In the loop. Search space: 174 Searched: 368
# In the loop. Search space: 173 Searched: 369
# ## Found edge! Between (6, 6, 1) and (6, 6, 2)
# In the loop. Search space: 172 Searched: 370
# In the loop. Search space: 174 Searched: 371
# In the loop. Search space: 175 Searched: 372
# In the loop. Search space: 176 Searched: 373
# In the loop. Search space: 179 Searched: 374
# In the loop. Search space: 181 Searched: 375
# In the loop. Search space: 181 Searched: 376
# ## Found edge! Between (4, 8, 1) and (4, 8, 2)
# In the loop. Search space: 182 Searched: 377
# In the loop. Search space: 181 Searched: 378
# In the loop. Search space: 181 Searched: 379
# In the loop. Search space: 182 Searched: 380
# In the loop. Search space: 185 Searched: 381
# ## Found edge! Between (4, 7, 2) and (4, 7, 3)
# ## Found edge! Between (4, 7, 2) and (4, 8, 2)
# ## Found edge! Between (4, 7, 2) and (5, 7, 2)
# In the loop. Search space: 184 Searched: 382
# In the loop. Search space: 184 Searched: 383
# ## Found edge! Between (7, 4, 2) and (7, 4, 3)
# ## Found edge! Between (7, 4, 2) and (7, 5, 2)
# In the loop. Search space: 183 Searched: 384
# In the loop. Search space: 185 Searched: 385
# ## Found edge! Between (5, 3, 4) and (5, 4, 4)
# ## Found edge! Between (5, 3, 4) and (6, 3, 4)
# In the loop. Search space: 185 Searched: 386
# In the loop. Search space: 185 Searched: 387
# In the loop. Search space: 185 Searched: 388
# In the loop. Search space: 184 Searched: 389
# In the loop. Search space: 185 Searched: 390
# In the loop. Search space: 185 Searched: 391
# In the loop. Search space: 188 Searched: 392
# In the loop. Search space: 190 Searched: 393
# ## Found edge! Between (5, 7, 1) and (5, 7, 2)
# In the loop. Search space: 189 Searched: 394
# In the loop. Search space: 188 Searched: 395
# In the loop. Search space: 189 Searched: 396
# In the loop. Search space: 189 Searched: 397
# ## Found edge! Between (5, 6, 2) and (5, 7, 2)
# ## Found edge! Between (5, 6, 2) and (6, 6, 2)
# In the loop. Search space: 189 Searched: 398
# In the loop. Search space: 189 Searched: 399
# In the loop. Search space: 191 Searched: 400
# ## Found edge! Between (2, 7, 4) and (2, 7, 5)
# ## Found edge! Between (2, 7, 4) and (3, 7, 4)
# In the loop. Search space: 191 Searched: 401
# In the loop. Search space: 190 Searched: 402
# In the loop. Search space: 193 Searched: 403
# In the loop. Search space: 193 Searched: 404
# In the loop. Search space: 194 Searched: 405
# In the loop. Search space: 195 Searched: 406
# In the loop. Search space: 198 Searched: 407
# In the loop. Search space: 200 Searched: 408
# In the loop. Search space: 202 Searched: 409
# In the loop. Search space: 203 Searched: 410
# In the loop. Search space: 203 Searched: 411
# In the loop. Search space: 204 Searched: 412
# In the loop. Search space: 206 Searched: 413
# ## Found edge! Between (7, 3, 3) and (7, 3, 4)
# ## Found edge! Between (7, 3, 3) and (7, 4, 3)
# In the loop. Search space: 205 Searched: 414
# In the loop. Search space: 205 Searched: 415
# In the loop. Search space: 207 Searched: 416
# In the loop. Search space: 206 Searched: 417
# In the loop. Search space: 207 Searched: 418
# In the loop. Search space: 209 Searched: 419
# In the loop. Search space: 208 Searched: 420
# In the loop. Search space: 210 Searched: 421
# In the loop. Search space: 212 Searched: 422
# In the loop. Search space: 212 Searched: 423
# In the loop. Search space: 212 Searched: 424
# ## Found edge! Between (4, 3, 6) and (4, 3, 7)
# ## Found edge! Between (4, 3, 6) and (4, 4, 6)
# ## Found edge! Between (4, 3, 6) and (5, 3, 6)
# In the loop. Search space: 211 Searched: 425
# In the loop. Search space: 211 Searched: 426
# In the loop. Search space: 215 Searched: 427
# In the loop. Search space: 216 Searched: 428
# In the loop. Search space: 215 Searched: 429
# In the loop. Search space: 214 Searched: 430
# In the loop. Search space: 213 Searched: 431
# In the loop. Search space: 214 Searched: 432
# ## Found edge! Between (5, 3, 5) and (5, 3, 6)
# ## Found edge! Between (5, 3, 5) and (5, 4, 5)
# In the loop. Search space: 214 Searched: 433
# In the loop. Search space: 215 Searched: 434
# In the loop. Search space: 216 Searched: 435
# In the loop. Search space: 218 Searched: 436
# ## Found edge! Between (3, 6, 3) and (4, 6, 3)
# In the loop. Search space: 218 Searched: 437
# In the loop. Search space: 221 Searched: 438
# ## Found edge! Between (9, 3, 2) and (9, 3, 3)
# In the loop. Search space: 221 Searched: 439
# In the loop. Search space: 221 Searched: 440
# ## Found edge! Between (5, 6, 3) and (5, 6, 4)
# ## Found edge! Between (5, 6, 3) and (5, 7, 3)
# ## Found edge! Between (5, 6, 3) and (6, 6, 3)
# ## Found edge! Between (5, 6, 3) and (5, 5, 3)
# ## Found edge! Between (5, 6, 3) and (4, 6, 3)
# In the loop. Search space: 220 Searched: 441
# In the loop. Search space: 219 Searched: 442
# In the loop. Search space: 218 Searched: 443
# In the loop. Search space: 218 Searched: 444
# ## Found edge! Between (4, 6, 2) and (4, 6, 3)
# In the loop. Search space: 217 Searched: 445
# In the loop. Search space: 220 Searched: 446
# In the loop. Search space: 219 Searched: 447
# ## Found edge! Between (3, 4, 5) and (3, 4, 6)
# In the loop. Search space: 219 Searched: 448
# ## Found edge! Between (6, 2, 4) and (6, 2, 5)
# ## Found edge! Between (6, 2, 4) and (6, 3, 4)
# In the loop. Search space: 219 Searched: 449
# In the loop. Search space: 220 Searched: 450
# In the loop. Search space: 223 Searched: 451
# In the loop. Search space: 223 Searched: 452
# In the loop. Search space: 222 Searched: 453
# In the loop. Search space: 221 Searched: 454
# ## Found edge! Between (7, 2, 4) and (7, 3, 4)
# ## Found edge! Between (7, 2, 4) and (8, 2, 4)
# In the loop. Search space: 221 Searched: 455
# In the loop. Search space: 223 Searched: 456
# In the loop. Search space: 222 Searched: 457
# In the loop. Search space: 221 Searched: 458
# In the loop. Search space: 220 Searched: 459
# In the loop. Search space: 219 Searched: 460
# In the loop. Search space: 218 Searched: 461
# In the loop. Search space: 217 Searched: 462
# In the loop. Search space: 218 Searched: 463
# In the loop. Search space: 218 Searched: 464
# In the loop. Search space: 218 Searched: 465
# In the loop. Search space: 217 Searched: 466
# In the loop. Search space: 219 Searched: 467
# In the loop. Search space: 218 Searched: 468
# In the loop. Search space: 217 Searched: 469
# In the loop. Search space: 216 Searched: 470
# In the loop. Search space: 219 Searched: 471
# In the loop. Search space: 219 Searched: 472
# In the loop. Search space: 218 Searched: 473
# In the loop. Search space: 217 Searched: 474
# In the loop. Search space: 220 Searched: 475
# In the loop. Search space: 222 Searched: 476
# In the loop. Search space: 223 Searched: 477
# In the loop. Search space: 222 Searched: 478
# In the loop. Search space: 222 Searched: 479
# In the loop. Search space: 222 Searched: 480
# In the loop. Search space: 221 Searched: 481
# In the loop. Search space: 221 Searched: 482
# In the loop. Search space: 221 Searched: 483
# In the loop. Search space: 220 Searched: 484
# ## Found edge! Between (5, 10, 1) and (5, 10, 2)
# In the loop. Search space: 222 Searched: 485
# In the loop. Search space: 221 Searched: 486
# In the loop. Search space: 220 Searched: 487
# In the loop. Search space: 222 Searched: 488
# In the loop. Search space: 221 Searched: 489
# In the loop. Search space: 221 Searched: 490
# In the loop. Search space: 221 Searched: 491
# In the loop. Search space: 221 Searched: 492
# In the loop. Search space: 220 Searched: 493
# ## Found edge! Between (5, 2, 5) and (6, 2, 5)
# In the loop. Search space: 219 Searched: 494
# In the loop. Search space: 219 Searched: 495
# In the loop. Search space: 219 Searched: 496
# In the loop. Search space: 220 Searched: 497
# In the loop. Search space: 220 Searched: 498
# In the loop. Search space: 219 Searched: 499
# ## Found edge! Between (3, 8, 2) and (3, 8, 3)
# ## Found edge! Between (3, 8, 2) and (4, 8, 2)
# In the loop. Search space: 218 Searched: 500
# In the loop. Search space: 217 Searched: 501
# In the loop. Search space: 216 Searched: 502
# In the loop. Search space: 216 Searched: 503
# In the loop. Search space: 216 Searched: 504
# In the loop. Search space: 215 Searched: 505
# In the loop. Search space: 216 Searched: 506
# In the loop. Search space: 215 Searched: 507
# In the loop. Search space: 214 Searched: 508
# ## Found edge! Between (7, 6, 1) and (7, 6, 2)
# In the loop. Search space: 214 Searched: 509
# In the loop. Search space: 216 Searched: 510
# In the loop. Search space: 215 Searched: 511
# In the loop. Search space: 214 Searched: 512
# ## Found edge! Between (6, 5, 2) and (6, 5, 3)
# ## Found edge! Between (6, 5, 2) and (6, 6, 2)
# ## Found edge! Between (6, 5, 2) and (7, 5, 2)
# In the loop. Search space: 213 Searched: 513
# ## Found edge! Between (4, 5, 3) and (4, 6, 3)
# ## Found edge! Between (4, 5, 3) and (5, 5, 3)
# In the loop. Search space: 212 Searched: 514
# In the loop. Search space: 212 Searched: 515
# In the loop. Search space: 211 Searched: 516
# In the loop. Search space: 210 Searched: 517
# In the loop. Search space: 209 Searched: 518
# In the loop. Search space: 209 Searched: 519
# In the loop. Search space: 209 Searched: 520
# In the loop. Search space: 209 Searched: 521
# In the loop. Search space: 208 Searched: 522
# In the loop. Search space: 207 Searched: 523
# In the loop. Search space: 206 Searched: 524
# In the loop. Search space: 206 Searched: 525
# In the loop. Search space: 208 Searched: 526
# In the loop. Search space: 208 Searched: 527
# In the loop. Search space: 207 Searched: 528
# In the loop. Search space: 206 Searched: 529
# In the loop. Search space: 205 Searched: 530
# In the loop. Search space: 205 Searched: 531
# In the loop. Search space: 208 Searched: 532
# ## Found edge! Between (5, 5, 2) and (5, 5, 3)
# In the loop. Search space: 207 Searched: 533
# In the loop. Search space: 206 Searched: 534
# In the loop. Search space: 205 Searched: 535
# In the loop. Search space: 205 Searched: 536
# In the loop. Search space: 207 Searched: 537
# In the loop. Search space: 206 Searched: 538
# In the loop. Search space: 205 Searched: 539
# In the loop. Search space: 205 Searched: 540
# ## Found edge! Between (7, 2, 5) and (7, 2, 6)
# ## Found edge! Between (7, 2, 5) and (7, 3, 5)
# ## Found edge! Between (7, 2, 5) and (6, 2, 5)
# In the loop. Search space: 205 Searched: 541
# ## Found edge! Between (4, 9, 2) and (4, 9, 3)
# ## Found edge! Between (4, 9, 2) and (5, 9, 2)
# ## Found edge! Between (4, 9, 2) and (4, 8, 2)
# In the loop. Search space: 204 Searched: 542
# In the loop. Search space: 207 Searched: 543
# In the loop. Search space: 206 Searched: 544
# ## Found edge! Between (2, 5, 5) and (2, 5, 6)
# In the loop. Search space: 205 Searched: 545
# In the loop. Search space: 205 Searched: 546
# In the loop. Search space: 204 Searched: 547
# In the loop. Search space: 203 Searched: 548
# ## Found edge! Between (11, 3, 2) and (11, 3, 3)
# In the loop. Search space: 205 Searched: 549
# In the loop. Search space: 205 Searched: 550
# In the loop. Search space: 207 Searched: 551
# In the loop. Search space: 206 Searched: 552
# In the loop. Search space: 205 Searched: 553
# In the loop. Search space: 207 Searched: 554
# In the loop. Search space: 206 Searched: 555
# In the loop. Search space: 205 Searched: 556
# ## Found edge! Between (2, 4, 6) and (2, 5, 6)
# ## Found edge! Between (2, 4, 6) and (3, 4, 6)
# In the loop. Search space: 205 Searched: 557
# In the loop. Search space: 204 Searched: 558
# In the loop. Search space: 205 Searched: 559
# In the loop. Search space: 205 Searched: 560
# In the loop. Search space: 204 Searched: 561
# In the loop. Search space: 204 Searched: 562
# In the loop. Search space: 203 Searched: 563
# ## Found edge! Between (5, 9, 1) and (5, 9, 2)
# In the loop. Search space: 203 Searched: 564
# In the loop. Search space: 204 Searched: 565
# ## Found edge! Between (8, 5, 1) and (8, 5, 2)
# In the loop. Search space: 203 Searched: 566
# In the loop. Search space: 202 Searched: 567
# ## Found edge! Between (9, 5, 1) and (9, 5, 2)
# ## Found edge! Between (9, 5, 1) and (9, 6, 1)
# In the loop. Search space: 202 Searched: 568
# In the loop. Search space: 206 Searched: 569
# In the loop. Search space: 205 Searched: 570
# In the loop. Search space: 204 Searched: 571
# In the loop. Search space: 203 Searched: 572
# In the loop. Search space: 202 Searched: 573
# ## Found edge! Between (8, 4, 2) and (8, 4, 3)
# ## Found edge! Between (8, 4, 2) and (8, 5, 2)
# In the loop. Search space: 201 Searched: 574
# In the loop. Search space: 200 Searched: 575
# In the loop. Search space: 200 Searched: 576
# In the loop. Search space: 201 Searched: 577
# In the loop. Search space: 201 Searched: 578
# In the loop. Search space: 202 Searched: 579
# In the loop. Search space: 201 Searched: 580
# In the loop. Search space: 200 Searched: 581
# In the loop. Search space: 199 Searched: 582
# In the loop. Search space: 199 Searched: 583
# In the loop. Search space: 198 Searched: 584
# In the loop. Search space: 197 Searched: 585
# In the loop. Search space: 199 Searched: 586
# In the loop. Search space: 200 Searched: 587
# In the loop. Search space: 199 Searched: 588
# In the loop. Search space: 199 Searched: 589
# In the loop. Search space: 198 Searched: 590
# In the loop. Search space: 200 Searched: 591
# In the loop. Search space: 200 Searched: 592
# ## Found edge! Between (4, 5, 4) and (4, 5, 5)
# ## Found edge! Between (4, 5, 4) and (4, 6, 4)
# ## Found edge! Between (4, 5, 4) and (5, 5, 4)
# In the loop. Search space: 199 Searched: 593
# In the loop. Search space: 198 Searched: 594
# In the loop. Search space: 198 Searched: 595
# In the loop. Search space: 198 Searched: 596
# In the loop. Search space: 197 Searched: 597
# ## Found edge! Between (2, 8, 3) and (3, 8, 3)
# In the loop. Search space: 196 Searched: 598
# In the loop. Search space: 195 Searched: 599
# In the loop. Search space: 196 Searched: 600
# In the loop. Search space: 196 Searched: 601
# In the loop. Search space: 196 Searched: 602
# In the loop. Search space: 196 Searched: 603
# In the loop. Search space: 197 Searched: 604
# In the loop. Search space: 196 Searched: 605
# In the loop. Search space: 200 Searched: 606
# In the loop. Search space: 200 Searched: 607
# In the loop. Search space: 199 Searched: 608
# In the loop. Search space: 198 Searched: 609
# In the loop. Search space: 197 Searched: 610
# In the loop. Search space: 200 Searched: 611
# In the loop. Search space: 199 Searched: 612
# In the loop. Search space: 200 Searched: 613
# In the loop. Search space: 201 Searched: 614
# In the loop. Search space: 201 Searched: 615
# In the loop. Search space: 200 Searched: 616
# In the loop. Search space: 201 Searched: 617
# In the loop. Search space: 202 Searched: 618
# ## Found edge! Between (2, 4, 7) and (2, 5, 7)
# ## Found edge! Between (2, 4, 7) and (3, 4, 7)
# In the loop. Search space: 203 Searched: 619
# In the loop. Search space: 203 Searched: 620
# In the loop. Search space: 202 Searched: 621
# ## Found edge! Between (6, 7, 1) and (6, 7, 2)
# In the loop. Search space: 201 Searched: 622
# In the loop. Search space: 201 Searched: 623
# In the loop. Search space: 201 Searched: 624
# In the loop. Search space: 204 Searched: 625
# In the loop. Search space: 204 Searched: 626
# In the loop. Search space: 207 Searched: 627
# In the loop. Search space: 207 Searched: 628
# In the loop. Search space: 208 Searched: 629
# ## Found edge! Between (4, 4, 5) and (4, 4, 6)
# ## Found edge! Between (4, 4, 5) and (4, 5, 5)
# ## Found edge! Between (4, 4, 5) and (5, 4, 5)
# In the loop. Search space: 207 Searched: 630
# In the loop. Search space: 206 Searched: 631
# In the loop. Search space: 209 Searched: 632
# In the loop. Search space: 211 Searched: 633
# ## Found edge! Between (3, 3, 6) and (3, 4, 6)
# In the loop. Search space: 211 Searched: 634
# In the loop. Search space: 212 Searched: 635
# In the loop. Search space: 212 Searched: 636
# In the loop. Search space: 211 Searched: 637
# In the loop. Search space: 211 Searched: 638
# ## Found edge! Between (6, 8, 1) and (6, 8, 2)
# ## Found edge! Between (6, 8, 1) and (7, 8, 1)
# In the loop. Search space: 210 Searched: 639
# In the loop. Search space: 209 Searched: 640
# In the loop. Search space: 211 Searched: 641
# In the loop. Search space: 211 Searched: 642
# In the loop. Search space: 211 Searched: 643
# In the loop. Search space: 211 Searched: 644
# In the loop. Search space: 211 Searched: 645
# ## Found edge! Between (10, 5, 1) and (10, 5, 2)
# In the loop. Search space: 212 Searched: 646
# In the loop. Search space: 211 Searched: 647
# In the loop. Search space: 210 Searched: 648
# In the loop. Search space: 209 Searched: 649
# In the loop. Search space: 210 Searched: 650
# In the loop. Search space: 212 Searched: 651
# In the loop. Search space: 212 Searched: 652
# In the loop. Search space: 211 Searched: 653
# In the loop. Search space: 211 Searched: 654
# In the loop. Search space: 212 Searched: 655
# ## Found edge! Between (10, 4, 2) and (10, 4, 3)
# ## Found edge! Between (10, 4, 2) and (10, 5, 2)
# In the loop. Search space: 211 Searched: 656
# In the loop. Search space: 211 Searched: 657
# ## Found edge! Between (8, 3, 3) and (8, 3, 4)
# ## Found edge! Between (8, 3, 3) and (8, 4, 3)
# ## Found edge! Between (8, 3, 3) and (9, 3, 3)
# In the loop. Search space: 210 Searched: 658
# In the loop. Search space: 210 Searched: 659
# In the loop. Search space: 212 Searched: 660
# In the loop. Search space: 211 Searched: 661
# In the loop. Search space: 211 Searched: 662
# In the loop. Search space: 210 Searched: 663
# In the loop. Search space: 209 Searched: 664
# In the loop. Search space: 209 Searched: 665
# ## Found edge! Between (2, 8, 4) and (2, 9, 4)
# ## Found edge! Between (2, 8, 4) and (3, 8, 4)
# In the loop. Search space: 209 Searched: 666
# ## Found edge! Between (8, 7, 0) and (8, 7, 1)
# In the loop. Search space: 210 Searched: 667
# In the loop. Search space: 211 Searched: 668
# In the loop. Search space: 213 Searched: 669
# In the loop. Search space: 215 Searched: 670
# In the loop. Search space: 214 Searched: 671
# In the loop. Search space: 213 Searched: 672
# In the loop. Search space: 214 Searched: 673
# In the loop. Search space: 213 Searched: 674
# In the loop. Search space: 212 Searched: 675
# In the loop. Search space: 212 Searched: 676
# In the loop. Search space: 212 Searched: 677
# ## Found edge! Between (11, 2, 3) and (11, 3, 3)
# In the loop. Search space: 214 Searched: 678
# In the loop. Search space: 216 Searched: 679
# In the loop. Search space: 216 Searched: 680
# In the loop. Search space: 217 Searched: 681
# ## Found edge! Between (2, 11, 2) and (3, 11, 2)
# In the loop. Search space: 218 Searched: 682
# In the loop. Search space: 217 Searched: 683
# In the loop. Search space: 219 Searched: 684
# In the loop. Search space: 219 Searched: 685
# In the loop. Search space: 221 Searched: 686
# ## Found edge! Between (9, 8, 0) and (9, 8, 1)
# In the loop. Search space: 222 Searched: 687
# In the loop. Search space: 222 Searched: 688
# ## Found edge! Between (6, 3, 5) and (6, 3, 6)
# ## Found edge! Between (6, 3, 5) and (7, 3, 5)
# ## Found edge! Between (6, 3, 5) and (6, 3, 4)
# ## Found edge! Between (6, 3, 5) and (6, 2, 5)
# In the loop. Search space: 222 Searched: 689
# In the loop. Search space: 224 Searched: 690
# In the loop. Search space: 224 Searched: 691
# In the loop. Search space: 224 Searched: 692
# In the loop. Search space: 224 Searched: 693
# In the loop. Search space: 225 Searched: 694
# In the loop. Search space: 224 Searched: 695
# In the loop. Search space: 225 Searched: 696
# In the loop. Search space: 226 Searched: 697
# In the loop. Search space: 228 Searched: 698
# ## Found edge! Between (9, 1, 6) and (9, 1, 7)
# ## Found edge! Between (9, 1, 6) and (9, 2, 6)
# In the loop. Search space: 228 Searched: 699
# In the loop. Search space: 229 Searched: 700
# In the loop. Search space: 229 Searched: 701
# In the loop. Search space: 231 Searched: 702
# In the loop. Search space: 230 Searched: 703
# ## Found edge! Between (7, 8, 0) and (7, 8, 1)
# In the loop. Search space: 230 Searched: 704
# In the loop. Search space: 229 Searched: 705
# In the loop. Search space: 229 Searched: 706
# In the loop. Search space: 228 Searched: 707
# ## Found edge! Between (9, 0, 7) and (9, 1, 7)
# In the loop. Search space: 230 Searched: 708
# In the loop. Search space: 231 Searched: 709
# In the loop. Search space: 230 Searched: 710
# In the loop. Search space: 229 Searched: 711
# ## Found edge! Between (7, 7, 1) and (7, 7, 2)
# ## Found edge! Between (7, 7, 1) and (7, 8, 1)
# ## Found edge! Between (7, 7, 1) and (8, 7, 1)
# In the loop. Search space: 228 Searched: 712
# In the loop. Search space: 228 Searched: 713
# In the loop. Search space: 228 Searched: 714
# In the loop. Search space: 228 Searched: 715
# In the loop. Search space: 229 Searched: 716
# In the loop. Search space: 228 Searched: 717
# In the loop. Search space: 228 Searched: 718
# In the loop. Search space: 227 Searched: 719
# In the loop. Search space: 226 Searched: 720
# ## Found edge! Between (7, 0, 7) and (7, 1, 7)
# In the loop. Search space: 227 Searched: 721
# In the loop. Search space: 228 Searched: 722
# In the loop. Search space: 227 Searched: 723
# In the loop. Search space: 228 Searched: 724
# ## Found edge! Between (8, 2, 3) and (8, 2, 4)
# In the loop. Search space: 227 Searched: 725
# In the loop. Search space: 227 Searched: 726
# In the loop. Search space: 231 Searched: 727
# In the loop. Search space: 231 Searched: 728
# In the loop. Search space: 231 Searched: 729
# In the loop. Search space: 233 Searched: 730
# ## Found edge! Between (5, 8, 2) and (5, 8, 3)
# ## Found edge! Between (5, 8, 2) and (5, 9, 2)
# ## Found edge! Between (5, 8, 2) and (6, 8, 2)
# ## Found edge! Between (5, 8, 2) and (5, 7, 2)
# ## Found edge! Between (5, 8, 2) and (4, 8, 2)
# In the loop. Search space: 232 Searched: 731
# In the loop. Search space: 235 Searched: 732
# In the loop. Search space: 235 Searched: 733
# In the loop. Search space: 234 Searched: 734
# ## Found edge! Between (9, 4, 2) and (9, 4, 3)
# ## Found edge! Between (9, 4, 2) and (9, 5, 2)
# In the loop. Search space: 233 Searched: 735
# In the loop. Search space: 233 Searched: 736
# In the loop. Search space: 233 Searched: 737
# In the loop. Search space: 232 Searched: 738
# ## Found edge! Between (3, 6, 4) and (3, 6, 5)
# ## Found edge! Between (3, 6, 4) and (3, 7, 4)
# ## Found edge! Between (3, 6, 4) and (4, 6, 4)
# In the loop. Search space: 231 Searched: 739
# ## Found edge! Between (8, 2, 5) and (8, 2, 6)
# ## Found edge! Between (8, 2, 5) and (8, 3, 5)
# ## Found edge! Between (8, 2, 5) and (8, 2, 4)
# In the loop. Search space: 231 Searched: 740
# In the loop. Search space: 231 Searched: 741
# In the loop. Search space: 230 Searched: 742
# In the loop. Search space: 230 Searched: 743
# In the loop. Search space: 229 Searched: 744
# In the loop. Search space: 229 Searched: 745
# In the loop. Search space: 232 Searched: 746
# ## Found edge! Between (3, 5, 5) and (3, 6, 5)
# ## Found edge! Between (3, 5, 5) and (4, 5, 5)
# In the loop. Search space: 232 Searched: 747
# In the loop. Search space: 232 Searched: 748
# In the loop. Search space: 231 Searched: 749
# In the loop. Search space: 230 Searched: 750
# In the loop. Search space: 230 Searched: 751
# In the loop. Search space: 230 Searched: 752
# In the loop. Search space: 230 Searched: 753
# ## Found edge! Between (6, 10, 0) and (7, 10, 0)
# In the loop. Search space: 230 Searched: 754
# In the loop. Search space: 229 Searched: 755
# In the loop. Search space: 228 Searched: 756
# ## Found edge! Between (9, 7, 0) and (9, 7, 1)
# In the loop. Search space: 228 Searched: 757
# ## Found edge! Between (3, 9, 2) and (3, 9, 3)
# In the loop. Search space: 227 Searched: 758
# In the loop. Search space: 227 Searched: 759
# In the loop. Search space: 226 Searched: 760
# In the loop. Search space: 225 Searched: 761
# ## Found edge! Between (6, 9, 1) and (6, 9, 2)
# ## Found edge! Between (6, 9, 1) and (7, 9, 1)
# In the loop. Search space: 224 Searched: 762
# In the loop. Search space: 223 Searched: 763
# In the loop. Search space: 222 Searched: 764
# In the loop. Search space: 221 Searched: 765
# In the loop. Search space: 223 Searched: 766
# ## Found edge! Between (6, 1, 6) and (6, 2, 6)
# In the loop. Search space: 223 Searched: 767
# In the loop. Search space: 222 Searched: 768
# In the loop. Search space: 223 Searched: 769
# In the loop. Search space: 224 Searched: 770
# In the loop. Search space: 223 Searched: 771
# In the loop. Search space: 224 Searched: 772
# In the loop. Search space: 226 Searched: 773
# In the loop. Search space: 227 Searched: 774
# In the loop. Search space: 229 Searched: 775
# In the loop. Search space: 229 Searched: 776
# In the loop. Search space: 228 Searched: 777
# In the loop. Search space: 227 Searched: 778
# ## Found edge! Between (4, 10, 2) and (4, 10, 3)
# ## Found edge! Between (4, 10, 2) and (5, 10, 2)
# In the loop. Search space: 226 Searched: 779
# In the loop. Search space: 225 Searched: 780
# In the loop. Search space: 224 Searched: 781
# In the loop. Search space: 223 Searched: 782
# ## Found edge! Between (4, 2, 7) and (4, 3, 7)
# ## Found edge! Between (4, 2, 7) and (5, 2, 7)
# In the loop. Search space: 223 Searched: 783
# In the loop. Search space: 223 Searched: 784
# In the loop. Search space: 222 Searched: 785
# ## Found edge! Between (10, 8, 0) and (10, 8, 1)
# ## Found edge! Between (10, 8, 0) and (11, 8, 0)
# In the loop. Search space: 222 Searched: 786
# In the loop. Search space: 221 Searched: 787
# ## Found edge! Between (2, 6, 5) and (2, 7, 5)
# ## Found edge! Between (2, 6, 5) and (3, 6, 5)
# In the loop. Search space: 221 Searched: 788
# In the loop. Search space: 220 Searched: 789
# In the loop. Search space: 219 Searched: 790
# In the loop. Search space: 220 Searched: 791
# In the loop. Search space: 219 Searched: 792
# ## Found edge! Between (1, 9, 4) and (2, 9, 4)
# In the loop. Search space: 220 Searched: 793
# In the loop. Search space: 221 Searched: 794
# In the loop. Search space: 221 Searched: 795
# In the loop. Search space: 220 Searched: 796
# In the loop. Search space: 222 Searched: 797
# In the loop. Search space: 221 Searched: 798
# In the loop. Search space: 221 Searched: 799
# In the loop. Search space: 220 Searched: 800
# In the loop. Search space: 221 Searched: 801
# In the loop. Search space: 221 Searched: 802
# In the loop. Search space: 221 Searched: 803
# In the loop. Search space: 220 Searched: 804
# ## Found edge! Between (11, 4, 2) and (11, 4, 3)
# In the loop. Search space: 220 Searched: 805
# ## Found edge! Between (5, 2, 6) and (5, 2, 7)
# ## Found edge! Between (5, 2, 6) and (5, 3, 6)
# ## Found edge! Between (5, 2, 6) and (6, 2, 6)
# In the loop. Search space: 219 Searched: 806
# In the loop. Search space: 220 Searched: 807
# In the loop. Search space: 219 Searched: 808
# In the loop. Search space: 222 Searched: 809
# In the loop. Search space: 221 Searched: 810
# In the loop. Search space: 220 Searched: 811
# In the loop. Search space: 219 Searched: 812
# In the loop. Search space: 220 Searched: 813
# ## Found edge! Between (11, 0, 7) and (11, 1, 7)
# In the loop. Search space: 222 Searched: 814
# In the loop. Search space: 221 Searched: 815
# ## Found edge! Between (8, 9, 0) and (8, 9, 1)
# In the loop. Search space: 221 Searched: 816
# ## Found edge! Between (9, 2, 4) and (8, 2, 4)
# In the loop. Search space: 222 Searched: 817
# In the loop. Search space: 221 Searched: 818
# In the loop. Search space: 222 Searched: 819
# In the loop. Search space: 222 Searched: 820
# In the loop. Search space: 221 Searched: 821
# In the loop. Search space: 221 Searched: 822
# In the loop. Search space: 220 Searched: 823
# In the loop. Search space: 219 Searched: 824
# ## Found edge! Between (9, 3, 4) and (9, 3, 5)
# ## Found edge! Between (9, 3, 4) and (9, 4, 4)
# ## Found edge! Between (9, 3, 4) and (10, 3, 4)
# ## Found edge! Between (9, 3, 4) and (9, 3, 3)
# ## Found edge! Between (9, 3, 4) and (8, 3, 4)
# In the loop. Search space: 218 Searched: 825
# ## Found edge! Between (3, 5, 6) and (3, 5, 7)
# ## Found edge! Between (3, 5, 6) and (3, 6, 6)
# ## Found edge! Between (3, 5, 6) and (4, 5, 6)
# ## Found edge! Between (3, 5, 6) and (3, 4, 6)
# ## Found edge! Between (3, 5, 6) and (2, 5, 6)
# In the loop. Search space: 217 Searched: 826
# ## Found edge! Between (6, 1, 5) and (6, 2, 5)
# In the loop. Search space: 216 Searched: 827
# In the loop. Search space: 215 Searched: 828
# In the loop. Search space: 214 Searched: 829
# In the loop. Search space: 214 Searched: 830
# ## Found edge! Between (6, 10, 1) and (6, 10, 2)
# ## Found edge! Between (6, 10, 1) and (7, 10, 1)
# In the loop. Search space: 213 Searched: 831
# In the loop. Search space: 213 Searched: 832
# In the loop. Search space: 212 Searched: 833
# In the loop. Search space: 211 Searched: 834
# In the loop. Search space: 213 Searched: 835
# ## Found edge! Between (1, 5, 6) and (2, 5, 6)
# In the loop. Search space: 213 Searched: 836
# ## Found edge! Between (6, 1, 7) and (6, 2, 7)
# ## Found edge! Between (6, 1, 7) and (7, 1, 7)
# In the loop. Search space: 213 Searched: 837
# ## Found edge! Between (10, 3, 3) and (10, 3, 4)
# ## Found edge! Between (10, 3, 3) and (10, 4, 3)
# ## Found edge! Between (10, 3, 3) and (11, 3, 3)
# ## Found edge! Between (10, 3, 3) and (9, 3, 3)
# In the loop. Search space: 212 Searched: 838
# ## Found edge! Between (10, 7, 1) and (10, 7, 2)
# ## Found edge! Between (10, 7, 1) and (10, 8, 1)
# ## Found edge! Between (10, 7, 1) and (11, 7, 1)
# ## Found edge! Between (10, 7, 1) and (9, 7, 1)
# In the loop. Search space: 211 Searched: 839
# In the loop. Search space: 212 Searched: 840
# In the loop. Search space: 213 Searched: 841
# In the loop. Search space: 212 Searched: 842
# In the loop. Search space: 211 Searched: 843
# ## Found edge! Between (8, 6, 1) and (8, 6, 2)
# ## Found edge! Between (8, 6, 1) and (8, 7, 1)
# ## Found edge! Between (8, 6, 1) and (9, 6, 1)
# In the loop. Search space: 210 Searched: 844
# ## Found edge! Between (2, 9, 3) and (2, 9, 4)
# ## Found edge! Between (2, 9, 3) and (3, 9, 3)
# In the loop. Search space: 209 Searched: 845
# In the loop. Search space: 208 Searched: 846
# In the loop. Search space: 207 Searched: 847
# In the loop. Search space: 207 Searched: 848
# ## Found edge! Between (11, 7, 0) and (11, 7, 1)
# ## Found edge! Between (11, 7, 0) and (11, 8, 0)
# In the loop. Search space: 208 Searched: 849
# In the loop. Search space: 207 Searched: 850
# In the loop. Search space: 206 Searched: 851
# ## Found edge! Between (2, 6, 6) and (2, 6, 7)
# ## Found edge! Between (2, 6, 6) and (2, 7, 6)
# ## Found edge! Between (2, 6, 6) and (3, 6, 6)
# ## Found edge! Between (2, 6, 6) and (2, 5, 6)
# In the loop. Search space: 205 Searched: 852
# In the loop. Search space: 205 Searched: 853
# In the loop. Search space: 205 Searched: 854
# In the loop. Search space: 206 Searched: 855
# In the loop. Search space: 205 Searched: 856
# In the loop. Search space: 206 Searched: 857
# ## Found edge! Between (9, 2, 3) and (9, 3, 3)
# In the loop. Search space: 205 Searched: 858
# In the loop. Search space: 205 Searched: 859
# In the loop. Search space: 205 Searched: 860
# In the loop. Search space: 204 Searched: 861
# In the loop. Search space: 203 Searched: 862
# In the loop. Search space: 203 Searched: 863
# In the loop. Search space: 205 Searched: 864
# In the loop. Search space: 205 Searched: 865
# In the loop. Search space: 205 Searched: 866
# In the loop. Search space: 205 Searched: 867
# ## Found edge! Between (12, 3, 3) and (12, 3, 4)
# ## Found edge! Between (12, 3, 3) and (12, 4, 3)
# ## Found edge! Between (12, 3, 3) and (11, 3, 3)
# In the loop. Search space: 205 Searched: 868
# In the loop. Search space: 208 Searched: 869
# In the loop. Search space: 208 Searched: 870
# In the loop. Search space: 207 Searched: 871
# In the loop. Search space: 206 Searched: 872
# ## Found edge! Between (9, 2, 5) and (9, 2, 6)
# ...
# In the loop. Search space: 171 Searched: 7131
# In the loop. Search space: 170 Searched: 7132
# In the loop. Search space: 169 Searched: 7133
# In the loop. Search space: 169 Searched: 7134
# In the loop. Search space: 168 Searched: 7135
# In the loop. Search space: 168 Searched: 7136
# In the loop. Search space: 167 Searched: 7137
# ## Found edge! Between (12, 16, 14) and (12, 16, 15)
# ## Found edge! Between (12, 16, 14) and (13, 16, 14)
# ## Found edge! Between (12, 16, 14) and (12, 16, 13)
# ## Found edge! Between (12, 16, 14) and (12, 15, 14)
# ## Found edge! Between (12, 16, 14) and (11, 16, 14)
# In the loop. Search space: 166 Searched: 7138
# In the loop. Search space: 165 Searched: 7139
# In the loop. Search space: 165 Searched: 7140
# In the loop. Search space: 164 Searched: 7141
# In the loop. Search space: 164 Searched: 7142
# In the loop. Search space: 164 Searched: 7143
# In the loop. Search space: 164 Searched: 7144
# ## Found edge! Between (11, 17, 15) and (11, 16, 15)
# In the loop. Search space: 163 Searched: 7145
# In the loop. Search space: 163 Searched: 7146
# In the loop. Search space: 163 Searched: 7147
# In the loop. Search space: 163 Searched: 7148
# In the loop. Search space: 162 Searched: 7149
# In the loop. Search space: 162 Searched: 7150
# In the loop. Search space: 161 Searched: 7151
# In the loop. Search space: 161 Searched: 7152
# In the loop. Search space: 160 Searched: 7153
# In the loop. Search space: 160 Searched: 7154
# In the loop. Search space: 160 Searched: 7155
# In the loop. Search space: 159 Searched: 7156
# In the loop. Search space: 158 Searched: 7157
# In the loop. Search space: 157 Searched: 7158
# ## Found edge! Between (10, 19, 13) and (10, 18, 13)
# In the loop. Search space: 156 Searched: 7159
# In the loop. Search space: 155 Searched: 7160
# In the loop. Search space: 155 Searched: 7161
# In the loop. Search space: 154 Searched: 7162
# In the loop. Search space: 156 Searched: 7163
# In the loop. Search space: 156 Searched: 7164
# In the loop. Search space: 155 Searched: 7165
# In the loop. Search space: 156 Searched: 7166
# In the loop. Search space: 156 Searched: 7167
# In the loop. Search space: 157 Searched: 7168
# In the loop. Search space: 156 Searched: 7169
# In the loop. Search space: 155 Searched: 7170
# In the loop. Search space: 155 Searched: 7171
# In the loop. Search space: 155 Searched: 7172
# In the loop. Search space: 155 Searched: 7173
# In the loop. Search space: 154 Searched: 7174
# In the loop. Search space: 154 Searched: 7175
# In the loop. Search space: 154 Searched: 7176
# In the loop. Search space: 154 Searched: 7177
# In the loop. Search space: 153 Searched: 7178
# In the loop. Search space: 153 Searched: 7179
# In the loop. Search space: 153 Searched: 7180
# In the loop. Search space: 154 Searched: 7181
# In the loop. Search space: 153 Searched: 7182
# In the loop. Search space: 152 Searched: 7183
# In the loop. Search space: 152 Searched: 7184
# In the loop. Search space: 151 Searched: 7185
# In the loop. Search space: 150 Searched: 7186
# In the loop. Search space: 149 Searched: 7187
# In the loop. Search space: 148 Searched: 7188
# In the loop. Search space: 147 Searched: 7189
# In the loop. Search space: 147 Searched: 7190
# In the loop. Search space: 146 Searched: 7191
# In the loop. Search space: 146 Searched: 7192
# ## Found edge! Between (13, 14, 15) and (13, 14, 16)
# ## Found edge! Between (13, 14, 15) and (14, 14, 15)
# ## Found edge! Between (13, 14, 15) and (13, 14, 14)
# ## Found edge! Between (13, 14, 15) and (13, 13, 15)
# ## Found edge! Between (13, 14, 15) and (12, 14, 15)
# In the loop. Search space: 145 Searched: 7193
# In the loop. Search space: 144 Searched: 7194
# In the loop. Search space: 143 Searched: 7195
# In the loop. Search space: 142 Searched: 7196
# In the loop. Search space: 141 Searched: 7197
# In the loop. Search space: 140 Searched: 7198
# In the loop. Search space: 139 Searched: 7199
# In the loop. Search space: 139 Searched: 7200
# In the loop. Search space: 140 Searched: 7201
# In the loop. Search space: 139 Searched: 7202
# In the loop. Search space: 139 Searched: 7203
# In the loop. Search space: 138 Searched: 7204
# In the loop. Search space: 139 Searched: 7205
# In the loop. Search space: 141 Searched: 7206
# In the loop. Search space: 140 Searched: 7207
# In the loop. Search space: 140 Searched: 7208
# In the loop. Search space: 140 Searched: 7209
# In the loop. Search space: 140 Searched: 7210
# In the loop. Search space: 139 Searched: 7211
# In the loop. Search space: 139 Searched: 7212
# In the loop. Search space: 138 Searched: 7213
# In the loop. Search space: 137 Searched: 7214
# In the loop. Search space: 136 Searched: 7215
# In the loop. Search space: 136 Searched: 7216
# In the loop. Search space: 136 Searched: 7217
# In the loop. Search space: 135 Searched: 7218
# In the loop. Search space: 135 Searched: 7219
# In the loop. Search space: 134 Searched: 7220
# In the loop. Search space: 133 Searched: 7221
# In the loop. Search space: 133 Searched: 7222
# In the loop. Search space: 133 Searched: 7223
# In the loop. Search space: 132 Searched: 7224
# ## Found edge! Between (12, 17, 15) and (12, 16, 15)
# In the loop. Search space: 131 Searched: 7225
# In the loop. Search space: 131 Searched: 7226
# In the loop. Search space: 130 Searched: 7227
# In the loop. Search space: 130 Searched: 7228
# In the loop. Search space: 129 Searched: 7229
# In the loop. Search space: 130 Searched: 7230
# In the loop. Search space: 130 Searched: 7231
# In the loop. Search space: 129 Searched: 7232
# In the loop. Search space: 128 Searched: 7233
# In the loop. Search space: 128 Searched: 7234
# In the loop. Search space: 128 Searched: 7235
# In the loop. Search space: 128 Searched: 7236
# In the loop. Search space: 128 Searched: 7237
# In the loop. Search space: 127 Searched: 7238
# In the loop. Search space: 126 Searched: 7239
# In the loop. Search space: 126 Searched: 7240
# In the loop. Search space: 125 Searched: 7241
# In the loop. Search space: 124 Searched: 7242
# In the loop. Search space: 124 Searched: 7243
# In the loop. Search space: 123 Searched: 7244
# In the loop. Search space: 123 Searched: 7245
# In the loop. Search space: 122 Searched: 7246
# In the loop. Search space: 122 Searched: 7247
# In the loop. Search space: 121 Searched: 7248
# In the loop. Search space: 121 Searched: 7249
# In the loop. Search space: 122 Searched: 7250
# In the loop. Search space: 122 Searched: 7251
# In the loop. Search space: 121 Searched: 7252
# In the loop. Search space: 120 Searched: 7253
# In the loop. Search space: 120 Searched: 7254
# In the loop. Search space: 120 Searched: 7255
# In the loop. Search space: 120 Searched: 7256
# In the loop. Search space: 119 Searched: 7257
# In the loop. Search space: 119 Searched: 7258
# In the loop. Search space: 118 Searched: 7259
# In the loop. Search space: 117 Searched: 7260
# In the loop. Search space: 117 Searched: 7261
# In the loop. Search space: 116 Searched: 7262
# In the loop. Search space: 116 Searched: 7263
# In the loop. Search space: 117 Searched: 7264
# In the loop. Search space: 117 Searched: 7265
# In the loop. Search space: 116 Searched: 7266
# In the loop. Search space: 115 Searched: 7267
# In the loop. Search space: 116 Searched: 7268
# In the loop. Search space: 116 Searched: 7269
# In the loop. Search space: 115 Searched: 7270
# In the loop. Search space: 114 Searched: 7271
# In the loop. Search space: 114 Searched: 7272
# In the loop. Search space: 115 Searched: 7273
# In the loop. Search space: 114 Searched: 7274
# In the loop. Search space: 113 Searched: 7275
# In the loop. Search space: 112 Searched: 7276
# In the loop. Search space: 112 Searched: 7277
# In the loop. Search space: 111 Searched: 7278
# In the loop. Search space: 110 Searched: 7279
# In the loop. Search space: 109 Searched: 7280
# In the loop. Search space: 108 Searched: 7281
# In the loop. Search space: 108 Searched: 7282
# In the loop. Search space: 107 Searched: 7283
# In the loop. Search space: 107 Searched: 7284
# In the loop. Search space: 107 Searched: 7285
# In the loop. Search space: 106 Searched: 7286
# In the loop. Search space: 106 Searched: 7287
# In the loop. Search space: 107 Searched: 7288
# In the loop. Search space: 106 Searched: 7289
# In the loop. Search space: 105 Searched: 7290
# In the loop. Search space: 104 Searched: 7291
# In the loop. Search space: 106 Searched: 7292
# In the loop. Search space: 106 Searched: 7293
# In the loop. Search space: 105 Searched: 7294
# In the loop. Search space: 105 Searched: 7295
# In the loop. Search space: 104 Searched: 7296
# In the loop. Search space: 104 Searched: 7297
# In the loop. Search space: 105 Searched: 7298
# In the loop. Search space: 104 Searched: 7299
# In the loop. Search space: 103 Searched: 7300
# In the loop. Search space: 102 Searched: 7301
# In the loop. Search space: 102 Searched: 7302
# In the loop. Search space: 101 Searched: 7303
# In the loop. Search space: 101 Searched: 7304
# In the loop. Search space: 100 Searched: 7305
# In the loop. Search space: 100 Searched: 7306
# In the loop. Search space: 99 Searched: 7307
# In the loop. Search space: 98 Searched: 7308
# In the loop. Search space: 98 Searched: 7309
# In the loop. Search space: 98 Searched: 7310
# In the loop. Search space: 97 Searched: 7311
# In the loop. Search space: 96 Searched: 7312
# In the loop. Search space: 96 Searched: 7313
# In the loop. Search space: 95 Searched: 7314
# In the loop. Search space: 94 Searched: 7315
# In the loop. Search space: 94 Searched: 7316
# In the loop. Search space: 94 Searched: 7317
# In the loop. Search space: 93 Searched: 7318
# In the loop. Search space: 93 Searched: 7319
# In the loop. Search space: 92 Searched: 7320
# In the loop. Search space: 92 Searched: 7321
# In the loop. Search space: 92 Searched: 7322
# In the loop. Search space: 92 Searched: 7323
# In the loop. Search space: 92 Searched: 7324
# In the loop. Search space: 91 Searched: 7325
# In the loop. Search space: 91 Searched: 7326
# In the loop. Search space: 90 Searched: 7327
# In the loop. Search space: 89 Searched: 7328
# In the loop. Search space: 88 Searched: 7329
# In the loop. Search space: 87 Searched: 7330
# In the loop. Search space: 87 Searched: 7331
# In the loop. Search space: 86 Searched: 7332
# In the loop. Search space: 86 Searched: 7333
# In the loop. Search space: 85 Searched: 7334
# In the loop. Search space: 84 Searched: 7335
# In the loop. Search space: 84 Searched: 7336
# In the loop. Search space: 84 Searched: 7337
# In the loop. Search space: 83 Searched: 7338
# In the loop. Search space: 82 Searched: 7339
# In the loop. Search space: 82 Searched: 7340
# In the loop. Search space: 81 Searched: 7341
# In the loop. Search space: 81 Searched: 7342
# In the loop. Search space: 82 Searched: 7343
# In the loop. Search space: 81 Searched: 7344
# In the loop. Search space: 80 Searched: 7345
# In the loop. Search space: 80 Searched: 7346
# In the loop. Search space: 79 Searched: 7347
# In the loop. Search space: 78 Searched: 7348
# In the loop. Search space: 78 Searched: 7349
# In the loop. Search space: 77 Searched: 7350
# In the loop. Search space: 77 Searched: 7351
# In the loop. Search space: 77 Searched: 7352
# In the loop. Search space: 77 Searched: 7353
# In the loop. Search space: 76 Searched: 7354
# In the loop. Search space: 75 Searched: 7355
# In the loop. Search space: 74 Searched: 7356
# In the loop. Search space: 73 Searched: 7357
# In the loop. Search space: 72 Searched: 7358
# In the loop. Search space: 72 Searched: 7359
# In the loop. Search space: 72 Searched: 7360
# In the loop. Search space: 71 Searched: 7361
# In the loop. Search space: 70 Searched: 7362
# In the loop. Search space: 70 Searched: 7363
# In the loop. Search space: 69 Searched: 7364
# In the loop. Search space: 69 Searched: 7365
# In the loop. Search space: 69 Searched: 7366
# In the loop. Search space: 68 Searched: 7367
# In the loop. Search space: 67 Searched: 7368
# In the loop. Search space: 67 Searched: 7369
# In the loop. Search space: 66 Searched: 7370
# In the loop. Search space: 65 Searched: 7371
# In the loop. Search space: 64 Searched: 7372
# In the loop. Search space: 63 Searched: 7373
# In the loop. Search space: 62 Searched: 7374
# In the loop. Search space: 62 Searched: 7375
# In the loop. Search space: 61 Searched: 7376
# In the loop. Search space: 61 Searched: 7377
# In the loop. Search space: 61 Searched: 7378
# In the loop. Search space: 61 Searched: 7379
# In the loop. Search space: 60 Searched: 7380
# In the loop. Search space: 59 Searched: 7381
# In the loop. Search space: 58 Searched: 7382
# In the loop. Search space: 57 Searched: 7383
# In the loop. Search space: 57 Searched: 7384
# In the loop. Search space: 56 Searched: 7385
# In the loop. Search space: 55 Searched: 7386
# In the loop. Search space: 54 Searched: 7387
# In the loop. Search space: 53 Searched: 7388
# In the loop. Search space: 52 Searched: 7389
# In the loop. Search space: 52 Searched: 7390
# In the loop. Search space: 52 Searched: 7391
# In the loop. Search space: 52 Searched: 7392
# In the loop. Search space: 51 Searched: 7393
# In the loop. Search space: 50 Searched: 7394
# In the loop. Search space: 49 Searched: 7395
# In the loop. Search space: 49 Searched: 7396
# In the loop. Search space: 48 Searched: 7397
# In the loop. Search space: 47 Searched: 7398
# In the loop. Search space: 46 Searched: 7399
# In the loop. Search space: 46 Searched: 7400
# In the loop. Search space: 45 Searched: 7401
# In the loop. Search space: 45 Searched: 7402
# In the loop. Search space: 45 Searched: 7403
# In the loop. Search space: 45 Searched: 7404
# In the loop. Search space: 45 Searched: 7405
# In the loop. Search space: 45 Searched: 7406
# In the loop. Search space: 45 Searched: 7407
# In the loop. Search space: 44 Searched: 7408
# In the loop. Search space: 43 Searched: 7409
# In the loop. Search space: 42 Searched: 7410
# In the loop. Search space: 41 Searched: 7411
# In the loop. Search space: 40 Searched: 7412
# In the loop. Search space: 40 Searched: 7413
# In the loop. Search space: 39 Searched: 7414
# In the loop. Search space: 39 Searched: 7415
# In the loop. Search space: 39 Searched: 7416
# In the loop. Search space: 38 Searched: 7417
# In the loop. Search space: 37 Searched: 7418
# In the loop. Search space: 36 Searched: 7419
# In the loop. Search space: 35 Searched: 7420
# In the loop. Search space: 34 Searched: 7421
# In the loop. Search space: 34 Searched: 7422
# In the loop. Search space: 33 Searched: 7423
# In the loop. Search space: 33 Searched: 7424
# In the loop. Search space: 33 Searched: 7425
# In the loop. Search space: 32 Searched: 7426
# In the loop. Search space: 31 Searched: 7427
# In the loop. Search space: 30 Searched: 7428
# In the loop. Search space: 30 Searched: 7429
# In the loop. Search space: 29 Searched: 7430
# In the loop. Search space: 29 Searched: 7431
# In the loop. Search space: 29 Searched: 7432
# In the loop. Search space: 29 Searched: 7433
# In the loop. Search space: 28 Searched: 7434
# In the loop. Search space: 27 Searched: 7435
# In the loop. Search space: 26 Searched: 7436
# In the loop. Search space: 25 Searched: 7437
# In the loop. Search space: 24 Searched: 7438
# In the loop. Search space: 23 Searched: 7439
# In the loop. Search space: 22 Searched: 7440
# In the loop. Search space: 21 Searched: 7441
# In the loop. Search space: 20 Searched: 7442
# In the loop. Search space: 20 Searched: 7443
# In the loop. Search space: 19 Searched: 7444
# In the loop. Search space: 19 Searched: 7445
# In the loop. Search space: 19 Searched: 7446
# In the loop. Search space: 18 Searched: 7447
# In the loop. Search space: 17 Searched: 7448
# In the loop. Search space: 16 Searched: 7449
# In the loop. Search space: 16 Searched: 7450
# In the loop. Search space: 16 Searched: 7451
# In the loop. Search space: 15 Searched: 7452
# In the loop. Search space: 14 Searched: 7453
# In the loop. Search space: 13 Searched: 7454
# In the loop. Search space: 12 Searched: 7455
# In the loop. Search space: 11 Searched: 7456
# In the loop. Search space: 10 Searched: 7457
# In the loop. Search space: 9 Searched: 7458
# In the loop. Search space: 8 Searched: 7459
# In the loop. Search space: 7 Searched: 7460
# In the loop. Search space: 6 Searched: 7461
# In the loop. Search space: 5 Searched: 7462
# In the loop. Search space: 4 Searched: 7463
# In the loop. Search space: 3 Searched: 7464
# In the loop. Search space: 2 Searched: 7465
# In the loop. Search space: 1 Searched: 7466
# 2048

# %% [markdown]
# 2041 is too low
#
# Hmm... worked for test data... why wouldn't it work for puzzle data?
#
# Eyeballing the puzzle data again... there is some zero values, so it's up against the edge. No biggie.
#
# 2048 is the right answer... ha! of course it is ;)
