# %% [markdown]
# # Day 14: Regolith Reservoir
#
# ## Approach
#
# 1. Turn paths into a grid pattern of ints. Use the int value to determine type of material: 0 = air, 1 = rock, 2 = sand
# 2. Will need to examine the bounds fo the path to work out what size of grid we're working with. It's not zero,zero set and we need to know when sand falls off the bounds of this -> i.e. falling into the abyss
# 3. We need to track sand as it falls. If it falls into the abyss then it doesn't get included in our total.
#
# Note: sand input always appears to be 500,0 - but should probably parameterise this.

# %%
testInput = """498,4 -> 498,6 -> 496,6
503,4 -> 502,4 -> 502,9 -> 494,9"""

testSandInput = (500,0)

class Cave:
    def __init__(self, pathsInput:str, sandPourPoint:tuple[int,int]):
        self.minX = 1000000 #a very large numbers
        self.maxX = 0
        self.minY = 1000000 #a very large numbers
        self.maxY = 0
        self.grid = [] #grid will be offset by minX,maxX
        self.sandPourPoint = sandPourPoint
        self.minX = min(self.minX,sandPourPoint[0])
        self.maxX = max(self.maxX,sandPourPoint[0])
        self.minY = min(self.minY,sandPourPoint[1])
        self.maxY = max(self.maxY,sandPourPoint[1])

        #parse the input
        paths = []
        for r in pathsInput.splitlines():
            path = []
            chunks = r.split(' -> ')
            for c in chunks:
                coords = c.split(',')
                x = int(coords[0])
                y = int(coords[1])
                self.minX = min(self.minX,x)
                self.maxX = max(self.maxX,x)
                self.minY = min(self.minY,y)
                self.maxY = max(self.maxY,y)
                path.append((x,y))
            paths.append(path)
        #we now know the bounds of our grid
        print('Field of play: '+str(self.minX)+','+str(self.minY)+':'+str(self.maxX)+','+str(self.maxY))

        self.gridWidth = self.maxX - self.minX
        self.gridHeight = self.maxY - self.minY      

        #build an empty grid
        for x in range(self.minX, self.maxX + 1, 1):
            xrow = []
            for y in range(self.minY, self.maxY +1, 1):
                xrow.append(0)
            self.grid.append(xrow)
        

        #populate the rock
        for path in paths:
            x = -1
            y = -1
            for point in path:
                if x == -1: #first point
                    x = point[0]
                    y = point[1]
                else:
                    dx = point[0] - x
                    dy = point[1] - y
                    #only one of dx or dy should be non-zero
                    if dx!=0:
                        #draw path in x direction
                        #need to know direction
                        step = int(dx / abs(dx))
                        gridStart = x - self.minX
                        gridFinish = point[0] + (1 * step) - self.minX #out by one errors on the boundaries
                        gridY = y - self.minY
                        for gridX in range(gridStart,gridFinish,step):
                            self.grid[gridX][gridY] = 1
                    else:
                        #draw path in y direction
                        step = int(dy / abs(dy))
                        gridStart = y - self.minY
                        gridFinish = point[1] + (1 * step) - self.minY
                        gridX = x - self.minX
                        for gridY in range(gridStart,gridFinish,step):
                            self.grid[gridX][gridY] = 1
                    #update last point
                    x = point[0]
                    y = point[1]
                    #print('---')
                    #print(self)

    def __str__(self):
        #print columns 0> and rows 0down
        outputStr = ''
        for y in range(self.gridHeight+1):
            rowStr = ''
            for x in range(self.gridWidth+1):
                match self.grid[x][y]:
                    case 0:
                        rowStr = rowStr + '.'
                    case 1:
                        rowStr = rowStr + '#'
                    case 2:
                        rowStr = rowStr + 'o'
            outputStr = outputStr + '\n' + rowStr
        return outputStr

    def outOfBounds(self, pos:tuple[int,int]):
        #check if the position is out of bounds - used to check if the sand will fall forever.
        return pos[0] < 0 or pos[0] > self.gridWidth or pos[1] < 0 or pos[1] > self.gridHeight

    def pourSand(self):
        #pour sand one chunk at a time
        abyss = False
        sandCounter = -1 #sandCounter will always over count 1, because it will also count the sand that falls to they abyss... so we coutneract that by starting at -1
        while not abyss: #we might revisit this condition later, but expect to break
            #loop of each bit of sand, so we stat with sand at the sand pouring point
            sandCounter += 1
            print(str(sandCounter) + ' units of sand')
            sandPos = (self.sandPourPoint[0]-self.minX,self.sandPourPoint[1]-self.minY)
            sandMoving = True
            while sandMoving and not abyss: 
                #A unit of sand always falls down one step if possible
                downOne = (sandPos[0],sandPos[1]+1)
                diagLeft = (sandPos[0]-1,sandPos[1]+1)
                diagRigth = (sandPos[0]+1,sandPos[1]+1)
                if self.outOfBounds(downOne):
                    abyss = True
                elif self.grid[downOne[0]][downOne[1]] == 0:
                    sandPos = downOne
                elif self.outOfBounds(diagLeft):
                    abyss = True
                elif self.grid[diagLeft[0]][diagLeft[1]] == 0:
                    sandPos = diagLeft
                elif self.outOfBounds(diagRigth):
                    abyss = True
                elif self.grid[diagRigth[0]][diagRigth[1]] == 0:
                    sandPos = diagRigth 
                else:
                    #sand has stopped
                    self.grid[sandPos[0]][sandPos[1]] = 2
                    sandMoving = False
        
        #print(str(sandCounter) + ' units of sand have come to rest')

#test
testCave = Cave(testInput, testSandInput)
print(testCave)
testCave.pourSand()
# Out:
# Field of play: 494,0:503,9
#
# ..........
# ..........
# ..........
# ..........
# ....#...##
# ....#...#.
# ..###...#.
# ........#.
# ........#.
# #########.
# 0 units of sand
# 1 units of sand
# 2 units of sand
# 3 units of sand
# 4 units of sand
# 5 units of sand
# 6 units of sand
# 7 units of sand
# 8 units of sand
# 9 units of sand
# 10 units of sand
# 11 units of sand
# 12 units of sand
# 13 units of sand
# 14 units of sand
# 15 units of sand
# 16 units of sand
# 17 units of sand
# 18 units of sand
# 19 units of sand
# 20 units of sand
# 21 units of sand
# 22 units of sand
# 23 units of sand
# 24 units of sand
# 24units of snad have come to rest

# %%
#real fun
input = open('day14input.txt').read()
realCave = Cave(input, testSandInput)
print(realCave)
realCave.pourSand()
# Out:
# Field of play: 486,0:571,171
#
# ......................................................................................
# ......................................................................................
# ......................................................................................
# ......................................................................................
# ......................................................................................
# ......................................................................................
# ......................................................................................
# ......................................................................................
# ......................................................................................
# ......................................................................................
# ......................................................................................
# ......................................................................................
# ......................................................................................
# ......................................................................................
# ........#..........#..................................................................
# ........############..................................................................
# ......................................................................................
# ......................................................................................
# ..................#####...............................................................
# ......................................................................................
# ...............#####.#####............................................................
# ......................................................................................
# ............#####.#####.#####.........................................................
# ......................................................................................
# .........#####.#####.#####.#####......................................................
# ......................................................................................
# ......................................................................................
# ......................................................................................
# ....#.#...............................................................................
# ....#.#...............................................................................
# ....#.#.#.............................................................................
# ....#.#.#.............................................................................
# ....#.#.#.............................................................................
# ....#.#.#.............................................................................
# #.#.#.#.#.............................................................................
# #.#.#.#.#.............................................................................
# #.#.#.#.#.#.#.........................................................................
# #############.........................................................................
# ......................................................................................
# ......................................................................................
# .........#............................................................................
# .........#.....#......................................................................
# .........#.....#......................................................................
# .........#.#.#.#......................................................................
# .........#.#.#.#......................................................................
# .........#.#.#.#......................................................................
# .........#.#.#.#......................................................................
# .........#.#.#.#......................................................................
# .........#.#.#.#......................................................................
# .........#.#.#.#......................................................................
# .........#######......................................................................
# ......................................................................................
# ......................................................................................
# .............#.....#..................................................................
# .............#.....#..................................................................
# .............#.....#..................................................................
# .............#.....#..................................................................
# .....#########.....#########..........................................................
# .....#.....................#..........................................................
# .....#.....................#..........................................................
# .....#.....................#..........................................................
# .....#.....................#..........................................................
# .....#.....................#..........................................................
# .....#######################..........................................................
# ......................................................................................
# ......................................................................................
# ..........................#...#.......................................................
# ..........................#...#.......................................................
# ..........................#...#.......................................................
# ..........................#...#.......................................................
# ...................########...######..................................................
# ...................#...............#..................................................
# ...................#...............#..................................................
# ...................#...............#..................................................
# ...................#...............#..................................................
# ...................#...............#..................................................
# ...................#...............#..................................................
# ...................#...............#..................................................
# ...................#################..................................................
# ......................................................................................
# ......................................................................................
# .................................######...............................................
# ......................................................................................
# ......................................................................................
# ..............................######.######...........................................
# ......................................................................................
# ......................................................................................
# ...........................######.######.######.......................................
# ......................................................................................
# ......................................................................................
# ........................######.######.######.######...................................
# ......................................................................................
# ......................................................................................
# ............................#...#.....................................................
# ............................#...#.....................................................
# ............................#...#.....................................................
# ............................#...#.....................................................
# ....................#########...######................................................
# ....................#................#................................................
# ....................#................#................................................
# ....................#................#................................................
# ....................##################................................................
# ......................................................................................
# ......................................................................................
# ....................................#####.............................................
# ......................................................................................
# .................................#####.#####..........................................
# ......................................................................................
# ..............................#####.#####.#####.......................................
# ......................................................................................
# ......................................................................................
# ......................................................................................
# ..........................................###############.............................
# ......................................................................................
# ......................................................................................
# ......................................................................................
# .......................................................#.......#......................
# .......................................................#########......................
# ......................................................................................
# ......................................................................................
# ......................................................................................
# ......................................................................................
# ........................................................#.............................
# ............................................#.....#.....#.............................
# ............................................#.....#.#...#.............................
# ............................................#.....#.#...#...#.#.......................
# ............................................#.#...#.#.#.#...#.#.......................
# ............................................#.#...#.#.#.#.#.#.#.......................
# ............................................#.#.#.#.#.#.#.#.#.#.......................
# ............................................#.#.#.#.#.#.#.#.#.#.......................
# ............................................###################.......................
# ......................................................................................
# ......................................................#...........#...................
# ......................................................#############...................
# ......................................................................................
# ......................................................................................
# ................................................................######................
# ......................................................................................
# ......................................................................................
# .............................................................######.######............
# ......................................................................................
# ......................................................................................
# ..........................................................######.######.######........
# ......................................................................................
# ......................................................................................
# .......................................................######.######.######.######....
# ......................................................................................
# ......................................................................................
# ....................................................######.######.######.######.######
# ......................................................................................
# ......................................................................................
# ........................................................#.............................
# ........................................................#.............................
# ......................................................#.#.............................
# ..................................................#...#.#.............................
# ..................................................#...#.#.............................
# ..................................................#.#.#.#...#.........................
# ................................................#.#.#.#.#...#.........................
# ................................................#.#.#.#.#...#.........................
# ................................................#.#.#.#.#...#.#.#.#...................
# ................................................#.#.#.#.#.#.#.#.#.#...................
# ................................................###################...................
# ......................................................................................
# ......................................................................................
# .................................................................#...#................
# .................................................................#...#................
# .................................................................#...#................
# .................................................................#...#................
# ............................................................######...##...............
# ............................................................#.........#...............
# ............................................................#.........#...............
# ............................................................###########...............
# 0 units of sand
# 1 units of sand
# 2 units of sand
# 3 units of sand
# 4 units of sand
# 5 units of sand
# 6 units of sand
# 7 units of sand
# 8 units of sand
# 9 units of sand
# 10 units of sand
# 11 units of sand
# 12 units of sand
# 13 units of sand
# 14 units of sand
# 15 units of sand
# 16 units of sand
# 17 units of sand
# 18 units of sand
# 19 units of sand
# 20 units of sand
# 21 units of sand
# 22 units of sand
# 23 units of sand
# 24 units of sand
# 25 units of sand
# 26 units of sand
# 27 units of sand
# 28 units of sand
# 29 units of sand
# 30 units of sand
# 31 units of sand
# 32 units of sand
# 33 units of sand
# 34 units of sand
# 35 units of sand
# 36 units of sand
# 37 units of sand
# 38 units of sand
# 39 units of sand
# 40 units of sand
# 41 units of sand
# 42 units of sand
# 43 units of sand
# 44 units of sand
# 45 units of sand
# 46 units of sand
# 47 units of sand
# 48 units of sand
# 49 units of sand
# 50 units of sand
# 51 units of sand
# 52 units of sand
# 53 units of sand
# 54 units of sand
# 55 units of sand
# 56 units of sand
# 57 units of sand
# 58 units of sand
# 59 units of sand
# 60 units of sand
# 61 units of sand
# 62 units of sand
# 63 units of sand
# 64 units of sand
# 65 units of sand
# 66 units of sand
# 67 units of sand
# 68 units of sand
# 69 units of sand
# 70 units of sand
# 71 units of sand
# 72 units of sand
# 73 units of sand
# 74 units of sand
# 75 units of sand
# 76 units of sand
# 77 units of sand
# 78 units of sand
# 79 units of sand
# 80 units of sand
# 81 units of sand
# 82 units of sand
# 83 units of sand
# 84 units of sand
# 85 units of sand
# 86 units of sand
# 87 units of sand
# 88 units of sand
# 89 units of sand
# 90 units of sand
# 91 units of sand
# 92 units of sand
# 93 units of sand
# 94 units of sand
# 95 units of sand
# 96 units of sand
# 97 units of sand
# 98 units of sand
# 99 units of sand
# 100 units of sand
# 101 units of sand
# 102 units of sand
# 103 units of sand
# 104 units of sand
# 105 units of sand
# 106 units of sand
# 107 units of sand
# 108 units of sand
# 109 units of sand
# 110 units of sand
# 111 units of sand
# 112 units of sand
# 113 units of sand
# 114 units of sand
# 115 units of sand
# 116 units of sand
# 117 units of sand
# 118 units of sand
# 119 units of sand
# 120 units of sand
# 121 units of sand
# 122 units of sand
# 123 units of sand
# 124 units of sand
# 125 units of sand
# 126 units of sand
# 127 units of sand
# 128 units of sand
# 129 units of sand
# 130 units of sand
# 131 units of sand
# 132 units of sand
# 133 units of sand
# 134 units of sand
# 135 units of sand
# 136 units of sand
# 137 units of sand
# 138 units of sand
# 139 units of sand
# 140 units of sand
# 141 units of sand
# 142 units of sand
# 143 units of sand
# 144 units of sand
# 145 units of sand
# 146 units of sand
# 147 units of sand
# 148 units of sand
# 149 units of sand
# 150 units of sand
# 151 units of sand
# 152 units of sand
# 153 units of sand
# 154 units of sand
# 155 units of sand
# 156 units of sand
# 157 units of sand
# 158 units of sand
# 159 units of sand
# 160 units of sand
# 161 units of sand
# 162 units of sand
# 163 units of sand
# 164 units of sand
# 165 units of sand
# 166 units of sand
# 167 units of sand
# 168 units of sand
# 169 units of sand
# 170 units of sand
# 171 units of sand
# 172 units of sand
# 173 units of sand
# 174 units of sand
# 175 units of sand
# 176 units of sand
# 177 units of sand
# 178 units of sand
# 179 units of sand
# 180 units of sand
# 181 units of sand
# 182 units of sand
# 183 units of sand
# 184 units of sand
# 185 units of sand
# 186 units of sand
# 187 units of sand
# 188 units of sand
# 189 units of sand
# 190 units of sand
# 191 units of sand
# 192 units of sand
# 193 units of sand
# 194 units of sand
# 195 units of sand
# 196 units of sand
# 197 units of sand
# 198 units of sand
# 199 units of sand
# 200 units of sand
# 201 units of sand
# 202 units of sand
# 203 units of sand
# 204 units of sand
# 205 units of sand
# 206 units of sand
# 207 units of sand
# 208 units of sand
# 209 units of sand
# 210 units of sand
# 211 units of sand
# 212 units of sand
# 213 units of sand
# 214 units of sand
# 215 units of sand
# 216 units of sand
# 217 units of sand
# 218 units of sand
# 219 units of sand
# 220 units of sand
# 221 units of sand
# 222 units of sand
# 223 units of sand
# 224 units of sand
# 225 units of sand
# 226 units of sand
# 227 units of sand
# 228 units of sand
# 229 units of sand
# 230 units of sand
# 231 units of sand
# 232 units of sand
# 233 units of sand
# 234 units of sand
# 235 units of sand
# 236 units of sand
# 237 units of sand
# 238 units of sand
# 239 units of sand
# 240 units of sand
# 241 units of sand
# 242 units of sand
# 243 units of sand
# 244 units of sand
# 245 units of sand
# 246 units of sand
# 247 units of sand
# 248 units of sand
# 249 units of sand
# 250 units of sand
# 251 units of sand
# 252 units of sand
# 253 units of sand
# 254 units of sand
# 255 units of sand
# 256 units of sand
# 257 units of sand
# 258 units of sand
# 259 units of sand
# 260 units of sand
# 261 units of sand
# 262 units of sand
# 263 units of sand
# 264 units of sand
# 265 units of sand
# 266 units of sand
# 267 units of sand
# 268 units of sand
# 269 units of sand
# 270 units of sand
# 271 units of sand
# 272 units of sand
# 273 units of sand
# 274 units of sand
# 275 units of sand
# 276 units of sand
# 277 units of sand
# 278 units of sand
# 279 units of sand
# 280 units of sand
# 281 units of sand
# 282 units of sand
# 283 units of sand
# 284 units of sand
# 285 units of sand
# 286 units of sand
# 287 units of sand
# 288 units of sand
# 289 units of sand
# 290 units of sand
# 291 units of sand
# 292 units of sand
# 293 units of sand
# 294 units of sand
# 295 units of sand
# 296 units of sand
# 297 units of sand
# 298 units of sand
# 299 units of sand
# 300 units of sand
# 301 units of sand
# 302 units of sand
# 303 units of sand
# 304 units of sand
# 305 units of sand
# 306 units of sand
# 307 units of sand
# 308 units of sand
# 309 units of sand
# 310 units of sand
# 311 units of sand
# 312 units of sand
# 313 units of sand
# 314 units of sand
# 315 units of sand
# 316 units of sand
# 317 units of sand
# 318 units of sand
# 319 units of sand
# 320 units of sand
# 321 units of sand
# 322 units of sand
# 323 units of sand
# 324 units of sand
# 325 units of sand
# 326 units of sand
# 327 units of sand
# 328 units of sand
# 329 units of sand
# 330 units of sand
# 331 units of sand
# 332 units of sand
# 333 units of sand
# 334 units of sand
# 335 units of sand
# 336 units of sand
# 337 units of sand
# 338 units of sand
# 339 units of sand
# 340 units of sand
# 341 units of sand
# 342 units of sand
# 343 units of sand
# 344 units of sand
# 345 units of sand
# 346 units of sand
# 347 units of sand
# 348 units of sand
# 349 units of sand
# 350 units of sand
# 351 units of sand
# 352 units of sand
# 353 units of sand
# 354 units of sand
# 355 units of sand
# 356 units of sand
# 357 units of sand
# 358 units of sand
# 359 units of sand
# 360 units of sand
# 361 units of sand
# 362 units of sand
# 363 units of sand
# 364 units of sand
# 365 units of sand
# 366 units of sand
# 367 units of sand
# 368 units of sand
# 369 units of sand
# 370 units of sand
# 371 units of sand
# 372 units of sand
# 373 units of sand
# 374 units of sand
# 375 units of sand
# 376 units of sand
# 377 units of sand
# 378 units of sand
# 379 units of sand
# 380 units of sand
# 381 units of sand
# 382 units of sand
# 383 units of sand
# 384 units of sand
# 385 units of sand
# 386 units of sand
# 387 units of sand
# 388 units of sand
# 389 units of sand
# 390 units of sand
# 391 units of sand
# 392 units of sand
# 393 units of sand
# 394 units of sand
# 395 units of sand
# 396 units of sand
# 397 units of sand
# 398 units of sand
# 399 units of sand
# 400 units of sand
# 401 units of sand
# 402 units of sand
# 403 units of sand
# 404 units of sand
# 405 units of sand
# 406 units of sand
# 407 units of sand
# 408 units of sand
# 409 units of sand
# 410 units of sand
# 411 units of sand
# 412 units of sand
# 413 units of sand
# 414 units of sand
# 415 units of sand
# 416 units of sand
# 417 units of sand
# 418 units of sand
# 419 units of sand
# 420 units of sand
# 421 units of sand
# 422 units of sand
# 423 units of sand
# 424 units of sand
# 425 units of sand
# 426 units of sand
# 427 units of sand
# 428 units of sand
# 429 units of sand
# 430 units of sand
# 431 units of sand
# 432 units of sand
# 433 units of sand
# 434 units of sand
# 435 units of sand
# 436 units of sand
# 437 units of sand
# 438 units of sand
# 439 units of sand
# 440 units of sand
# 441 units of sand
# 442 units of sand
# 443 units of sand
# 444 units of sand
# 445 units of sand
# 446 units of sand
# 447 units of sand
# 448 units of sand
# 449 units of sand
# 450 units of sand
# 451 units of sand
# 452 units of sand
# 453 units of sand
# 454 units of sand
# 455 units of sand
# 456 units of sand
# 457 units of sand
# 458 units of sand
# 459 units of sand
# 460 units of sand
# 461 units of sand
# 462 units of sand
# 463 units of sand
# 464 units of sand
# 465 units of sand
# 466 units of sand
# 467 units of sand
# 468 units of sand
# 469 units of sand
# 470 units of sand
# 471 units of sand
# 472 units of sand
# 473 units of sand
# 474 units of sand
# 475 units of sand
# 476 units of sand
# 477 units of sand
# 478 units of sand
# 479 units of sand
# 480 units of sand
# 481 units of sand
# 482 units of sand
# 483 units of sand
# 484 units of sand
# 485 units of sand
# 486 units of sand
# 487 units of sand
# 488 units of sand
# 489 units of sand
# 490 units of sand
# 491 units of sand
# 492 units of sand
# 493 units of sand
# 494 units of sand
# 495 units of sand
# 496 units of sand
# 497 units of sand
# 498 units of sand
# 499 units of sand
# 500 units of sand
# 501 units of sand
# 502 units of sand
# 503 units of sand
# 504 units of sand
# 505 units of sand
# 506 units of sand
# 507 units of sand
# 508 units of sand
# 509 units of sand
# 510 units of sand
# 511 units of sand
# 512 units of sand
# 513 units of sand
# 514 units of sand
# 515 units of sand
# 516 units of sand
# 517 units of sand
# 518 units of sand
# 519 units of sand
# 520 units of sand
# 521 units of sand
# 522 units of sand
# 523 units of sand
# 524 units of sand
# 525 units of sand
# 526 units of sand
# 527 units of sand
# 528 units of sand
# 529 units of sand
# 530 units of sand
# 531 units of sand
# 532 units of sand
# 533 units of sand
# 534 units of sand
# 535 units of sand
# 536 units of sand
# 537 units of sand
# 538 units of sand
# 539 units of sand
# 540 units of sand
# 541 units of sand
# 542 units of sand
# 543 units of sand
# 544 units of sand
# 545 units of sand
# 546 units of sand
# 547 units of sand
# 548 units of sand
# 549 units of sand
# 550 units of sand
# 551 units of sand
# 552 units of sand
# 553 units of sand
# 554 units of sand
# 555 units of sand
# 556 units of sand
# 557 units of sand
# 558 units of sand
# 559 units of sand
# 560 units of sand
# 561 units of sand
# 562 units of sand
# 563 units of sand
# 564 units of sand
# 565 units of sand
# 566 units of sand
# 567 units of sand
# 568 units of sand
# 569 units of sand
# 570 units of sand
# 571 units of sand
# 572 units of sand
# 573 units of sand
# 574 units of sand
# 575 units of sand
# 576 units of sand
# 577 units of sand
# 578 units of sand
# 579 units of sand
# 580 units of sand
# 581 units of sand
# 582 units of sand
# 583 units of sand
# 584 units of sand
# 585 units of sand
# 586 units of sand
# 587 units of sand
# 588 units of sand
# 589 units of sand
# 590 units of sand
# 591 units of sand
# 592 units of sand
# 593 units of sand
# 594 units of sand
# 595 units of sand
# 596 units of sand
# 597 units of sand
# 598 units of sand
# 599 units of sand
# 600 units of sand
# 601 units of sand
# 602 units of sand
# 603 units of sand
# 604 units of sand
# 605 units of sand
# 606 units of sand
# 607 units of sand
# 608 units of sand
# 609 units of sand
# 610 units of sand
# 611 units of sand
# 612 units of sand
# 613 units of sand
# 614 units of sand
# 615 units of sand
# 616 units of sand
# 617 units of sand
# 618 units of sand
# 619 units of sand
# 620 units of sand
# 621 units of sand
# 622 units of sand
# 623 units of sand
# 624 units of sand
# 625 units of sand
# 626 units of sand
# 627 units of sand
# 628 units of sand
# 629 units of sand
# 630 units of sand
# 631 units of sand
# 632 units of sand
# 633 units of sand
# 634 units of sand
# 635 units of sand
# 636 units of sand
# 637 units of sand
# 638 units of sand
# 639 units of sand
# 640 units of sand
# 641 units of sand
# 642 units of sand
# 643 units of sand
# 644 units of sand
# 645 units of sand
# 646 units of sand
# 647 units of sand
# 648 units of sand
# 649 units of sand
# 650 units of sand
# 651 units of sand
# 652 units of sand
# 653 units of sand
# 654 units of sand
# 655 units of sand
# 656 units of sand
# 657 units of sand
# 658 units of sand
# 659 units of sand
# 660 units of sand
# 661 units of sand
# 662 units of sand
# 663 units of sand
# 664 units of sand
# 665 units of sand
# 666 units of sand
# 667 units of sand
# 668 units of sand
# 669 units of sand
# 670 units of sand
# 671 units of sand
# 672 units of sand
# 673 units of sand
# 674 units of sand
# 675 units of sand
# 676 units of sand
# 677 units of sand
# 678 units of sand
# 679 units of sand
# 680 units of sand
# 681 units of sand
# 682 units of sand
# 683 units of sand
# 684 units of sand
# 685 units of sand
# 686 units of sand
# 687 units of sand
# 688 units of sand
# 689 units of sand
# 690 units of sand
# 691 units of sand
# 692 units of sand
# 693 units of sand
# 694 units of sand
# 695 units of sand
# 696 units of sand
# 697 units of sand
# 698 units of sand
# 699 units of sand
# 700 units of sand
# 701 units of sand
# 702 units of sand
# 703 units of sand
# 704 units of sand
# 705 units of sand
# 706 units of sand
# 707 units of sand
# 708 units of sand
# 709 units of sand
# 710 units of sand
# 711 units of sand
# 712 units of sand
# 713 units of sand
# 714 units of sand
# 715 units of sand
# 716 units of sand
# 717 units of sand
# 718 units of sand
# 719 units of sand
# 720 units of sand
# 721 units of sand
# 722 units of sand
# 723 units of sand
# 724 units of sand
# 725 units of sand
# 726 units of sand
# 727 units of sand
# 728 units of sand
# 729 units of sand
# 730 units of sand
# 731 units of sand
# 732 units of sand
# 733 units of sand
# 734 units of sand
# 735 units of sand
# 736 units of sand
# 737 units of sand
# 738 units of sand
# 739 units of sand
# 740 units of sand
# 741 units of sand
# 742 units of sand
# 743 units of sand
# 744 units of sand
# 745 units of sand
# 746 units of sand
# 747 units of sand
# 748 units of sand
# 749 units of sand
# 750 units of sand
# 751 units of sand
# 752 units of sand
# 753 units of sand
# 754 units of sand
# 755 units of sand
# 756 units of sand
# 757 units of sand
# 758 units of sand
# 759 units of sand
# 760 units of sand
# 761 units of sand
# 762 units of sand
# 763 units of sand
# 764 units of sand
# 765 units of sand
# 766 units of sand
# 767 units of sand
# 768 units of sand
# 769 units of sand
# 770 units of sand
# 771 units of sand
# 772 units of sand
# 773 units of sand
# 774 units of sand
# 775 units of sand
# 776 units of sand
# 777 units of sand
# 778 units of sand
# 779 units of sand
# 780 units of sand
# 781 units of sand
# 782 units of sand
# 783 units of sand
# 784 units of sand
# 785 units of sand
# 786 units of sand
# 787 units of sand
# 788 units of sand
# 789 units of sand
# 790 units of sand
# 791 units of sand
# 792 units of sand
# 793 units of sand
# 794 units of sand
# 795 units of sand
# 796 units of sand
# 797 units of sand
# 798 units of sand
# 799 units of sand
# 800 units of sand
# 801 units of sand
# 802 units of sand
# 803 units of sand
# 804 units of sand
# 805 units of sand
# 806 units of sand
# 807 units of sand
# 808 units of sand
# 809 units of sand
# 810 units of sand
# 811 units of sand
# 812 units of sand
# 813 units of sand
# 814 units of sand
# 815 units of sand
# 816 units of sand
# 817 units of sand
# 818 units of sand
# 819 units of sand
# 820 units of sand
# 821 units of sand
# 822 units of sand
# 823 units of sand
# 824 units of sand
# 825 units of sand
# 826 units of sand
# 827 units of sand
# 828 units of sand
# 829 units of sand
# 830 units of sand
# 831 units of sand
# 832 units of sand
# 833 units of sand
# 834 units of sand
# 835 units of sand
# 836 units of sand
# 837 units of sand
# 838 units of sand
# 839 units of sand
# 840 units of sand
# 841 units of sand
# 842 units of sand
# 843 units of sand
# 844 units of sand
# 845 units of sand
# 846 units of sand
# 847 units of sand
# 848 units of sand
# 849 units of sand
# 850 units of sand
# 851 units of sand
# 852 units of sand
# 853 units of sand
# 854 units of sand
# 855 units of sand
# 856 units of sand
# 857 units of sand
# 858 units of sand
# 859 units of sand
# 860 units of sand
# 861 units of sand
# 862 units of sand
# 863 units of sand
# 864 units of sand
# 865 units of sand
# 866 units of sand
# 867 units of sand
# 868 units of sand
# 869 units of sand
# 870 units of sand
# 871 units of sand
# 872 units of sand
# 873 units of sand
# 874 units of sand
# 875 units of sand
# 876 units of sand
# 877 units of sand
# 878 units of sand
# 879 units of sand
# 880 units of sand
# 881 units of sand
# 882 units of sand
# 883 units of sand
# 884 units of sand
# 885 units of sand
# 886 units of sand
# 887 units of sand
# 888 units of sand
# 889 units of sand
# 890 units of sand
# 891 units of sand
# 892 units of sand
# 893 units of sand
# 894 units of sand
# 895 units of sand
# 896 units of sand
# 897 units of sand
# 898 units of sand
# 899 units of sand
# 900 units of sand
# 901 units of sand
# 902 units of sand
# 903 units of sand
# 904 units of sand
# 905 units of sand
# 906 units of sand
# 907 units of sand
# 908 units of sand
# 909 units of sand
# 910 units of sand
# 911 units of sand
# 912 units of sand
# 913 units of sand
# 914 units of sand
# 915 units of sand
# 916 units of sand
# 917 units of sand
# 918 units of sand
# 919 units of sand
# 920 units of sand
# 921 units of sand
# 922 units of sand
# 923 units of sand
# 924 units of sand
# 925 units of sand
# 926 units of sand
# 927 units of sand
# 928 units of sand
# 929 units of sand
# 930 units of sand
# 931 units of sand
# 932 units of sand
# 933 units of sand
# 934 units of sand
# 935 units of sand
# 936 units of sand
# 937 units of sand
# 938 units of sand
# 939 units of sand
# 940 units of sand
# 941 units of sand
# 942 units of sand
# 943 units of sand
# 944 units of sand
# 945 units of sand
# 946 units of sand
# 947 units of sand
# 948 units of sand
# 949 units of sand
# 950 units of sand
# 951 units of sand
# 952 units of sand
# 953 units of sand
# 954 units of sand
# 955 units of sand
# 956 units of sand
# 957 units of sand
# 958 units of sand
# 959 units of sand
# 960 units of sand
# 961 units of sand
# 962 units of sand
# 963 units of sand
# 964 units of sand
# 965 units of sand
# 966 units of sand
# 967 units of sand
# 968 units of sand
# 969 units of sand
# 970 units of sand
# 971 units of sand
# 972 units of sand
# 973 units of sand
# 974 units of sand
# 975 units of sand
# 976 units of sand
# 977 units of sand
# 978 units of sand
# 979 units of sand
# 980 units of sand
# 981 units of sand
# 982 units of sand
# 983 units of sand
# 984 units of sand
# 985 units of sand
# 986 units of sand
# 987 units of sand
# 988 units of sand
# 989 units of sand
# 990 units of sand
# 991 units of sand
# 992 units of sand
# 993 units of sand
# 994 units of sand
# 995 units of sand
# 996 units of sand
# 997 units of sand
# 998 units of sand
# 999 units of sand
# 1000 units of sand
# 1001 units of sand
# 1001units of snad have come to rest
